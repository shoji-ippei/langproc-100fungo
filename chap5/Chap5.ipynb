# %% [markdown]
# # 第5章: 係り受け解析
#
# ```bash
# $ cat data/neco.txt | cabocha -f1 > data/neko.txt.cabocha
# ```

# %% [markdown]
# ## 40. 係り受け解析結果の読み込み（形態素）

# %%
class Morph:
    def __init__(self, nd):
        self.surface = nd['surface']
        self.base = nd['base']
        self.pos = nd['pos']
        self.pos1 = nd['pos1']

with open('../data/neko.txt.cabocha', encoding='utf-8') as f:
    l = f.read().split('EOS\n')
f.close()

# %%
ls = list(filter(lambda x: x != '',l))
txtArr=[]
#surface \t part-of-speech, sub-class1, sub-class2, sub-class3, inflection, conjugation, base, reading, pronunciation
for line in ls:
    arr=[]
    for w in line.split('\n'):
        if w == '':continue
        elif w[0] == '*':continue
        surf,feat = w.split('\t')
        feat=feat.split(',')
        arr.append(
            Morph({
                    'surface': surf,
                    'base'   : feat[6],
                    'pos'    : feat[0],
                    'pos1'   : feat[1]
            })
        )
        
    txtArr.append(arr)

# %%
[x.surface for x in txtArr[6]]
# Out:
# ['しかも',
#  'あと',
#  'で',
#  '聞く',
#  'と',
#  'それ',
#  'は',
#  '書生',
#  'という',
#  '人間',
#  '中',
#  'で',
#  '一番',
#  '獰悪',
#  'な',
#  '種族',
#  'で',
#  'あっ',
#  'た',
#  'そう',
#  'だ',
#  '。']

# %% [markdown]
# ## 41. 係り受け解析結果の読み込み（文節・係り受け）

# %%
class Chunk:
    def __init__(self, morphs, dst):
        self.morphs = morphs
        self.dst = dst
        self.srcs = []

# %%
result=[]
for line in ls:
    lsChunk=[]
    #print(line)
    for w in line.split('\n'):
        if w == '':continue
        elif w[0] == '*': # chunk → 毎回文節の最初
            dst=w.split(' ')[2].rstrip('D')
            # 　新規Chunkオブジェクト作成、チャンクリスト末尾に入れる
            lsChunk.append(Chunk([],int(dst)))
        else: # 単語
            surf,feat = w.split('\t')
            feat=feat.split(',')
            # 　lsChunkの最後のChunkオブジェクト（この単語を含む文節の最初で作成される）
            # 　取り出したlsChunkのmorphsリストに入れる
            lsChunk[-1].morphs.append(
                Morph({
                        'surface': surf,
                        'base'   : feat[6],
                        'pos'    : feat[0],
                        'pos1'   : feat[1]
                })
            )
            
    for i,c in enumerate(lsChunk):
        # dist番目のチャンクのsrcsリストに各チャンクのindexを入れる
        lsChunk[lsChunk[i].dst].srcs.append(i)
    
    result.append(lsChunk)
    
for ch in result[7]:
    print(f"{''.join([m.surface for m in ch.morphs])} (-> {''.join([w.surface for w in result[7][ch.dst].morphs])})")
# Out:
# この (-> 書生というのは)
# 書生というのは (-> 話である。)
# 時々 (-> 捕えて)
# 我々を (-> 捕えて)
# 捕えて (-> 煮て)
# 煮て (-> 食うという)
# 食うという (-> 話である。)
# 話である。 (-> 話である。)

# %% [markdown]
# ## 42. 係り元と係り先の文節の表示

# %%
for chList in result[0:10]:
    for ch in chList:
        print(''.join([m.surface for m in list(filter(lambda x: x.pos != '記号', ch.morphs))]),
              ''.join([w.surface for w in list(filter(lambda x: x.pos != '記号', chList[ch.dst].morphs))]),
             sep='\t')
# Out:
# 一	一
# 	猫である
# 吾輩は	猫である
# 猫である	猫である
# 名前は	無い
# まだ	無い
# 無い	無い
# どこで	生れたか
# 生れたか	つかぬ
# とんと	つかぬ
# 見当が	つかぬ
# つかぬ	つかぬ
# 何でも	薄暗い
# 薄暗い	所で
# じめじめした	所で
# 所で	泣いて
# ニャーニャー	泣いて
# 泣いて	記憶している
# いた事だけは	記憶している
# 記憶している	記憶している
# 吾輩は	見た
# ここで	始めて
# 始めて	人間という
# 人間という	ものを
# ものを	見た
# 見た	見た
# しかも	種族であったそうだ
# あとで	聞くと
# 聞くと	種族であったそうだ
# それは	種族であったそうだ
# 書生という	人間中で
# 人間中で	種族であったそうだ
# 一番	獰悪な
# 獰悪な	種族であったそうだ
# 種族であったそうだ	種族であったそうだ
# この	書生というのは
# 書生というのは	話である
# 時々	捕えて
# 我々を	捕えて
# 捕えて	煮て
# 煮て	食うという
# 食うという	話である
# 話である	話である
# しかし	思わなかった
# その	当時は
# 当時は	なかったから
# 何という	考も
# 考も	なかったから
# なかったから	思わなかった
# 別段	恐し
# 恐し	思わなかった
# いとも	思わなかった
# 思わなかった	思わなかった
# ただ	載せられて
# 彼の	掌に
# 掌に	載せられて
# 載せられて	持ち上げられた
# スーと	持ち上げられた
# 持ち上げられた	時
# 時	フワフワした
# 何だか	フワフワした
# フワフワした	感じが
# 感じが	あったばかりである
# あったばかりである	あったばかりである

# %% [markdown]
# ## 43. 名詞を含む文節が動詞を含む文節に係るものを抽出

# %%
for chList in result[0:100]:
    for ch in chList:
        txt=''.join([m.surface for m in list(filter(lambda x: x.pos != '記号', ch.morphs))])
        dstTxt=''.join([w.surface for w in list(filter(lambda x: x.pos != '記号', chList[ch.dst].morphs))])
        posList=[m.pos for m in list(filter(lambda x: x.pos != '記号', ch.morphs))]
        posDstList=[m.pos for m in list(filter(lambda x: x.pos != '記号', chList[ch.dst].morphs))]
        
        if '名詞' in posList and '動詞' in posDstList:
            print(txt, dstTxt,sep='\t')
# Out:
# どこで	生れたか
# 見当が	つかぬ
# 所で	泣いて
# ニャーニャー	泣いて
# いた事だけは	記憶している
# 記憶している	記憶している
# 吾輩は	見た
# ここで	始めて
# ものを	見た
# あとで	聞くと
# 我々を	捕えて
# 掌に	載せられて
# スーと	持ち上げられた
# 時	フワフワした
# 感じが	あったばかりである
# 上で	落ちついて
# 顔を	見たのが
# ものの	見始であろう
# 見始であろう	見始であろう
# ものだと	思った
# 感じが	残っている
# 今でも	残っている
# 第一毛をもって	装飾されべきはずの
# 顔が	つるつるして
# その後	逢ったが
# 猫にも	逢ったが
# 一度も	出会わした
# 真中が	突起している
# 突起している	突起している
# 中から	吹く
# ぷうぷうと煙を	吹く
# 咽せぽくて	弱った
# 人間の	飲む
# 事は	知った
# 頃	知った
# 裏で	坐って
# 心持に	坐って
# 速力で	運転し始めた
# 運転し始めた	運転し始めた
# 書生が	動くのか
# 動くのか	動くのか
# 自分だけが	動くのか
# 動くのか	分らないが
# 眼が	廻る
# 胸が	悪くなる
# 音が	して
# 眼から	出た
# 火が	出た
# それまでは	記憶しているが
# 記憶しているが	分らない
# あとは	分らない
# 事やら	分らない
# 気が	付いて
# 書生は	いない
# たくさん	おった
# 兄弟が	見えぬ
# 一疋も	見えぬ
# 母親さえ	隠してしまった
# 姿を	隠してしまった
# 所とは	違って
# 眼を	明いていられぬくらいだ
# 吾輩は	棄てられたのである
# 上から	棄てられたのである
# 急に	棄てられたのである
# 中へ	棄てられたのである
# 棄てられたのである	棄てられたのである
# 思いで	這い出すと
# 笹原を	這い出すと
# 向うに	ある
# 池が	ある
# 吾輩は	見た
# 前に	坐って
# 分別も	出ない
# 書生がまた	来てくれるかと
# 迎に	来てくれるかと
# 試みに	やって
# 誰も	来ない
# 上を	渡って
# 風が	渡って
# 日が	かかる
# 暮れ	かかる
# 腹が	減って来た
# 非常に	減って来た
# 声が	出ない
# 何でも	廻り始めた
# 食物の	ある
# 所まで	ある
# 決心を	して
# 池を	廻り始めた
# 左りに	廻り始めた
# そこを	我慢して
# 我慢して	這って行くと
# 無理やりに	這って行くと
# 事で	出た
# 所へ	出た
# ここへ	這入ったら
# 竹垣の	崩れた
# 穴から	もぐり込んだ
# 邸内に	もぐり込んだ
# もので	餓死したかも知れんのである
# 竹垣が	破れていなかったなら
# 吾輩は	餓死したかも知れんのである
# 路傍に	餓死したかも知れんのである
# 餓死したかも知れんのである	餓死したかも知れんのである
# 蔭とは	云った
# 穴は	なっている
# 今日に	至るまで
# 吾輩が	訪問する
# 三毛を	訪問する
# 通路に	なっている
# 邸へは	忍び込んだものの
# うちに	暗くなる
# 腹は	減る
# 雨が	降って来るという
# 始末で	出来なくなった
# 猶予が	出来なくなった
# 方へ	あるいて行く
# 方へと	あるいて行く
# 今から	考えると
# 時は	おったのだ
# 内に	這入って
# おったのだ	おったのだ
# ここで	遭遇したのである
# 吾輩は	遭遇したのである
# 人間を	見るべき
# 機会に	遭遇したのである
# 遭遇したのである	遭遇したのである
# 第一に	逢ったのが
# これは	抛り出した
# 書生より	見るや
# 方で	見るや
# 吾輩を	見るや
# 否やいきなり	つかんで
# 頸筋を	つかんで
# 表へ	抛り出した
# 駄目だと	思ったから
# 眼を	ねぶって
# 運を	任せていた
# 天に	任せていた
# 寒いのには	出来ん
# 我慢が	出来ん
# 吾輩は	這い上った
# 隙を	見て
# 台所へ	這い上った
# 吾輩は	這い上り
# 何でも	繰り返したのを
# 事を	繰り返したのを
# 四五遍	繰り返したのを
# 繰り返したのを	記憶している
# 記憶している	記憶している
# 時に	云う
# おさんと	云う
# 者は	いやになった
# いやになった	いやになった
# 偸んで	してやってから
# 返報を	してやってから
# 痞が	下りた
# 吾輩が	つまみ出されようとした
# 最後に	つまみ出されようとした
# ときに	出て来た
# 主人が	出て来た
# 何だと	いいながら
# 下女は	困りますと
# 吾輩を	ぶら下げて
# 方へ	向けて
# 小猫が	出しても
# 御台所へ	上って来て
# 主人は	おったが
# 毛を	撚りながら
# 顔を	眺めて
# そんなら	置いてやれといったまま
# 内へ	置いてやれといったまま
# 置いてやれといったまま	這入ってしまった
# 奥へ	這入ってしまった
# 主人は	見えた
# 口を	聞かぬ
# 人と	見えた
# 下女は	抛り出した
# 口惜しそうに	抛り出した
# 吾輩を	抛り出した
# 台所へ	抛り出した
# 吾輩は	したのである
# 家を	極める
# 住家と	極める
# 事に	したのである
# したのである	したのである
# 滅多に	合せる
# 吾輩と	合せる
# 顔を	合せる
# 学校から	帰ると
# 終日	這入った
# 書斎に	這入った
# 勉強家だと	思っている
# ものが	いうような
# 吾輩は	見るが
# 忍び足に	覗いて
# 書斎を	覗いて
# 彼は	ある
# 昼寝を	している
# 事が	ある
# 上に	たらしている
# 涎を	たらしている
# 彼は	あらわしている
# 胃弱で	帯びて
# 色が	帯びて
# 黄色を	帯びて
# 徴候を	あらわしている
# 癖に	食う
# 大飯を	食う
# 大飯を	食った
# 後で	飲む
# タカジヤスターゼを	飲む
# 後で	ひろげる
# 書物を	ひろげる
# 二三ページ	読むと
# 涎を	垂らす
# 上へ	垂らす
# これが	繰り返す
# 毎夜	繰り返す
# 吾輩は	ある
# 猫ながら	考える
# 事が	ある
# 人間と	生れたら
# 教師と	なるに
# 猫にでも	出来ぬ
# 主人に	云わせると
# ないそうで	鳴らしている
# 彼は	鳴らしている
# 友達が	来る
# 度に	鳴らしている
# 不平を	鳴らしている
# 吾輩が	住み込んだ
# 家へ	住み込んだ
# どこへ	行っても
# 相手に	してくれ
# 珍重されなかったかは	分る
# 今日に	至るまで
# 名前さえ	つけてくれないのでも
# つけてくれないのでも	分る
# 限り	入れてくれた
# 吾輩を	入れてくれた
# 傍に	いる
# 事を	つとめた
# 朝主人が	読む
# 新聞を	読む
# ときは	乗る
# 上に	乗る
# 彼が	する
# 昼寝を	する
# ときは	乗る
# 背中に	乗る
# これは	やむを得んのである
# やむを得んのである	やむを得んのである
# その後	した
# 上	した
# 朝は	した
# 上	した
# 夜は	した
# 上	した
# 昼は	した
# 椽側へ	寝る
# 事と	した
# 夜に	入って
# 寝床へ	もぐり込んで
# いっしょに	ねる
# 小供というのは	寝る
# 三つで	なると
# 夜に	なると
# 二人が	寝る
# 一つ	寝る
# 床へ	入って
# 一間へ	寝る
# 吾輩は	割り込むのであるが
# いつでも	見出して
# 中間に	見出して
# 己れを	見出して
# 余地を	見出して
# 割り込むのであるが	なる
# 運悪く	醒ますが
# 一人が	醒ますが
# 眼を	醒ますが
# 事に	なる
# 小供は——	泣き出すのである
# 方が	来た
# 質が	来た
# わるい——猫が	来た
# 猫が	来たと
# 夜中でも	泣き出すのである
# 何でも	泣き出すのである
# 声で	泣き出すのである
# 泣き出すのである	泣き出すのである
# 主人は	飛び出してくる
# 眼を	さまして
# 部屋から	飛び出してくる
# せんだってなどは	叩かれた
# 物指で	叩かれた
# 尻ぺたをひどく	叩かれた
# 吾輩は	断言せざるを得ないようになった
# 人間と	同居して
# 同居して	観察すれば
# 彼等を	観察すれば
# 観察すれば	する
# 彼等は	断言せざるを得ないようになった
# ものだと	断言せざるを得ないようになった
# 断言せざるを得ないようになった	断言せざるを得ないようになった

# %% [markdown]
# ## 44. 係り受け木の可視化

# %%
import pydot

coms=[]
for chList in [result[7]]:
    for ch in chList:
        txt=''.join([m.surface for m in list(filter(lambda x: x.pos != '記号', ch.morphs))])
        dstTxt=''.join([w.surface for w in list(filter(lambda x: x.pos != '記号', chList[ch.dst].morphs))])
        if txt != '' and dstTxt != '':
            coms.append((txt,dstTxt))

g=pydot.graph_from_edges(coms)
g.write_png('../data/44.png', prog='dot')
# Out:
# True

# %% [markdown]
# ## 45. 動詞の格パターンの抽出

# %%
n,t='\n','\t'
res=[]
with open('../data/45.txt', mode='w') as f:
    for chList in result:
        for ch in chList:
            ils=[idx for idx, x in enumerate([m.pos for m in list(filter(lambda x: x.pos != '記号', ch.morphs))]) if x == '動詞']
            if len(ils)==0:continue
            for i in ils:
                postPosList=[m.base for m in list(filter(lambda x: x.pos != '記号', sum([chList[idx].morphs for idx in ch.srcs],[]))) if m.pos == '助詞']
                f.write(f"{ch.morphs[i].base}{t}{' '.join(postPosList)}{n}")
f.close()

# %%
# !cat ../data/45.txt | sort | uniq -c | sort -nr
# Out:
#    2920 する	が
#    1968 つく	か が
#    1122 する
#    1014 する	が と で
#     654 云う	に
#     496 いる	は て を て
#     436 られる	に
#     357 られる	て と
#     328 する	まで は
#     316 見る	の
#     255 云う	と は
#     250 思う	と
#     250 かける
#     244 「
#     241 ある	まで
#     201 する	が は へ と を
#     183 たらす	に を て
#     143 する	まで が を
#     135 出る	も
#     128 見せる	て
#     128 来る	が
#     125 ある	が かい
#     123 思う	と て
#     117 いる	が でも て
#     114 云う
#     113 云う	て は と
#     112 見る	は を
#     108 出る	の に
#     106 行く	へ
#     105 する	から て て を
#      98 出来る	て
#      96 聞く	で
#      92 する	て だけ は て
#      84 あるく	へ へ と て
#      80 なる	ものの に
#      80 つづける	を
#      77 いる	と て に が に て
#      76 見る
#      74 聞く	で を
#      73 来る	が に
#      72 知る	は
#      70 行く	て に
#      67 なる	と に かも
#      67 ひろげる	で を
#      67 あきれる
#      63 食う	て
#      63 出る	て も が
#      56 聞く
#      53 出来る	で が
#      51 見る	は て て
#      50 しいる	じゃ と
#      49 分る	か
#      47 生れる	で
#      47 云う	から と
#      46 く	と
#      45 たつ	なんか
#      44 見える	が も
#      44 知る	に を
#      44 くる	は て から て
#      43 来る	が に て
#      43 持つ	を
#      43 出る	て と で へ
#      42 行く	は に は
#      42 云う	とか
#      41 這入る	へ
#      39 ふてる	ほど
#      38 話す
#      38 死ぬ
#      38 分る	に も
#      37 食う	に を
#      37 至る	に
#      37 来る
#      37 する	は ながら を
#      36 読む	を
#      36 考える	と
#      36 思う	て か と
#      36 帰る	に
#      36 出す
#      35 出来る
#      35 わする	ね と て へ と
#      35 あらわれる	が
#      34 行く
#      34 知る
#      34 おる	ばかり が て
#      33 話す	の
#      32 返る
#      32 得る	を
#      32 入る	に
#      32 いる	から て を に て
#      31 起す	が を
#      31 聞く	か て を
#      31 考える
#      30 言う	と
#      30 する	と て たり を て
#      30 おっしゃる	な と
#      29 立つ	に
#      29 ある	に て や さえ て
#      28 来る	か に て て
#      28 向う	に
#      28 出来る	に は が
#      28 入れる	を へ
#      28 ある	が ばかり
#      27 飲む	の
#      27 貰う	に
#      27 くらべる	ね と に
#      26 見る	ので が
#      26 寝る	へ
#      26 出る	でも へ
#      26 やる	は て て て で か て
#      25 過ぎる	が
#      25 笑う	は て に
#      25 笑う	て て
#      25 笑う
#      25 死ぬ	が
#      25 つく	と やら に も が
#      24 笑う	て
#      24 立てる	を
#      24 来る	やら
#      24 持つ	が を
#      24 作る	で
#      24 す	に を
#      24 する	て は に かも
#      24 しまう	さえ を て
#      23 逢う	に
#      23 向く	へ が
#      23 取る	は
#      23 分る
#      23 云う	など は と
#      23 やむをえる
#      22 起る	が
#      22 思う
#      21 見る	から
#      21 立つ	て も
#      21 知れる	か
#      21 寝る
#      21 云う	で は を と
#      21 ある	たり ちゃ は
#      20 読む	が を
#      20 生きる
#      20 引く	が
#      20 困る
#      20 出来る	も が て て
#      20 出る	から
#      20 いける	に ちゃ
#      19 這入る	と て
#      19 込む	て へ
#      19 買う	も て
#      19 知れる	かも
#      19 書く	に
#      19 付く	が
#      19 下さる	て
#      19 とる	など は から
#      19 られる	は から に へ
#      18 遣る
#      18 買う	を
#      18 見える	と て を と
#      18 置く	が に
#      18 怒る	て
#      18 得る	は を
#      18 廻る	が が
#      18 困る	は
#      18 受ける	を
#      18 下せる	て に
#      18 上げる	と を
#      18 すます	じゃ か は て
#      17 来る	から に
#      17 利く	は
#      17 上る	て へ
#      17 やめる	で から を
#      16 飲む
#      16 食う
#      16 限る	に
#      16 買う
#      16 聞かす	か
#      16 答える	て と
#      16 立つ
#      16 知れる	と に かも
#      16 有る	が
#      16 忘れる	を
#      16 困る	て は
#      16 取る	が よ
#      16 切る	と
#      16 上げる	を
#      16 あらわす	は て を て
#      15 足す	の
#      15 聞く	より を
#      15 聞く	か と が に
#      15 考える	も と
#      15 着る	に
#      15 待つ	を
#      15 帰る
#      15 する	て て だけ に よ と
#      14 鳴る	が
#      14 開く	に
#      14 違う	が
#      14 過ぎる	に を
#      14 這入る	は て へ
#      14 這入る
#      14 見える	に は が
#      14 行く	でも に
#      14 知る	て に を
#      14 来る	が から
#      14 思う	は で も に
#      14 廻る	へ
#      14 始める	で
#      14 入れる	を
#      14 乗る	に
#      14 上る
#      13 言う	が を
#      13 落ちる	が
#      13 致す	に を
#      13 致す	に
#      13 致す
#      13 置く	て て ね
#      13 知らす	を て
#      13 申す
#      13 振る	を
#      13 怒る
#      13 変る
#      13 呼ぶ	が
#      13 く	は て を
#      13 ある	から に じゃ か
#      13 する	に たって に は
#      13 かく	は で ばかり て
#      13 いる	を て くらい
#      13 かける	ばかり が
#      13 ぱちつかせる	を
#      12 食う	で に が
#      12 飛び込む	へ
#      12 飛ぶ
#      12 起きる
#      12 読む
#      12 給う	で
#      12 答える	と は て
#      12 立てる	と へ
#      12 申す	と
#      12 生きる	て に
#      12 持つ
#      12 得る	で に が
#      12 廻る	て て を
#      12 寝る	て へ
#      12 坐る	に
#      12 合う	に
#      12 取る
#      12 参る	も と
#      12 動く	が
#      12 分る	か に は
#      12 出す	が から を
#      12 使う	を に
#      12 住む	に
#      12 云う	は ので と
#      12 云う	に とか
#      12 上る	は て へ
#      12 する	をもって
#      12 やる	に て も だけ は て
#      11 鳴る
#      11 飲む	で を
#      11 食う	でも か
#      11 飛ぶ	と
#      11 隣る
#      11 限る	も に
#      11 逢う	に も
#      11 返る	に
#      11 行く	まで
#      11 行く	へ へ と て
#      11 考える	が て て
#      11 答える	と
#      11 教える	と
#      11 持つ	に を へ
#      11 打つ
#      11 懸ける	て に
#      11 吹く	を
#      11 合う	は に
#      11 受ける	も て
#      11 切る	を で
#      11 似る	で
#      11 付ける	て も
#      11 付ける	を
#      11 上る	へ
#      11 する	によって と は
#      11 れる	って から
#      11 れる	から は に も は に
#      11 られる	に て から も
#      11 つとめる	から を
#      10 黙る
#      10 驚く	て
#      10 違う	と は
#      10 通る	と を
#      10 送る	て
#      10 起す	は て を
#      10 貰う	も て
#      10 落ちる	で は
#      10 落ちる
#      10 脱ぐ	を
#      10 磨る	で
#      10 着る	に を
#      10 泣く
#      10 死ぬ	と と
#      10 有る	も も
#      10 暮らす	が
#      10 打つ	も
#      10 懸ける	を
#      10 待つ
#      10 張る	を
#      10 吹く	を に
#      10 ある	について が
#      10 くる	ながら まで
#      10 する	は ほど は と を に
#      10 いただく	から
#       9 食える	は
#       9 過ぎる	は で は
#       9 過ぎる
#       9 通す	に
#       9 足す	て を
#       9 話す	て を
#       9 見る	より で を
#       9 見る	か ね と を
#       9 落す	を へ
#       9 繰り返す	が
#       9 来る	のに に を
#       9 書く	を で
#       9 懸る
#       9 延ばす	を
#       9 始める	が と で
#       9 始める
#       9 好く	に
#       9 利く	で も
#       9 出来る	から が
#       9 出来る	よ から に
#       9 出す	たり を へ
#       9 入る	が に
#       9 使う	で
#       9 云う	ので と は て
#       9 乗る	は に
#       9 下りる	は と を
#       9 ろ	ので
#       9 めす	など は に まで
#       9 いる	て は として の に
#       9 いる	て と て に とか
#       9 せる	は に て に を て と を
#       9 わする	よ と が を の の
#       9 おっしゃる	ね は と
#       9 いらっしゃる	は て
#       8 食える	と が
#       8 隣る	が
#       8 開く	は を
#       8 述べる	を
#       8 解す	を
#       8 覚める	が
#       8 見る	は て で を て
#       8 行く	など は へ
#       8 行く	と は て と へ
#       8 聞く	じゃ
#       8 聞く	て は か と で
#       8 考える	から
#       8 相
#       8 直す	を
#       8 構う	にゃ
#       8 構う	に も
#       8 来る	て と が を て
#       8 有す	は を て
#       8 持つ	まで
#       8 折れる	に が
#       8 思い切る
#       8 忘れる	に を
#       8 引く	て を
#       8 廻る	で も を に
#       8 帰る	か に て て
#       8 帰る	て は
#       8 存じる	と
#       8 始める	に で
#       8 売る
#       8 在る	が
#       8 困る	て から
#       8 喰う	が
#       8 向う
#       8 叩く	で を
#       8 取る	が を て
#       8 及ぶ	に も
#       8 去る	を
#       8 劣る	に
#       8 分る	すら
#       8 分る	か は て も
#       8 出来る	に でも
#       8 出掛ける	と
#       8 出る	が から
#       8 云う	で など は と
#       8 れる	から くらい へ
#       8 なる	て でも より
#       8 あるく	て を って
#       8 のぼる	か へ と のみ
#       8 いらっしゃる
#       7 頼む	を
#       7 連れる	を
#       7 逢う	が で に
#       7 逢う
#       7 這入る	ちゃ
#       7 送る	が を
#       7 迂る
#       7 込む	を
#       7 足りる	が
#       7 負ける	も
#       7 覚める	て が
#       7 見廻る	を
#       7 行う	に でも
#       7 舐める
#       7 置く	へ
#       7 給う	に て
#       7 笑う	は の よ と
#       7 立つ	は て て
#       7 知れる	は より
#       7 知れる	て は に かも
#       7 疑う
#       7 洗う	が を
#       7 泣く	で
#       7 殺す
#       7 極める	を と
#       7 来る	ながら を
#       7 有る
#       7 教える	か に
#       7 撫でる	て を
#       7 撫でる
#       7 掻く	を
#       7 捕える	を
#       7 振る
#       7 持つ	は は を て
#       7 折れる	が
#       7 打つ	と を
#       7 感ずる	を
#       7 御
#       7 得る
#       7 張る	と を
#       7 引く	ね と に
#       7 引く
#       7 変る	の
#       7 坐る	で に
#       7 取る	と は に ね
#       7 動く
#       7 出来る	など も が
#       7 出る	から に て へ
#       7 出る	が ので も に
#       7 出る	へ は で へ て
#       7 入れる	で も に
#       7 伺う
#       7 云う	ばかり も
#       7 云う	か ね と は を
#       7 いる	ながら て を て
#       7 きく	から は より が を
#       7 てる	と によって を
#       7 おる	て か な まで は が て
#       7 られる	から と から
#       7 られる	に て や さえ て
#       6 鳴る	で が に
#       6 驚く	と ね
#       6 食う	で は が は
#       6 飛ぶ	ば で
#       6 離れる	が を
#       6 離れる	を
#       6 隠す
#       6 障る	に
#       6 陣取る	に
#       6 釣る	が に
#       6 這入る	と は へ に
#       6 起す
#       6 買う	は て も
#       6 貰う
#       6 負ける
#       6 読む	な と は
#       6 読める	の
#       6 許す	の
#       6 覚える
#       6 覗く	を
#       6 見る	に って を
#       6 見る	て まで
#       6 行く	で まで で
#       6 蒙る
#       6 落す	を
#       6 落ちつく	に が
#       6 立つ	か な と に
#       6 立てる
#       6 突く	で を
#       6 穿つ	を
#       6 禿げる	が
#       6 示す	を
#       6 知れる
#       6 眺める	の と を
#       6 盗む	を
#       6 用いる	を
#       6 済む	て
#       6 浮く	に
#       6 洗う	を
#       6 構う	は で も
#       6 来る	て より が
#       6 来る	へ が から
#       6 書く
#       6 撫でる	て て を
#       6 控える	を に
#       6 控える	て
#       6 掛ける	と
#       6 捕る	て
#       6 挙げる	を
#       6 抜く	が を
#       6 折る	の
#       6 承る	ば
#       6 懸る	を
#       6 恐れ入る	て ね
#       6 思う	でも と は
#       6 思う	から と
#       6 思う	て んで と
#       6 怒る	が に
#       6 忘れる	な と は
#       6 心得る	は が は て
#       6 待つ	を を
#       6 弾く
#       6 引く	は の に で
#       6 延びる	の が
#       6 威張る
#       6 好む
#       6 困る	ちゃ
#       6 喰う	て を に
#       6 向ける	へ
#       6 合わす	に
#       6 叩く	か
#       6 動じる	は も
#       6 分る	つつ か
#       6 出来る	に だけ は が
#       6 出来る	て と が に て ぜ
#       6 光る	の
#       6 光る
#       6 借りる	を
#       6 使う	と を に
#       6 似合う	が
#       6 似る
#       6 仕る	は
#       6 云う	ながら
#       6 乗せる	を
#       6 中る	と
#       6 並ぶ	と
#       6 上げる	て て て
#       6 上げる
#       6 する	じゃ だけ は に
#       6 いる	から と は まで も で
#       6 する	が によって
#       6 する	は から まで を
#       6 いる	て のに を て から
#       6 する	が から に は を に も
#       6 いる	て は ばかり に を て
#       6 かける	ので よ と は に
#       6 ほのめかす	など と
#       5 黙る	か
#       5 驚く
#       5 飛び込む
#       5 飛び出す	て
#       5 頼む
#       5 限る	と は に
#       5 進む	が
#       5 通る
#       5 返る	は て と
#       5 迎える	を
#       5 込む
#       5 転がる	と て て
#       5 転がる	に
#       5 越す	に
#       5 負ける	から
#       5 誘う	を
#       5 見える	より に
#       5 被る	を
#       5 落ちる	な か が
#       5 落ちつく
#       5 至る	と に
#       5 聴く	に が
#       5 聴く	は
#       5 聞える	て と が
#       5 聞かす	に を
#       5 置く
#       5 続く	も
#       5 結う	に
#       5 終る	を
#       5 立てる	に は を の
#       5 称する	と
#       5 破る	を
#       5 破れる	が
#       5 知る	より も
#       5 知る	さえ
#       5 知る	て は は か
#       5 知れる	て は か
#       5 着く	に を が
#       5 眺める	は て を て
#       5 眺める	て
#       5 眠る	て
#       5 直す	は は を
#       5 留める	に も
#       5 申し合せる	も
#       5 申す	か と
#       5 生れる	でも と
#       5 生える	で に の
#       5 煮る	て
#       5 照らす	に
#       5 焚く	を
#       5 減る	は
#       5 気に入る	で
#       5 殺す	て
#       5 残る	も
#       5 残る
#       5 構う	に
#       5 構う
#       5 極まる	に
#       5 来る	さえ から
#       5 教える	も を て
#       5 放す	を
#       5 放つ
#       5 握る	を
#       5 掻く	を に
#       5 掛ける	は は
#       5 捲く	を へ
#       5 捧げる	て に
#       5 振る	の に を
#       5 振る	に を
#       5 拾う	ば
#       5 拾う
#       5 担ぐ	は
#       5 抱く	を
#       5 抜ける	が
#       5 抑える	を で
#       5 払う	の
#       5 懸る	は に
#       5 懸ける
#       5 感ずる	て を
#       5 悟る
#       5 恐れ入る
#       5 忍ぶ	を
#       5 心得る	を の
#       5 当る	の
#       5 弾く	を
#       5 帰る	て へ さ
#       5 尽す	を
#       5 尋ねる	を に
#       5 寝る	に は で
#       5 寄る	へ
#       5 存じる	か と
#       5 困る	から も
#       5 噛む
#       5 喰う	に が
#       5 吹く
#       5 向く	と は を
#       5 合う
#       5 叩く	な と で を
#       5 取り上げる	を
#       5 反す	に
#       5 及ぶ	な て に
#       5 参る	ので に も
#       5 参る	へ
#       5 勝つ
#       5 動く	て に て
#       5 劣る	に も
#       5 割る	で を
#       5 切る	て を と
#       5 分ける	を に
#       5 出来る	とも は と が
#       5 出来る	から
#       5 出る	ながら を
#       5 入る
#       5 似合う	の ね
#       5 付く	の に
#       5 云う	の なんて を
#       5 云う	て を など と
#       5 乗る
#       5 与える	ば を
#       5 下る	が
#       5 上る	から
#       5 「	じゃ か
#       5 く	ば は に て
#       5 やる	んで か を て っけ
#       5 てる	が だって へ が じゃ か
#       5 いる	に たり て たり て て
#       5 する	は たり へ だり
#       5 いる	て は か と くらい て
#       5 てる	て て が ね が じゃ
#       5 わかる	なんか に が
#       5 まする	により
#       5 つける	まで さえ
#       5 いじる	て ながら を
#       5 ならぶ	で でも に で も
#       5 いける	に な じゃ を に
#       5 かぶせる	たり へ を
#       5 からかう	か は を て に
#       5 ぱちつかせる	と が を
#       4 黙る	と て
#       4 驚かす	を よ
#       4 飲む	から
#       4 食う	を んで
#       4 飛び出す	から
#       4 飛ぶ	ので
#       4 願う
#       4 雇う	を
#       4 隠す	を
#       4 隔てる	を
#       4 降る	が
#       4 降りる	と
#       4 降りる
#       4 間違える	と
#       4 釣る	を
#       4 重なる	に と
#       4 重なる	が
#       4 重んずる	を
#       4 還す
#       4 避ける	を
#       4 達す	も に
#       4 連れる	て ば
#       4 途切れる	が
#       4 逃がす
#       4 退く
#       4 述べる	よ と を と
#       4 述べる	よ と を
#       4 述べる	と を
#       4 込む	が は に へ
#       4 踏む	を
#       4 起る	でも は
#       4 起こす	て を に
#       4 起きる	て
#       4 貰う	など は て
#       4 負ける	で と も
#       4 認める	を
#       4 話す	とか
#       4 評す	と
#       4 訴える	に
#       4 計る	が
#       4 言う
#       4 見渡す	て
#       4 見廻す	と を
#       4 見付ける	に
#       4 見る	たり て が を
#       4 見せる	など も に
#       4 見える	が ので と
#       4 見える	な と は て に に
#       4 見える
#       4 見つめる	て を
#       4 見つめる	に
#       4 表す	を
#       4 行く	から は へ に
#       4 蒙る	を
#       4 至る	て から に
#       4 至る	ば も に
#       4 聞く	も から
#       4 罹る	に
#       4 給う
#       4 籠る	が
#       4 答える	て と が に
#       4 答える
#       4 笑う	ので
#       4 立てる	も を を
#       4 移す	を へ
#       4 称する	とか
#       4 私
#       4 磨く	で で
#       4 磨る
#       4 睨める	を
#       4 着る
#       4 直す
#       4 登る	が へ
#       4 登る
#       4 申し合せる
#       4 生ずる	より
#       4 濁す	て を
#       4 潰す	を
#       4 潜る	を
#       4 流す	ば て
#       4 流す	を
#       4 洩らす	て を
#       4 洩らす	を
#       4 泣く	は に
#       4 求める	に を
#       4 求める
#       4 気が付く	な と
#       4 気が付く	と
#       4 比べる	と
#       4 残る	が に
#       4 構う	が まで
#       4 構える	て に
#       4 構える	に
#       4 極める	は は に
#       4 来る	ので て と ね
#       4 来る	て から と で
#       4 来る	と は から て
#       4 来る	て と が の に て
#       4 書く	で と て
#       4 暮す	に て
#       4 暮らす	と で
#       4 昔
#       4 敷く	に
#       4 散る	の
#       4 放す	は て て
#       4 撲る
#       4 損なう
#       4 揚げる	を
#       4 描く	を
#       4 掻く
#       4 掠める	を
#       4 掛る	が
#       4 捨てる	を
#       4 捧げる	に
#       4 捕る
#       4 挟む	は へ
#       4 持つ	て と が を て
#       4 担ぐ	て を
#       4 抜く	を
#       4 抛り出す	へ の に
#       4 抛る	を を
#       4 抓む	を
#       4 悟る	と
#       4 思い出す	は を
#       4 思う	だけ は と も
#       4 怒鳴る	と
#       4 応ずる	に
#       4 忍び込む
#       4 心得る	と
#       4 得る	から と
#       4 得る	は て か と を
#       4 待つ	から
#       4 引っ張る	が を
#       4 弁じる	は か
#       4 弁じる	て
#       4 廻る	から
#       4 帰る	って て
#       4 帯びる	を
#       4 差し支える
#       4 尽す
#       4 尽きる	で が
#       4 尋ねる	か と は に
#       4 尋ねる	て
#       4 寝転ぶ	で
#       4 始める	から を
#       4 失う	を
#       4 変る	に の
#       4 売る	が
#       4 坐る	と て て
#       4 喰う
#       4 命ずる	も を
#       4 呼ぶ	は が
#       4 呼ぶ
#       4 呑む
#       4 告げる	て を
#       4 吐く	に は を
#       4 取る	から
#       4 勧める	の
#       4 動く	て を
#       4 利く
#       4 切る
#       4 切れる	で が
#       4 分る	ものの か
#       4 分る	か から
#       4 分る	が で は て か
#       4 出掛ける	て も
#       4 出る	は か から
#       4 写す	に を
#       4 入る	に は に
#       4 入れる	まで も に
#       4 入れる	で に は て に
#       4 借る	て を
#       4 借る	が
#       4 候う	も
#       4 倒れる
#       4 信じる	が
#       4 作る	て を
#       4 余る	も
#       4 似る	が に
#       4 伺う	て
#       4 任せる	に
#       4 付く	て か が
#       4 仕切る	て を
#       4 仕る
#       4 云う	とか ので ね
#       4 云う	に へ って
#       4 云う	が も と は と ば
#       4 乗る	て て へ
#       4 下さる	だけ を
#       4 下ろす
#       4 ぶら下げる	を
#       4 す	が から へ
#       4 なる	くらい から ば
#       4 いる	という に を が と
#       4 おる	たり が に は も も て
#       4 くる	は だって から て
#       4 する	に は から に が て ね
#       4 する	て が て たって
#       4 いる	は か な と から て て
#       4 ならぶ	が まで も て は に
#       4 からかう	なんて に
#       4 つづける	て から が
#       4 おっしゃる	じゃ か と
#       4 いらっしゃる	じゃ に
#       3 鳴る	から が と
#       3 鳴らす	を
#       3 騒ぐ	に が
#       3 騒ぐ	が
#       3 騒ぐ
#       3 飲む	て が を
#       3 食える
#       3 飛び込む	か と が
#       3 飛び下りる	から
#       3 顧みる	を
#       3 願う	から を
#       3 願う	へ を
#       3 願う	て
#       3 頼む	て と て
#       3 頬張る	は で に
#       3 頂く	に
#       3 響く	に
#       3 離れる
#       3 隠れる	も
#       3 陥る	て に
#       3 開く	に も を
#       3 開く
#       3 開ける	て を
#       3 開ける	て
#       3 釣る
#       3 醒ます	が を
#       3 違う	じゃ
#       3 違う	は と は
#       3 達する	ば は
#       3 過ぎる	じゃ を
#       3 遊ぶ	など に は
#       3 遊ぶ	て
#       3 遇う	に
#       3 連れる	も て て
#       3 通り抜ける	を
#       3 通す	でも に で
#       3 通す	まで に
#       3 通じる	に は
#       3 這う	て に
#       3 這う	へ
#       3 逃げ出す
#       3 逃げる	て
#       3 送る	に て を
#       3 追う	を て
#       3 追う	を
#       3 迷う	に
#       3 述べる	たり に
#       3 述べる
#       3 返す	て を
#       3 込む	へ は を
#       3 込める	を
#       3 越す	か て に
#       3 買う	と が を が
#       3 貰う	て て ね
#       3 講じる	を
#       3 読む	より を
#       3 読む	でも
#       3 説く	と
#       3 誘い出す	で
#       3 認める	も は
#       3 話す	を て に
#       3 話せる	は
#       3 試みる	て を
#       3 訳す	を
#       3 触れる	を
#       3 覚す	て を
#       3 覚える	と に を
#       3 覗く	から
#       3 覗く	に を
#       3 見渡す	に て を
#       3 見廻す	て と を
#       3 見合せる	を
#       3 見出す	を も
#       3 見る	は から て て
#       3 見せる	まで に は て
#       3 見える	さえ
#       3 見せる	と と は が を
#       3 裏返す	を
#       3 行く	から まで に
#       3 行く	は から を に
#       3 行く	の に ちゃ に
#       3 落ちつく	で
#       3 苦しむ	て か に
#       3 苦しむ	に
#       3 舐める	を
#       3 致す	は て は を
#       3 致す	が を に
#       3 至る	から に
#       3 臨む	に
#       3 脱す	で を
#       3 背く	は
#       3 聴く	から に
#       3 聞く	ながら を
#       3 聞く	たって
#       3 聞く	から も を
#       3 聞く	は かい と
#       3 考え出す
#       3 考える	くらい に
#       3 考える	ながら
#       3 考える	が ながら
#       3 考える	は は と て
#       3 習う	も
#       3 罵る	と に
#       3 繰り返す	が に で で を
#       3 繰り返す	を に
#       3 縛する	に は に
#       3 続く	か と
#       3 結う	を に
#       3 籠る	と へ
#       3 笑う	ながら て
#       3 笑う	ので と
#       3 立つ	まで
#       3 立つ	は に が て て
#       3 突く	を
#       3 積む	が を
#       3 移る	へ
#       3 称す	を
#       3 禿げる
#       3 砕ける
#       3 知る	より に に も
#       3 知る	を か かい
#       3 知れる	から も かも
#       3 知れる	だけ に が かも
#       3 知れる	が ねえ と
#       3 着る	のに を
#       3 着く	が て て に
#       3 着ける	に を
#       3 相成る	と も
#       3 盗む	て を
#       3 登る	に
#       3 疲れる	と
#       3 疑う	ば に
#       3 疑る	も
#       3 略す	を
#       3 留まる	と
#       3 申し込む	と
#       3 申す	と や が
#       3 煙る	の
#       3 煙る
#       3 焼ける	で
#       3 濡れる	も
#       3 濁る
#       3 滑る
#       3 滅する	て
#       3 渡る	を と が
#       3 渡る	を
#       3 済す	て て
#       3 済ます	に
#       3 添える	も を
#       3 流行る	ね
#       3 流れる	に は が
#       3 流れる	が
#       3 洩らす	と は を に
#       3 注す	と を
#       3 気がつく	と も
#       3 気がつく	と
#       3 殺す	て と
#       3 死ぬ	ずつ
#       3 欠ける
#       3 構う	は て て も
#       3 棄てる	を
#       3 来る	と も でも に て
#       3 来る	は は て じゃ か
#       3 やって来る	て
#       3 書く	て に を て
#       3 曲がる	の
#       3 断わる	を
#       3 断わる
#       3 敷く	へ を
#       3 敷く
#       3 敲く	は を
#       3 散らす	を
#       3 攫む	が を
#       3 撫でる	を
#       3 握る	て を
#       3 推す	て
#       3 控える	て へ て
#       3 探す	で
#       3 掛る	て に
#       3 捻る	て に を
#       3 捻る	を
#       3 捲く	の
#       3 据える	と を
#       3 捕る	ば を
#       3 振る	わ て も を
#       3 持ち上がる	か
#       3 持つ	から を
#       3 持つ	て のう は て
#       3 持つ	に を まで
#       3 拭く	を
#       3 括る	を へ
#       3 押す	よ と を
#       3 抱く	を に
#       3 抜ける	は て て
#       3 抛る
#       3 折る	わ と を
#       3 折れる	さえ の
#       3 払う	て を
#       3 払う
#       3 戻る	が は
#       3 感ずる	ので に
#       3 感ずる	が と の に
#       3 愛する	を
#       3 惹く	を
#       3 惚れる	に
#       3 悟る	て を
#       3 恐れ入る	に は て ば
#       3 恐れ入る	は
#       3 恐る
#       3 恐れる	を
#       3 思い切る	と
#       3 思い出す	ね と に を
#       3 思い出す	で
#       3 思い出す
#       3 思う	だけ は て も と
#       3 思う	を くらい に
#       3 忘れる
#       3 心得る	が て に
#       3 得る	が から を さ
#       3 得る	ば は と を
#       3 役に立つ	に
#       3 弾く	に を
#       3 張る	と を さ
#       3 張る
#       3 弱る	て
#       3 引き返す	て
#       3 引き受ける	は を で
#       3 引き受ける	を
#       3 廻る
#       3 帰る	から
#       3 帰る	で から
#       3 帯びる	で が を
#       3 差支える	で
#       3 差し支える	と も
#       3 崩す	ば を
#       3 尽す	は も
#       3 就く	に
#       3 する	は に対して を て
#       3 寝つく	は と
#       3 寄る
#       3 寄せる	を
#       3 威張る	ちゃ
#       3 威張る	と
#       3 始める	で も を に
#       3 好く	か に
#       3 奏す	を
#       3 失う	は を
#       3 変る	も て な
#       3 売る	て で
#       3 垂らす	を へ
#       3 垂らす	を
#       3 図る
#       3 困る	の に て
#       3 噛む	を で
#       3 問う	か ね と
#       3 問い
#       3 呼ぶ	で を と
#       3 呼びつける	に
#       3 呑む	が を
#       3 呑む	を
#       3 告げる	も で を
#       3 吹き出す	が と
#       3 吹く	から を
#       3 向う	だけ に
#       3 向ける	に を
#       3 吐く	を
#       3 合う	から に
#       3 召し上がる	が を
#       3 受ける	でも を
#       3 受ける	て も を
#       3 取り合う	に は
#       3 取り上げる	て を
#       3 取る	て だけ
#       3 収める	を に
#       3 去る	と も
#       3 勤まる	て て
#       3 勝る	に
#       3 務まる	て が
#       3 動く	まで
#       3 動く	と が に て
#       3 動じる	は
#       3 加える	て を
#       3 剥ぐ	を
#       3 利かす	の で を
#       3 切る	が と は を
#       3 切れる	で
#       3 分つ	じゃ か は
#       3 分かる	が
#       3 出逢う	て
#       3 出来る	なんか は
#       3 出来る	は に から が
#       3 出す	が に でも を
#       3 凝る	に
#       3 兼ねる	も て
#       3 入れる	で は て へ
#       3 入れる
#       3 働く	に
#       3 傾ける	と
#       3 借りる
#       3 信じる	が に
#       3 保つ	て を
#       3 使える	で で に
#       3 余す
#       3 住む	に で
#       3 住む
#       3 似る	が に て
#       3 伺う	て を
#       3 休む	に
#       3 休む
#       3 代る
#       3 云う	は ながら な と
#       3 云う	を なんて
#       3 云う	と は ばかり
#       3 云う	ば て は とか
#       3 乗り込む	へ
#       3 丸める	を
#       3 並べる	へ を
#       3 並べる	を
#       3 与える	に け を
#       3 下りる	に は て へ
#       3 ぶら下がる	が と へ て
#       3 ぶら下がる	は て
#       3 上げる	から に
#       3 上げる	でも
#       3 す	と は に を に
#       3 なる	やいなや が に て ね
#       3 ある	だって にゃ が ぜ
#       3 れる	だって に は に て さ
#       3 おく	から ながら を て
#       3 いむ	から だって
#       3 する	とも まで は と て ば
#       3 いる	から と くらい て
#       3 なる	が にとって は に も
#       3 する	は ながら の を に て
#       3 いる	で くらい に が て
#       3 ある	に にゃ が から ね
#       3 する	と は によって の を
#       3 する	は か について に
#       3 する	に は をもって
#       3 いう	か は でも じゃ か
#       3 する	て は まで は で て かも
#       3 する	と に て ばかり さ
#       3 なる	も さ ね が とか を
#       3 たまる	けれども て は
#       3 なれる	だって が に は
#       3 られる	まで から を
#       3 つまる	て ばかり て も
#       3 くべる	て って と と は て に
#       3 られる	を て くらい
#       3 くべる	て も は と と も に
#       3 やられる	が ねえ と に
#       3 ほのめかす	で と は を
#       2 鳴く	ばかり
#       2 鳴る	は で が と
#       2 鳴らす	の よ と
#       2 鳴らす
#       2 驚く	は て て
#       2 驚かす	て
#       2 首
#       2 飾る	を へ
#       2 飲む	ばかり
#       2 飲む	て でも
#       2 飲む	て に で ね
#       2 食う	が から は
#       2 食える	でも
#       2 飛び降りる	から
#       2 飛び込む	に でも
#       2 飛び込む	で へ
#       2 飛び出す	が から
#       2 飛び出す	は と が から
#       2 飛び出す	は て へ
#       2 飛び出す
#       2 飛び下りる	は て
#       2 飛び下りる	に
#       2 飛び上がる	から に
#       2 飛ぶ	から が
#       2 飛ぶ	は て を が に
#       2 顧みる	と は を
#       2 願う	が ので を
#       2 願う	て も へ を
#       2 願う	が は を
#       2 頼む	から
#       2 頼む	て と
#       2 預る	で に
#       2 響く	から に
#       2 離す	に
#       2 集まる
#       2 隠れる	へ て
#       2 障る	に に
#       2 障る
#       2 陣取る	が に
#       2 限る	は を って に
#       2 間違う	と て
#       2 間違う	よ
#       2 間に合う	って
#       2 間に合う	と
#       2 開く	て ね と は に を
#       2 開く	が か は を て
#       2 開く	で も で を
#       2 釣り合う	て も
#       2 釣る	は で へ
#       2 釣れる	が
#       2 重んじる	に を
#       2 避ける
#       2 適す	に
#       2 違う
#       2 達す	が て に さ
#       2 達す	に
#       2 達する	ば は に
#       2 達する	の
#       2 過す	を
#       2 過ぎる	か と は て は
#       2 遊ぶ	は でも に
#       2 遊ぶ	て で
#       2 進む	だけ
#       2 進む	て ばかり
#       2 進める	から を
#       2 進める	て より は も
#       2 連れ出す	は に
#       2 連れる	て へ で も
#       2 連れる
#       2 逢う	にゃ よ
#       2 造る	さ を
#       2 通り過ぎる	へ
#       2 通り掛る	を
#       2 通り抜ける	に を
#       2 通う	に まで へ
#       2 通る	け て て を
#       2 通す	の に を
#       2 這入る	なぞ は も へ
#       2 這入る	だり へ
#       2 這う	は て へ
#       2 透す	を
#       2 送る	が に か ば
#       2 追う	が でも に
#       2 迷う	が に
#       2 述べる	から
#       2 述べる	で と は を て
#       2 そり返る	が
#       2 近寄る
#       2 近付く	が へ
#       2 近づく	の
#       2 込む	から が
#       2 込む	から
#       2 込む	は に て へ け
#       2 込める	を に
#       2 やり込める	と に
#       2 もぐり込む	へ
#       2 載せる	を へ
#       2 載せる	に
#       2 較べる	に
#       2 転がる	が と に は て て
#       2 転ずる	は て は を
#       2 転がる
#       2 蹴る	を
#       2 踏み込む	も
#       2 踏む	が を
#       2 踏む
#       2 踊る	て を
#       2 足る
#       2 足りる	に か
#       2 足りる
#       2 越える	を
#       2 起き直る
#       2 起つ	ながら に
#       2 起す	て から
#       2 起す	と も を から
#       2 起す	て が に を
#       2 起きる	のに
#       2 起きる	て も
#       2 貼る	に
#       2 費やす	に を
#       2 買う	て から
#       2 貰う	ちゃ か
#       2 貰う	より
#       2 貰う	は から さ
#       2 貰う	を から
#       2 貰う	で も が ば が
#       2 貫く	に て を
#       2 貪る
#       2 負ける	て も
#       2 譲る	は において は も
#       2 譲る	を に
#       2 講じる	て を
#       2 諦める	と ば
#       2 論じる	て
#       2 調べる
#       2 読み出す	は て を
#       2 読む	から に て で
#       2 読める	は が
#       2 読める
#       2 説く	に を
#       2 誘う	て を
#       2 誓う
#       2 認める	と は と
#       2 誇る	て
#       2 誂える	に を
#       2 誂える
#       2 話す	から と
#       2 話す	て で か て
#       2 話せる
#       2 試みる
#       2 評す	が を
#       2 証拠立てる	を
#       2 訳す
#       2 計る	て は か も
#       2 言う	ものの
#       2 言う	から と
#       2 言う	から
#       2 解す	は に は
#       2 解す	に を
#       2 解す
#       2 解せる	を
#       2 観る	を
#       2 視る	て
#       2 見計らう	に
#       2 見立てる	に
#       2 見廻す	か な と を
#       2 見受ける	に は
#       2 見付ける	て が
#       2 見上げる
#       2 見る	ながら は を
#       2 見る	から じゃ
#       2 見る	に ながら を
#       2 見る	て ばかり
#       2 見る	て か と ばかり て
#       2 見える	について と
#       2 見える	て から は て
#       2 見つめる	のみ を
#       2 見つめる	は て に て
#       2 見つめる	が を て
#       2 要する	は に と を
#       2 要する	は を
#       2 褒める	を
#       2 装う	と を
#       2 被る	て を
#       2 表する	と は て を
#       2 表する	に を
#       2 表する	を
#       2 衝く	を
#       2 行く	たって で は
#       2 行く	から くらい へ
#       2 行く	な ながら
#       2 行く	て は から に も
#       2 行く	て が まで
#       2 行く	け ば は かも
#       2 行う	か ね が へ で も
#       2 行ける	は へ で も に
#       2 蒙る	でも で
#       2 落ちる	から で も
#       2 落ちる	から
#       2 落ちる	て て か て
#       2 苦しむ	が で
#       2 舞う	に が
#       2 致す	など を
#       2 腐る	の
#       2 能う	ば を
#       2 肥る	か
#       2 肥る
#       2 聴く	て て よ
#       2 聞く	て かい と が
#       2 聞く	は で から て
#       2 聞こえる	が
#       2 聞きつける	を
#       2 考え込む	と は
#       2 考え直す
#       2 考え出す	が て と と
#       2 考え出す	を も
#       2 考える	まで も と
#       2 罵る	を
#       2 置く	として は を
#       2 置く	に は が に て
#       2 纏める	や て
#       2 繋ぐ	を
#       2 縮まる	て は が
#       2 縮める
#       2 練る	て を
#       2 綻びる	の
#       2 続く	で も は
#       2 続ける	て て を
#       2 続ける	の
#       2 給う	よ て て
#       2 絞る	を
#       2 絞る
#       2 終る	は で
#       2 納める	へ
#       2 糺す	を
#       2 籠る	は の へ
#       2 答える	ので と は と
#       2 答える	から は と
#       2 答える	とも と
#       2 答える	で も でも を
#       2 答える	よ と は ながら
#       2 答える	て さ と は に
#       2 笑う	が ので て
#       2 端折る	の
#       2 立つ	て が に は て て
#       2 立てる	は まで も を て
#       2 窺う	て は を
#       2 窮する	と に
#       2 突っ込む	を
#       2 突く
#       2 穿く	て て を
#       2 穿つ
#       2 究める	を
#       2 称する	など と
#       2 称する	に と
#       2 禿げる	から
#       2 禿げる	は で て
#       2 禁じる	は を
#       2 禁ずる	を
#       2 祝す	が を
#       2 示す	ば に を
#       2 磨る	ばかり
#       2 磨く	も で を
#       2 破る	よ と が を
#       2 破る	と が に
#       2 破れる
#       2 知る	から ね と は を
#       2 知る	は から
#       2 知る	よ は も て が ね
#       2 知れる	から て て に て かも
#       2 知れる	ので も
#       2 知れる	と から と かも
#       2 知れる	に まで も の
#       2 知れる	で は より が かも
#       2 知れる	で へ を て かも
#       2 知れる	も て は の
#       2 知らせる	を
#       2 睨む	に
#       2 睨める
#       2 着る	でも
#       2 着く	と は て が へ
#       2 着せる	に
#       2 眺める	は から を
#       2 眺める	て を
#       2 真似る	を
#       2 直す	が も
#       2 目立つ	と
#       2 目ざす
#       2 盗る
#       2 登る	まで
#       2 異なる	が
#       2 留める
#       2 画く	が
#       2 申す	から を と
#       2 用いる	は が に
#       2 生える	でも に が
#       2 生じる	て が に は も
#       2 生じる	と で は も
#       2 甘んじる	も
#       2 現われる	に が
#       2 片づく
#       2 片づける	が
#       2 爛れる	に
#       2 煮る	て て
#       2 煩わす	を
#       2 照らす	に が に
#       2 焼く	に を
#       2 焦る	と
#       2 焦れる
#       2 為す	が
#       2 澄ます	は て
#       2 澄ます	で
#       2 潰す	が を
#       2 潰せる	な で は
#       2 潰れる
#       2 演ずる	を
#       2 溺れる	て
#       2 溶かす	を
#       2 溯る	より に
#       2 溜る	が
#       2 溜める	て
#       2 渡す	から と を に
#       2 減る	は が
#       2 済む	から で
#       2 消える	を って
#       2 消える	も の に
#       2 消える	は に
#       2 消える	ば
#       2 消える
#       2 浸る	の
#       2 浴びる	で を
#       2 浮ぶ	で に
#       2 浮く
#       2 浮かぶ	も
#       2 浮かれる	のみ
#       2 流す
#       2 流れる	が に
#       2 活ける	に
#       2 洩る	の
#       2 洩る
#       2 洩れる
#       2 注する
#       2 決める	と
#       2 汚す	を
#       2 求める	を
#       2 気取る	を
#       2 気に入る	が も
#       2 気に入る
#       2 気が付く	ので と
#       2 気が付く	にゃ
#       2 気が付く	で は と
#       2 残る	でも て
#       2 死ぬ	ので て
#       2 死す	は て に
#       2 歩く	を
#       2 欺く	を
#       2 欠く	に が
#       2 欠く	に
#       2 欠ける	に の
#       2 構う	など は でも
#       2 構う	で も から
#       2 極め込む	て を
#       2 極める	て と で に
#       2 極まる
#       2 棄てる	を で
#       2 果す	を
#       2 果せる
#       2 来る	くらい と が
#       2 来る	ので て を って へ
#       2 来る	じゃ か と は に て
#       2 来る	から て て で の
#       2 来る	に が ながら て
#       2 来たす	が て て
#       2 来たす	て て
#       2 期す	を
#       2 有す	は に を て
#       2 有する	へ を
#       2 有する	を
#       2 書く	なんか
#       2 曲る	から へ
#       2 曝す
#       2 暮す	から と は に
#       2 暮す	と に て ば
#       2 暮す	で
#       2 映じる	に
#       2 明く	の
#       2 明ける	が
#       2 断る	に
#       2 斬る	を
#       2 敲く	は て を
#       2 敲く	を
#       2 放り込む	が へ
#       2 放つ	で の を て
#       2 放つ	が を
#       2 改める	は を
#       2 攫む
#       2 擦り付ける	を へ
#       2 擦る	を
#       2 撚る	を
#       2 携える	を
#       2 揺れる	が
#       2 換える	のに を
#       2 換える	て で も
#       2 提げる	を
#       2 揉む	て
#       2 掻く	な と を
#       2 接す	に も
#       2 探る
#       2 掛る	が は か に
#       2 掛る	よ に が
#       2 掛ける	で で は に を
#       2 掛ける
#       2 捻る	て を
#       2 据える	は に が て
#       2 捧ぐ	に
#       2 捕える
#       2 捉える	を
#       2 振り返る	を
#       2 振い落す	て を
#       2 振り立てる	を
#       2 振り向く	か を
#       2 振り向く
#       2 振り上げる
#       2 挟む	に を で
#       2 挙げる	の を
#       2 指す	を
#       2 持ち出す	が を に
#       2 持つ	ばかり
#       2 持つ	まで が を
#       2 持つ	は にて を
#       2 持つ	て まで
#       2 持てる
#       2 拾う	で を
#       2 拭く	よ と で を
#       2 押し出す	を
#       2 押す	ちゃ よ と を
#       2 押す	ね と が を
#       2 押す	を
#       2 押しかける	が
#       2 抱える	を
#       2 択ぶ	ば は を
#       2 択ぶ	か を
#       2 択ぶ	と
#       2 抜く
#       2 抜ける	て から
#       2 抜ける
#       2 抛り出す	は や で へ
#       2 抛り出す	を
#       2 抛る	が て に
#       2 折れる	で も が
#       2 投げ込む	は て へ
#       2 投げ出す
#       2 投ずる	に
#       2 承る
#       2 払う	て て と
#       2 打つ	から
#       2 打つ	が に を
#       2 手伝う	に が
#       2 戻る	に
#       2 懸ける	に を に
#       2 懲りる	に
#       2 懲らしめる
#       2 憤る	を
#       2 感ずる	ながら が
#       2 感じる	じゃ か と
#       2 感じる	が て ので を
#       2 感じる
#       2 惚れる	から
#       2 惚れる	が に
#       2 悟る	のに も
#       2 恐れ入る	が で も
#       2 恐る	と に
#       2 恐れる
#       2 急き込む	と
#       2 急ぐ
#       2 思い立つ
#       2 思う	くらい と も
#       2 思う	から
#       2 思う	と くらい
#       2 思う	が ので と も
#       2 思う	と のに
#       2 思う	て と しか
#       2 思う	て と は ほど と
#       2 思いつく	まで を
#       2 怒る	でも
#       2 怒る	ば が ば
#       2 応える	ば に
#       2 忘れる	から
#       2 忘れる	が から て
#       2 忘れる	よ と は は て
#       2 忍び込む	へ は
#       2 忍び込む	へ
#       2 忍ぶ
#       2 心得る	は でも て が
#       2 心得る
#       2 心付く	て が と
#       2 心付く	も
#       2 得る	から ながら を て
#       2 得る	でも は と を
#       2 得る	から が を
#       2 得る	から
#       2 得る	か と は に に を
#       2 従う	と に
#       2 する	に従って は て
#       2 いる	に従って を
#       2 なる	に従って
#       2 後れる
#       2 律する	を以て を
#       2 待ち構える	で て
#       2 待ち構える	と
#       2 待つ	から で に
#       2 待つ	て から
#       2 待ちかねる	が
#       2 彫る	を へ
#       2 当る	て て よ
#       2 当る
#       2 張る	から
#       2 張れる	て
#       2 弱る	は て も
#       2 弱る	は は
#       2 引き揚げる
#       2 引張る	って を
#       2 引張る	と は て を
#       2 引き取る	と ば を
#       2 引き下がる	て へ と
#       2 引く	より が に を
#       2 引く	を でも ね
#       2 引く	が と だけ へ を
#       2 引きずる	が を
#       2 引きずる	て
#       2 弄する	が を
#       2 弁じる	は て を
#       2 廻る	ので で
#       2 廻る	よ と が を の の
#       2 延びる
#       2 帰る	から て に
#       2 帰る	は から て へ
#       2 巻く	へ
#       2 差支える	から
#       2 差支える	て も
#       2 差し出す
#       2 崩れる	で の
#       2 崩れる	の
#       2 崩れる
#       2 属す	は は に
#       2 属する	は に
#       2 届く	の
#       2 居る	に
#       2 尽きる
#       2 尋ねる	が に を
#       2 寝る	など は で
#       2 寝る	から か
#       2 寝る	て なり て
#       2 寝る	に たり
#       2 寝る	て は で て
#       2 寝ぼける	が
#       2 寄る	で へ
#       2 寄れる	は か
#       2 寄りつく
#       2 守る	を
#       2 嫌う	を
#       2 威張る	て ぜ
#       2 始める	ながら て
#       2 始める	から
#       2 奪う	を
#       2 奢る	で も
#       2 奏す	て を
#       2 奉る	を
#       2 失せる	て ぞ
#       2 変ずる	て を
#       2 変える	を
#       2 売る	て を で
#       2 塗る	を を で
#       2 堪える	を に
#       2 埋る	て に さ
#       2 埋める	て は を
#       2 坐る	か と は て て へ
#       2 坐る
#       2 在る	が に
#       2 圧す	に は
#       2 困る	は て も て て
#       2 噛む	から
#       2 噛む	ば
#       2 嘲る
#       2 嘆ずる	を
#       2 喜ぶ	て で
#       2 喜ぶ	の
#       2 問う	て
#       2 問いかける	て と に
#       2 唸る	ぜ に で で て
#       2 唸る	て
#       2 命じる	に か を
#       2 呼ぶ	から を
#       2 呼ぶ	と で よ と
#       2 呑み込む	て て を
#       2 吹き出す	は
#       2 吸う	の に
#       2 吸う	に
#       2 吠える	て に
#       2 向き直る	と は
#       2 向う	て として に
#       2 向く	ぜ と が を
#       2 向ける	から へ
#       2 向ける	は に を
#       2 吐く
#       2 名乗る	と
#       2 名づける	を と
#       2 名づける	を
#       2 合わせる	と を
#       2 号する	など と
#       2 号する	を と
#       2 叶う	に
#       2 叱りつける
#       2 叫ぶ	と
#       2 叩く
#       2 叩きつける	で へ
#       2 受け取る	を に
#       2 受ける	が まで を
#       2 取り掛る	て に
#       2 取り払う
#       2 取り合う	て
#       2 取り出す	から を
#       2 取る	さえ に
#       2 取れる	が
#       2 取りかかる	て は に
#       2 取りはずす	に を
#       2 及ぶ	は て に は よ
#       2 及ぶ	と て を に
#       2 及ぶ	の
#       2 及ぼす	に を
#       2 及ぼす	に
#       2 参る	だけ
#       2 参る	は に が
#       2 去る	は か と
#       2 占める	に を
#       2 包む	て で
#       2 勧める	から
#       2 勧める
#       2 勤める	に を て
#       2 勝つ	が に は
#       2 動じる	と て よ と は
#       2 動かす
#       2 助かる
#       2 加える	ので を
#       2 加える	て な と が を
#       2 加える	ね と が を
#       2 加わる	は に が
#       2 力む	と
#       2 割り出す	から
#       2 剥げる	は
#       2 削る	を
#       2 刺す	を へ
#       2 利く	から と は
#       2 利く	って
#       2 刈る	の
#       2 切る	にゃ は
#       2 切る	で は から
#       2 切る	に と を て よ
#       2 切れる	と が が
#       2 分ける	て を に で
#       2 分ける
#       2 出直す	て
#       2 出直す
#       2 出来る	だって に は
#       2 出来る	から まで に が
#       2 出来る	て さえ と は が
#       2 出来る	で ば から ばかり ば
#       2 出来る	に は と で も
#       2 出掛ける	ので に に
#       2 出掛ける	まで
#       2 出掛ける	で と へ
#       2 出掛ける
#       2 出る	ながら と へ
#       2 出る	から から て
#       2 出る	さえ から
#       2 出る	ので て を って へ
#       2 出す	ので に か へ を ね
#       2 出す	から ね と が を
#       2 出る	は から で に に
#       2 出す	か と ばかり は を
#       2 出す	は て でも でも で
#       2 出す	に は から に が て ね
#       2 出す	に は て ながら が
#       2 出る	て と て から が
#       2 出す	な と て ぞ の に へ
#       2 出る	と に が へ に て
#       2 むき出す	を
#       2 凹ます	と を
#       2 処する	に
#       2 冷かす	が と
#       2 冷める
#       2 冷やかす	を
#       2 写る	と に て
#       2 具える	て は を
#       2 する	は て が と共に が に て
#       2 入れる	かい と が を
#       2 入れる	など へ
#       2 入れる	て へ を ずつ
#       2 光る	と の に て
#       2 光る	の に と
#       2 光る	ば て
#       2 充ちる	に
#       2 働く	が に
#       2 傾く	に が
#       2 候う	に は
#       2 候う
#       2 係る	は に
#       2 依る
#       2 使う	じゃ よ
#       2 使う	に しか
#       2 使える	て は
#       2 作る	って
#       2 作る	は が に
#       2 作る
#       2 何だ
#       2 佇む	で
#       2 伸す	を
#       2 伝う	て を
#       2 伝わる	を
#       2 伏せる	の
#       2 企てる	と
#       2 仰ぐ	を
#       2 代える
#       2 付ける	から
#       2 付ける	て と へ を て
#       2 仕る	に を
#       2 交ぜ返す	ね と
#       2 交ぜる	ば と て を
#       2 云う	ながら から と
#       2 云う	ながら て を て
#       2 云う	ばかり さ と
#       2 云う	って から
#       2 云う	から が て と さ
#       2 云う	と は ものの に
#       2 乱す	に を
#       2 乱れる	で が
#       2 乞う	て か も
#       2 乗り込む	が へ
#       2 乗せる	を へ
#       2 中る
#       2 並ぶ	は に
#       2 並べる	が か と を
#       2 並べる	が と を
#       2 与る	を に
#       2 与える	は て に を
#       2 下る
#       2 下げる	から か を
#       2 下りる	から
#       2 ぶら下げる	て を で
#       2 上る	から に が
#       2 上がる	が から
#       2 上がる	て て も も が
#       2 上がる	て が し て
#       2 「	か にゃ
#       2 す	に て も だけ は て
#       2 やる	けれども と て んで て
#       2 いる	やいなや か か を
#       2 いる	だって ばかり て じゃ か
#       2 する	なんて だって は や
#       2 する	ばかり は として を て
#       2 かう	なんて を じゃ か
#       2 する	けれど で と は を に て
#       2 だす	のみ において を
#       2 する	から ばかり じゃ も か で
#       2 する	から くらい の に て
#       2 する	たり たり たり たり て て
#       2 れる	から から は とか よ
#       2 なる	のに なあ と を に
#       2 がる	じゃ か なんか て も て も
#       2 する	じゃ ね ものの が て さ
#       2 する	から て だって
#       2 する	から と たり から たり て
#       2 なる	って て じゃ か で が に よ
#       2 する	ので が から は て に て
#       2 する	んで と から と に て
#       2 する	たり と は など を
#       2 いる	なあ ば に は に って
#       2 いる	は において に に
#       2 いる	と ながら として に で
#       2 ある	が だって くらい は
#       2 する	は として に を つつ
#       2 する	ん から ながら に て
#       2 する	け たり に として て は か
#       2 する	ば こそ が として て も
#       2 やる	は から は なんか も
#       2 いる	て かも が でも まで で
#       2 する	て から て から は を て
#       2 おる	が など は て にあたって
#       2 する	て のに は て ばかり に
#       2 れる	て から は も と かも
#       2 する	と は にあたって て て
#       2 ふる	に と ばかり ながら に
#       2 する	は で ばかり て から
#       2 する	と に ばかり て は から ね
#       2 いる	が と やら ながら に て
#       2 する	て も から か から な
#       2 する	て が から は て は に つつ
#       2 ある	て も に だって じゃ か
#       2 いる	よ が ね かしら に が
#       2 する	な と は たり たり て
#       2 とる	が に は て を ばかり よ
#       2 かかる	じゃ くらい
#       2 かえる	から に を だけ
#       2 かかる	と くらい
#       2 しまう	が て といった へ て
#       2 しまう	が と として に て
#       2 ござる	に と は さえ ば は
#       2 しかめる	ちゃあ と を
#       2 ざんする	は でも
#       2 からかう	ば は から
#       2 かさねる	て と に が の て
#       2 おっしゃる	ばかり
#       2 なりすます	は まで も に
#       2 しめつける	て から を
#       2 かきつける	て は て に を
#       1 鼓する	が に を
#       1 黙過	が
#       1 黙る	ながら から
#       1 黙る	から と は と んで から て
#       1 黙る	ので て て
#       1 黙る	から
#       1 黙る	か に て
#       1 鳴る	として が で
#       1 鳴る	ほど
#       1 鳴く	に ばかり
#       1 鳴る	を て
#       1 鳴らす	たり と は など を
#       1 鳴らす	は に を て
#       1 鳴らす	て を
#       1 鳴かせる
#       1 魅入る	として に
#       1 魂消る	て と
#       1 魂消る	て
#       1 驚く	ながら
#       1 驚く	まで が に は も
#       1 驚く	から
#       1 驚く	ば など は から
#       1 驚く	で って
#       1 驚く	か と は に に を
#       1 驚く	が て は を よ
#       1 驚く	て よ へ は
#       1 驚かす	て で に
#       1 騰る
#       1 騒ぎ立てる	さ など は が
#       1 騒ぎ立てる	て と ずつ
#       1 騒ぎ立てる	は て と て
#       1 騒ぎ立てる	と は で
#       1 騒ぎ立てる	て
#       1 騒ぎ立てる
#       1 騒ぎ出す	で
#       1 騒ぐ	とか て で
#       1 騒ぐ	は など と
#       1 騒ぐ	て で だって
#       1 騒ぐ	に て が から で で と さ
#       1 騒ぐ	て を で
#       1 駆る	より に て
#       1 駆る	に も が に
#       1 馴れる	が は て
#       1 馴らす	を に
#       1 馬鹿
#       1 養う	て を
#       1 養う	を
#       1 飾り付ける	に
#       1 飾り付ける
#       1 飾る	に に を
#       1 飽き飽きする	も
#       1 飽く
#       1 飼う	か を
#       1 飼う	へ
#       1 飲み込む	て から を
#       1 飲み込む	て を
#       1 飲み込む	て
#       1 飲み込む
#       1 飲み込める
#       1 飲み干す	ながら を に
#       1 飲み干す	て を
#       1 飲み干す	を
#       1 飲み下す	を
#       1 飲む	から から て も
#       1 飲む	と は ながら を
#       1 飲む	と は から
#       1 飲む	て て は で に で さ
#       1 飲める	だって て を
#       1 飲める	と と は て が に よ
#       1 飲める	は よ
#       1 飲める	を
#       1 食い込む	は のみ に まで で
#       1 食い込む	に て を ばかり
#       1 食い込む	へ
#       1 食い切る	は で で
#       1 食い切る	の
#       1 食い切る
#       1 食み出す	ほど に から
#       1 食み出す	が から て
#       1 食み出す	が まで
#       1 食み出す	が て まで
#       1 食う	くらい て
#       1 食う	ばかり
#       1 食う	から に が
#       1 食う	まで
#       1 食う	も けれども を
#       1 食う	で でも ちゃあ
#       1 食う	で から て に て て
#       1 食う	が で ばかり
#       1 食う	に て から として て
#       1 食う	て が から で も と ほど で て
#       1 食う	て ね を たって
#       1 食う	は に を ずつ
#       1 食う	に に を な まで
#       1 食う	て に は が て を て
#       1 食う	て と は て を て
#       1 食べる	から で て を
#       1 食べる	から に も
#       1 食わす	て から で も
#       1 食える	は って も
#       1 食わす	に と を から
#       1 食わせる	から に て に を
#       1 食わせる	ちゃ に を
#       1 食いつく	より ね
#       1 食わせる	て から
#       1 食わせる	て ば と は を
#       1 食わせる	よ と は を
#       1 食わせる	に を
#       1 食わせる
#       1 飛び離れる
#       1 飛込む	て から と で
#       1 飛込む	に が に
#       1 飛び込む	から ので て で へ
#       1 飛び込む	から に は へ と
#       1 飛び込む	て から かも
#       1 飛び込む	も のに で へ で
#       1 飛び込める	の へ
#       1 飛び越える	を ばかり に
#       1 飛び越える
#       1 飛出る	から から
#       1 飛び出す	でも から て
#       1 飛び出す	から の
#       1 飛び出す	ば だって は
#       1 飛び出す	て から から から に
#       1 飛び出す	は て から て
#       1 飛び出す	と は て から て
#       1 飛び出す	と が に て に
#       1 飛び出す	と て で て
#       1 飛び出す	が に
#       1 飛び下りる	から から
#       1 飛び下りる	は て から を が
#       1 飛び下りる	て て から
#       1 飛び下りる	て で と を
#       1 飛び上がる	は て ばかり に と
#       1 飛び上がる	と に て
#       1 飛び上がる	て て
#       1 飛び上がる	で
#       1 飛び上がる
#       1 飛ぶ	やら へ で
#       1 飛ぶ	は は も で
#       1 飛ぶ	て へ が
#       1 飛ばす	へ を
#       1 飛ばす
#       1 飛びつく	から に に
#       1 飛びつく	は と へ て
#       1 飛びつく
#       1 顧みる	は として
#       1 顧みる	わ ねえ と を
#       1 顧みる	と は ながら を
#       1 顧みる	の て として
#       1 顧みる	て と は を
#       1 顧みる	と を
#       1 顧みる
#       1 願う	から に も を って
#       1 願う	から は で を
#       1 願う	って
#       1 願う	か でも
#       1 願う	が て から を
#       1 頼む	じゃ か と から に
#       1 頼む	から か
#       1 頼む	に でも
#       1 頼む	て て か って
#       1 頼む	の が を で
#       1 頬張る	じゃ か と を に
#       1 頬張る	に を
#       1 頑張る	じゃ が と て
#       1 頑張る	て が て
#       1 頑張る	に
#       1 頑固
#       1 頂く	じゃ けども て を て の
#       1 頂く	から で を て
#       1 頂く	に を
#       1 響く	て と が を通して を通して へ
#       1 響く	など と に
#       1 響く	は に へ
#       1 響く	て に
#       1 面す	に
#       1 靡く	に
#       1 静まり返る	まで
#       1 静まり返る	は
#       1 震わせる	を と
#       1 離す	だけ は
#       1 離す	と は て
#       1 離れる	くらい
#       1 離れる	は から を
#       1 離れる	と は で を
#       1 離れる	と は ね
#       1 雇う	なぞ は て に
#       1 雇う	から を
#       1 雇う	て から を
#       1 雇う	が に て
#       1 集う	へ が に て
#       1 集る	の が へ
#       1 集る	が
#       1 集める	より が に を
#       1 集まる	だけ
#       1 集める	も を
#       1 隣る	も て と
#       1 隠す	さえ を て
#       1 隠す	に は て か へ を
#       1 隠す	さ へ で も
#       1 隠す	て も
#       1 隠れる	て を に
#       1 障る	って まで に
#       1 障る	たり が
#       1 障る	に が に
#       1 隔てる	で と を
#       1 隔てる	と を
#       1 陳べる	は で
#       1 陥る	も が に
#       1 陥る	に
#       1 陥る
#       1 陥れる	け たり を
#       1 陥れる	け たり
#       1 陥れる	て を に
#       1 陥れる	て を
#       1 除く	を
#       1 除く
#       1 除ける	は でも
#       1 除ける	か と は
#       1 除ける	て を
#       1 限る	から は か に て
#       1 限る	でも へ は に
#       1 限る	て から は か に さ
#       1 限る	と から ね
#       1 限る	に のみ
#       1 限る	て か と は に
#       1 限る	で が と も
#       1 降り込む	が
#       1 降参
#       1 降る	て か と から
#       1 降る	と に が に て
#       1 降す	に は を へ
#       1 降る	は に
#       1 降りる	どころか へ
#       1 降りる	は から て ば
#       1 降りる	は て
#       1 降らせる	から を に
#       1 附す	を へ に を
#       1 附ける	と か で も
#       1 附ける
#       1 阿る	から
#       1 防ぐ	ば を に
#       1 関す	が に て
#       1 関する	て は に
#       1 関する
#       1 間違う	て ば よ
#       1 間違う
#       1 間違える	まで と を
#       1 間違える	かい と
#       1 間違える	を と
#       1 まかり間違う
#       1 間に合う	から まで に
#       1 間に合う	て て て
#       1 間に合う	と よ
#       1 開き直る	で と
#       1 開け放つ	を
#       1 開け放す
#       1 開く	ので と を へ
#       1 開く	たり を
#       1 開く	で が ながら
#       1 開く	と を とも て
#       1 開ける	なぞ も から
#       1 開ける	から を か に
#       1 開ける	だけ が を
#       1 開ける	でも を
#       1 開ける	は など で は
#       1 開ける	が が から よ
#       1 開ける	へ を に
#       1 こじ開ける	で
#       1 閉じる	が に のみ
#       1 鑑みる	も に
#       1 鍛え上げる	て を
#       1 錬る	に を
#       1 鋳る	に
#       1 釣り込む	と は
#       1 釣り合う	から って から ね
#       1 釣る	て ばかり に
#       1 釣る	で は て も から へ
#       1 釣る	て が し て
#       1 釣れる	は だって から で
#       1 釣れる	か かい
#       1 釣れる	が か
#       1 重ねる	まで は を
#       1 重んずる	は に て
#       1 醸す	ば にて も に を
#       1 醒める
#       1 酬いる	たり たり ばかり に
#       1 酔っ払う	に
#       1 還す	ながら なんて
#       1 還す	を
#       1 避ける	は だけ
#       1 遺す	て を か
#       1 遺す	を
#       1 選ぶ	て の
#       1 選ぶ	を
#       1 遮る	が も を
#       1 適す	に て
#       1 適する	に て に
#       1 遣る	を は
#       1 遣る	も
#       1 遣わす	へ
#       1 遠のく	を
#       1 遠のく
#       1 遠ざかる	て でも に
#       1 違う	んで で も と は が
#       1 違う	から て と は
#       1 違う	まで と は
#       1 違う	から と
#       1 違う	か なあ と は
#       1 違う	て も が から ね
#       1 違う	は と は に が
#       1 達す	は として に
#       1 達す	は に に
#       1 達する	ながら に
#       1 過ぎる	に関して は は が
#       1 過ぎ去る	は
#       1 過ぎる	から って に は
#       1 過ぎる	が として は
#       1 過ぎる	は ので は が から
#       1 過ぎる	は ば は に
#       1 やり過ごす	を に
#       1 運動
#       1 運ぶ	ながら を に
#       1 運ぶ	を に も まで で
#       1 運ぶ	が は へ と を
#       1 運ぶ	は
#       1 運ぶ
#       1 遊ぶ	から も
#       1 遊ぶ	て のに で も の に に
#       1 遊ぶ	が ので は て
#       1 遊ぶ
#       1 遊ばす	じゃ か
#       1 遊ばす
#       1 遅い	て
#       1 遂げる	から は て は に を
#       1 逸す
#       1 逸する	て を
#       1 進行
#       1 進む	のに に で
#       1 進む	まで も
#       1 進む	は の て に で
#       1 進む	て も て
#       1 進む	で が
#       1 進む
#       1 進める	かい かい と が を
#       1 進める	と は で を
#       1 進める
#       1 連続	が
#       1 連れ添う
#       1 連れる	から て
#       1 連れる	て から さえ
#       1 連れる	て まで て
#       1 連れる	は て から を て
#       1 逢う	て を として
#       1 逢える	ば
#       1 造る	とか を
#       1 造る	か も に
#       1 造る
#       1 逝く
#       1 通り過ぎる	として を
#       1 通り過ぎる	て を
#       1 通り過ぎる
#       1 通り越す	を と
#       1 通り越す	を
#       1 通り越す
#       1 通り抜ける
#       1 通う	として に
#       1 通る	のに から を
#       1 通る	じゃ か でも で か ね
#       1 通す	さえ
#       1 通す	て まで に を
#       1 通る	て が で が で も
#       1 通る	は は て も は
#       1 通じる	の など は
#       1 通れる	て って
#       1 通じる	に は が
#       1 通ずる	に
#       1 通じる
#       1 れる	を通じて
#       1 這出る	は て へ
#       1 這い出す	から に と さ
#       1 這い出す	から て
#       1 這い出す	で を
#       1 這い出す
#       1 這入る	により て から へ で も て
#       1 這入る	くらい は か て に は が て
#       1 這入る	ながら へ
#       1 這入る	たって
#       1 這入る	から だけ しか に
#       1 這入る	で より に が
#       1 這入る	て から に
#       1 這入る	が て といった へ て
#       1 這入る	に は から が
#       1 這入る	て と は ながら て
#       1 這入る	な と を て へ
#       1 這う	から が
#       1 這う	から
#       1 這う
#       1 途切れる	が でも
#       1 途切れる
#       1 逐う
#       1 透かす	て に
#       1 透かす	を
#       1 逆立てる	で を て
#       1 逆上せる	を
#       1 逆上せる
#       1 逆らう	が に
#       1 逆らう	に
#       1 逃げ込む	は て て へ
#       1 逃げ惑う	へ のみ
#       1 逃げ延びる	しか
#       1 逃げる	は て へ の て
#       1 送る	から を
#       1 送る	より
#       1 退く	は て ながら へ
#       1 退ける	て
#       1 やって退ける	は を に
#       1 追い込む	て へ
#       1 追い詰める	に
#       1 追払う	を から を
#       1 追払う	で を
#       1 追い廻す	で
#       1 追い出す	が て は で は て
#       1 追い出す
#       1 追付く
#       1 追う	に は ば
#       1 追う
#       1 追いやる	から と は を て
#       1 追いつく	に
#       1 追いかける	ので ながら て
#       1 追っかける	って で
#       1 追っかける	も へ
#       1 迷い込む	へ
#       1 迷う	でも が
#       1 迷う	と は て
#       1 迷わす	は に
#       1 迷わす	に
#       1 述べる	から と を の に
#       1 述べる	は において として から て に
#       1 述べる	が て について を の に
#       1 述べる	て も から て
#       1 述べる	て と は て を て
#       1 返す	ながら を
#       1 返す	として
#       1 返る	にゃ にゃ と
#       1 返る	から も など と
#       1 返る	じゃ か は て
#       1 返る	まで に
#       1 返る	が から に に
#       1 返す	は ちゃ よ
#       1 返す	と は て から を まで
#       1 返る	が ね と は て に
#       1 返る	が は て ね
#       1 まぜ返す	じゃ か と が
#       1 まぜ返す	と を
#       1 あきれ返る	て の
#       1 あきれ返る	も
#       1 ひっくり返る	たり ばかり が と か に
#       1 ひっくり返す	を
#       1 ひっくり返る
#       1 近寄る	と まで が
#       1 近寄る	な と っと で
#       1 近づく	て て
#       1 込む	ながら
#       1 込む	が で は と て を で
#       1 込める
#       1 つけ込む	て は か は か に で
#       1 せき込む
#       1 やり込める	じゃ か と は を
#       1 やり込める	も から
#       1 やり込める	を
#       1 もぐり込む	から から
#       1 もぐり込む	ので へ
#       1 もぐり込む	て から に
#       1 もぐり込む	と て へ
#       1 輝く	は より も て
#       1 輝く	て を に て
#       1 載る	て
#       1 載せる	で も なんか は を に
#       1 載せる	で は で へ て
#       1 載せる	を て へ
#       1 載っける	へ
#       1 較べる	など に
#       1 転げ落ちる	に へ
#       1 転じる	から を
#       1 転がす	て ばかり て から
#       1 転がる	は まで も て
#       1 転じる	か ね と は を
#       1 転がれる	て も
#       1 躍り込む	に
#       1 躍り出る	から ながら て に
#       1 躍る	ながら と を
#       1 躍る	は て で じゃ じゃ を て
#       1 躍る
#       1 蹶る	に
#       1 蹴返す	に が を
#       1 蹴る	だり
#       1 蹴る	て と が ほど
#       1 踞る	て に が
#       1 踞る	は て
#       1 踏み込む	へ を
#       1 踏切る	の
#       1 踏切る
#       1 踏み出せる	て も
#       1 踏み付ける	を
#       1 踏む	じゃ か が を
#       1 踏む	も は は
#       1 踏みつける	を
#       1 踊る	じゃ じゃ が
#       1 踊る	が で を
#       1 踊る
#       1 跳ね返る	と のみ は て は て に
#       1 跳ね返す	を
#       1 跳ねる	て も
#       1 跳ねかす	を
#       1 跳ねのける	において か は を に
#       1 跨ぐ	を へ
#       1 足る	けれども から て も
#       1 足る	から は に
#       1 足る	は て に
#       1 足りる	は だけ は
#       1 越す	ば じゃ か
#       1 越す	に は で を ば
#       1 越す	て へ を に
#       1 越す	が へ
#       1 越す
#       1 越える	から を
#       1 越える
#       1 超す	を
#       1 超える	が を
#       1 起き直る	は て に
#       1 起き上がる
#       1 起る	において
#       1 起す	ながら を と
#       1 起す	とも に まで を
#       1 起す	んで と に は も を
#       1 起る	たり が ね
#       1 起る	ば くらい は に
#       1 起る	に として
#       1 起す	に は なんか
#       1 起る	が て から は が
#       1 起る	ば と から
#       1 起る	に も は に よ
#       1 起こす	から て
#       1 起きる	は だって から て
#       1 起こす	は から
#       1 起きる	て も じゃ か
#       1 走る	は に て に を て と を
#       1 走る	は て を へ
#       1 走る	て に
#       1 走る
#       1 貼る	さえ
#       1 貼る	を で へ
#       1 貼る	へ を
#       1 費やす	に て から を
#       1 費やす	に は は と を ば
#       1 費やす	に は を
#       1 買い込む	を
#       1 買い被る	こそ を
#       1 買い被る	を
#       1 買う	に対して も で を
#       1 買う	から よ て
#       1 買う	から が
#       1 買う	かい
#       1 買う	が ばかり て ね
#       1 買う	で から は て も
#       1 買う	で は のみ で
#       1 買える	に が
#       1 買える	が
#       1 買える
#       1 貰う	から に は と て
#       1 貰う	は て から は を て
#       1 貰う	は に から
#       1 責める	て に に
#       1 責める	て と
#       1 責める	と
#       1 責める
#       1 貪る	に を
#       1 負う	を で
#       1 負ける	に だって
#       1 負ける	て て でも に
#       1 譲る	において は に も
#       1 譲る	に
#       1 譲る
#       1 謹む	と から
#       1 謹む	に に
#       1 謹む
#       1 謡う	て も と
#       1 講じる	に対して を て
#       1 諭す	を
#       1 諦める	と
#       1 論じる	ぜ から
#       1 論ずる
#       1 調子づく	と が の
#       1 調子づく	と が
#       1 調子づく
#       1 調べる	て て
#       1 調べる	の
#       1 誰
#       1 読み直す	から て と て
#       1 読み出す	は に
#       1 読み出す	て
#       1 読む	でも に は を で
#       1 読む	から を で
#       1 読む	が も で で ので
#       1 読む	は と て か
#       1 読みかける
#       1 説く	て が て に に
#       1 説く
#       1 誤る	は て
#       1 誤る
#       1 語る	で も
#       1 語る
#       1 誘う
#       1 誓う	など と は
#       1 認める	まで から を
#       1 認める	など は から において を
#       1 認める	に て や さえ て
#       1 認める	ん の に で に て
#       1 認める	は が て が ね
#       1 誇る	を以て に
#       1 誇る	を て
#       1 誇る
#       1 誂える	に
#       1 話す	に従って は て と
#       1 話す	によって が を
#       1 話す	について の
#       1 話す	たって
#       1 話す	なぞ に でも の に
#       1 話す	は から も
#       1 話す	に は として を ば
#       1 話す	は て だけ
#       1 話す	が に て という
#       1 話す	と が で か で て
#       1 話す	は に も か て
#       1 話せる	の ねえ
#       1 話せる	に も
#       1 話しかける	ながら に
#       1 話しかける	から ね と
#       1 話しかける	て ね と は へ
#       1 話しかける	て に
#       1 詰め込む	が に は は が で
#       1 詰め込む	て に
#       1 詰る	って じゃ か
#       1 詰る	ちゃ
#       1 詰る
#       1 詰める	を
#       1 詰まる
#       1 詫び入る
#       1 詫びる	て を
#       1 詫びる	と
#       1 試す	か を
#       1 試す
#       1 試みる	は から くらい しか
#       1 試みる	よ と が を
#       1 試みる	て て を
#       1 試みる	は
#       1 詣る
#       1 詠む	て も を
#       1 評す	と に て も
#       1 評す	て ば と
#       1 評す
#       1 評する	は を とか
#       1 評する	て を と
#       1 証拠立てる	は によって
#       1 証す	て を
#       1 訴える	と に ので て は を て
#       1 訴える	か が に
#       1 訴える	て に
#       1 訴える
#       1 訳す	から
#       1 訳す	は でも
#       1 訳す	て て
#       1 許す	から だけ て
#       1 許す	に を
#       1 設ける	を
#       1 訪う	を
#       1 記す	ので を は
#       1 記す	に は が
#       1 討つ	を で
#       1 計る	から て さえ ば も
#       1 計る	から を
#       1 計る	は も
#       1 計る
#       1 言い触らす	を
#       1 言い放つ	と は に
#       1 言い放つ	を に
#       1 言い兼ねる	と も
#       1 言い付ける	が
#       1 言う	て って っけ
#       1 言う	を に まで
#       1 言う	て は か な と を
#       1 言う	て は は を て
#       1 言う	て よ と を
#       1 言う	と を て
#       1 言いつける	が のみ か を
#       1 言いつける
#       1 触る	と が に
#       1 触れる	ばかり に を
#       1 解す	など は を
#       1 解す	ほど
#       1 解する	の は を
#       1 角張る
#       1 観る	も を
#       1 覚る	と
#       1 覚る
#       1 覚える	なんか が
#       1 覚える	まで は
#       1 覚ます	が に から を
#       1 覚える	て ね ね と は
#       1 覚える	ぜ は て わ
#       1 覗く	を から
#       1 覗く	が で は と て を で
#       1 覗く	に て を
#       1 覗く
#       1 見馴れる	と
#       1 見馴れる
#       1 見離す	よ と は に まで
#       1 見離す	に
#       1 見違える	と は
#       1 見違える	に
#       1 見透かす	から
#       1 見逃す
#       1 見送る	を
#       1 見識張る	に
#       1 見詰める	は は を て
#       1 見詰める	で
#       1 見計らう	から
#       1 見計らう	て を
#       1 見舞う	が を
#       1 見習う	て に
#       1 見習う
#       1 見縊る	を
#       1 見積る	は を と ね
#       1 見渡す	かしら と を
#       1 見渡す	から て を
#       1 見渡す	から を
#       1 見渡す	な と て を
#       1 見渡す	て を
#       1 見棄てる	を
#       1 見捨てる	を に
#       1 見抜く	が を
#       1 見る	に従って
#       1 見当る
#       1 見張る	を に
#       1 見廻る	から と
#       1 見廻す
#       1 見届ける	で を
#       1 見届ける	を
#       1 見向く	が と が と は も
#       1 見合せる	から が
#       1 見合わせる	を
#       1 見受ける	じゃ か と も に
#       1 見受ける	て と ので は に は
#       1 見受ける	と は より に
#       1 見て取る	じゃ か と も と
#       1 見て取る	に は と
#       1 見て取る	と
#       1 見出す	でも に を を
#       1 見出す	で かも と において が
#       1 見出す	を
#       1 見付ける	で も に
#       1 見付ける
#       1 見下す	と て て を て
#       1 見下す	が に
#       1 見下せる	から が に
#       1 見下ろす	な と は たり たり て
#       1 見下ろす	と と て を て
#       1 見上ぐ	は は から を
#       1 見上げる	と から
#       1 見上げる	と は を
#       1 見上げる	を
#       1 見る	について は て
#       1 見る	ながら から
#       1 見る	ばかり に て が ね と を に
#       1 見る	という が
#       1 見る	なんか
#       1 見る	ので と ながら
#       1 見る	から と たり から たり て
#       1 見る	も によって
#       1 見る	に たり て たり て て
#       1 見る	に は て なんぞ に を
#       1 見る	は か ね ば まで ばかり て
#       1 見る	て が は で も て かも
#       1 見る	が と の は て に を
#       1 見る	が て な て て か
#       1 見せる	だって だって を に
#       1 見える	ながら も と
#       1 見せる	たり て たり ばかり
#       1 見える	など は に が の の に て
#       1 見える	て ので という だけ が
#       1 見せる	て のみ でも に
#       1 見える	が から は に に
#       1 見える	て さえ
#       1 見せる	と は として て
#       1 見える	は て ものの
#       1 見える	の が ので は に も
#       1 見せる	と で んで
#       1 見える	か ね と ばかり は と
#       1 見える	で は に は じゃ か
#       1 見える	に で は と だけ
# ...
#       1 叩く	など は で
#       1 叩く	など を
#       1 叩く	で と から が を て
#       1 叩く	と は で と で を
#       1 叩く	と が で を と
#       1 古る	とかいう
#       1 古ぼける
#       1 口走る	て を
#       1 受合う	て から と の に
#       1 受合う	で か か
#       1 受け合う	は か とも まで は
#       1 受け合う	か か
#       1 受け合える
#       1 受取る	を に
#       1 受取る	を
#       1 受け取る	のみ と は
#       1 受け取れる	て から と しか
#       1 受ける	さえ
#       1 受ける	も として より を
#       1 受ける	は こそ
#       1 受ける	は が から を て
#       1 受ける	は を に から
#       1 取り違える	を
#       1 取り落す	を
#       1 取り立てる	と
#       1 取り留める
#       1 取り殺す	て を
#       1 取り残す	は も
#       1 取り極める	て だけ は に
#       1 取り扱う	から に は て として て
#       1 取り扱う	は まで を として て
#       1 取り扱う
#       1 取払う	て を
#       1 取払う
#       1 取り払う	から
#       1 取り巻く	を から
#       1 取り寄せる	から よ
#       1 取り寄せる	さ が から を て か
#       1 取り囲む	に は として て を で
#       1 取り合せる	の
#       1 取り去る	を
#       1 取り出す	から たり て が て を
#       1 取り出す	から
#       1 取り出す	て から を
#       1 取り出す	で
#       1 取り乱す
#       1 取上げる	を
#       1 取り上げる	ながら と を
#       1 取り上げる	な と で を
#       1 取り上げる	が と を
#       1 取る	なんか
#       1 取る	ちゃ でも
#       1 取る	から て を
#       1 取る	は で から
#       1 取れる	だって
#       1 取れる	さえ
#       1 取れる	て は は
#       1 取れる	ば は
#       1 取れる
#       1 取りつく	くらい に が
#       1 取りかかる	から より に
#       1 取りかかる	は じゃ で と て に
#       1 取りとめる	て ので は に を
#       1 収める	ながら を に へ
#       1 収める	から と が を と
#       1 収める	から に
#       1 収める	を
#       1 反り返る	は に て て
#       1 反り返る	で は
#       1 反る
#       1 及ぶ	かも が から に は
#       1 及ぶ	から に は
#       1 及ぶ	か と は て に で
#       1 及ぶ
#       1 及ぼす	たり に を
#       1 及ぼす	て に を
#       1 参堂
#       1 参る	から に は ので
#       1 参る	じゃ か と で と
#       1 参る	って て
#       1 参る	に から が が
#       1 参る	も より も
#       1 参る	て と から が が
#       1 参る	ば に など へ
#       1 参る	に と に が ねえ
#       1 参る	が へ は て と
#       1 参る
#       1 参らせる	じゃ と は に を
#       1 厭く	は
#       1 厭きる
#       1 卸す	でも
#       1 卸す	て を に て
#       1 卸す	は を て
#       1 卸す	て
#       1 卸す
#       1 印す	に を まで
#       1 印せる	に
#       1 占める	と として に を
#       1 化す	に て
#       1 化ける	だって が
#       1 化ける	ば のに は に て って
#       1 化ける	で が に かも
#       1 化ける	て で も に
#       1 化ける	て に
#       1 化ける	に
#       1 包む	から て て を
#       1 包む	て も くらい に を
#       1 包む	を
#       1 勧める	から と
#       1 勧める	て と は て を
#       1 勧める	と て は に
#       1 勤める	によって を
#       1 勤まる	が
#       1 勝つ	でも
#       1 勝れる	と て に
#       1 勝れる	て が
#       1 務まる	て も は
#       1 動き出す	ば のに と
#       1 動き出す
#       1 動く	けれども って
#       1 動く	のに が で
#       1 動く	のに も
#       1 動く	か だけ が
#       1 動く	も って
#       1 動く	は が って
#       1 動く	て と に が として て
#       1 動かす	より に を
#       1 動かす	と ば を ば
#       1 動かす	の に も
#       1 労する	て を
#       1 助かる	が から
#       1 助ける	も て
#       1 助かる	と
#       1 劣る	と て かも が は より て
#       1 劣る	も は に
#       1 加える	から て て は ば て を
#       1 加える	て が が て を に
#       1 加える	を
#       1 加える
#       1 つけ加える	から と に
#       1 力む	に従って を
#       1 力む	から を
#       1 劃する	て として に を
#       1 劃する	を て など と
#       1 割り込む	な と は って に で
#       1 割り込む	は て に か
#       1 割り込む	と に で
#       1 割り込む	で
#       1 割り切れる	くらい
#       1 割り切れる	も に
#       1 割り切れる
#       1 割り出す	と は から に
#       1 割る	を
#       1 割く
#       1 剰る	の
#       1 剥がれる	と て
#       1 削り取る	で が
#       1 剃る	て さえ
#       1 刻む	の に を
#       1 刻む	を に
#       1 刻む	を
#       1 刺し通す	が に に を
#       1 制す	で は の
#       1 制する	から と が
#       1 利く	から ほど かも
#       1 利く	でも ね て て は が
#       1 利く	じゃ か よ は
#       1 利く	は くらい と
#       1 利く	に なんて
#       1 利く	ば から が
#       1 利く	で も ほど に は
#       1 利く	と で は が は か
#       1 利く	て も に は も
#       1 利く	は て も が
#       1 利く	て は が
#       1 利かす	から も を
#       1 利かす	が を
#       1 利かす	を
#       1 別れる	て
#       1 判ずる	と も
#       1 初める	は を に
#       1 初める	は
#       1 列ねる	之 が を
#       1 刈り込む	ほど
#       1 刈り込む	と ども に
#       1 刈り込む	は まで
#       1 刈り込む	を て
#       1 刈る	を に
#       1 切り開く	が を
#       1 切り落す	に は て は に
#       1 切り落す	を
#       1 切り抜く	が ほど
#       1 切り抜ける	と は を と
#       1 切り抜ける	て に
#       1 切り刻む	を
#       1 切り付ける	ね と は から に に
#       1 切り上げる	に じゃ か
#       1 切り上げる	て
#       1 切る	くらい が に だって て よ
#       1 切る	から
#       1 切る	は と に か ね と を
#       1 切れる	から が
#       1 切れる	から
#       1 切れる	て から
#       1 切らす	は は て から に を て さ
#       1 切れる	で に は に が て
#       1 はち切れる
#       1 分捕る	から
#       1 分つ	において は が に て
#       1 分る	なんか にゃ
#       1 分る	という が は に も
#       1 分る	ながら は に も
#       1 分る	なんぞ に は
#       1 分る	かも ので って で か
#       1 分る	から から が
#       1 分る	だけ は だって か じゃ か
#       1 分る	から て て も
#       1 分つ	は ので も は でも て
#       1 分る	は など に は
#       1 分る	が から は
#       1 分る	て が て たって
#       1 分る	て が は やら として も
#       1 分る	に て も だけ は て
#       1 分る	は と で から
#       1 分る	に は て か ので
#       1 分る	は て て が と など が
#       1 分かる	など に が
#       1 出逢う	は は で が と
#       1 出逢う	と に さ
#       1 出逢う
#       1 出直す	ば て か な
#       1 出直す	て は と
#       1 出来上がる	て に に が
#       1 出来上がる
#       1 出来る	くらい じゃあ が
#       1 出来る	たって じゃ
#       1 出来る	くらい て て と も
#       1 出来る	くらい て か の
#       1 出来る	なんか
#       1 出来る	から も まで
#       1 出来る	から に は が かも
#       1 出来る	など は て て ば に でも
#       1 出来る	など は が と で は に も が
#       1 出来る	て ながら が
#       1 出来る	も くらい
#       1 出来る	が から とも が
#       1 出来る	て ので と だけ は
#       1 出来る	が ちゃ が から
#       1 出来る	に て から は も と は に
#       1 出来る	も に ね が は が て ね
#       1 出掛ける	として を
#       1 出掛ける	て ながら に
#       1 出掛ける	が さえ ば に
#       1 出掛ける	が まで
#       1 出掛ける	が で から
#       1 出掛ける	て て ね に へ
#       1 出掛ける	へ で も に
#       1 出張る	で
#       1 出す	で は に対して
#       1 出向く	から へ
#       1 出合う	まで に
#       1 出合う	で
#       1 出る	は と共に へ
#       1 出会う	と は
#       1 出会う	も
#       1 出す	やいなや が に て ね
#       1 出す	やいなや は を と
#       1 出す	ながら から に を
#       1 出す	ながら から を
#       1 出る	だって
#       1 出る	とも も じゃ か
#       1 出す	に について
#       1 出る	は ながら が て から て ので な
#       1 出る	が くらい が
#       1 出す	は ながら
#       1 出る	が やら のみ も
#       1 出る	と でも が から ね
#       1 出る	て たり が て から
#       1 出る	に から て て に は かしら ん
#       1 出る	て から と と て へ が
#       1 出る	に が ながら て
#       1 出す	が て から は を
#       1 出る	と が か ばかり は が
#       1 出る	と が に が て という
#       1 出せる	だけ で が
#       1 出せる	て から に を よ
#       1 出せる	て も が も
#       1 出せる	て を
#       1 出せる	が
#       1 はみ出す	は かい から べ ん が へ くらい ずつ て
#       1 かい出す	と が から
#       1 せり出す	て て て
#       1 せり出す	の に
#       1 せり出す
#       1 つまみ出す	ね と は から を
#       1 つまみ出す	が に
#       1 凹む
#       1 凹ます	で だけ を
#       1 処する	へ に
#       1 凝り固まる	で に に
#       1 凝る	だけ に に
#       1 凝る
#       1 凝らす	て を
#       1 凝らす	を
#       1 凌ぐ	ちゃ を
#       1 凌ぐ	に は て で で
#       1 凋む	が
#       1 冷笑
#       1 冷かす	まで
#       1 冷かす	な と は て
#       1 冷える	が
#       1 冷やかす	と が と
#       1 冠する	て を
#       1 写し出す	を
#       1 写す	でも を
#       1 冒す	が
#       1 兼ねる	に は と で も
#       1 兼ねる	か と は
#       1 兼ねる
#       1 する	と共に て の に
#       1 いる	は と共に を て
#       1 する	に で と共に
#       1 なる	て と が と共に に て
#       1 あがる	が と共に
#       1 しまう	て と が と共に に て
#       1 入れ違う	と
#       1 入り込む	から へ
#       1 入り込む	て
#       1 入り乱れる	と
#       1 入る	とか
#       1 入れる	ばかり は で を て
#       1 入れる	ちゃ って
#       1 入れる	こそ て て て を に
#       1 入れる	て から に へ
#       1 入れる	へ だけ は
#       1 入れる	か に でも
#       1 入れる	が と は として に
#       1 入れる	と に は に に とも が て
#       1 入れる	て は て に は を へ て
#       1 光らす	を
#       1 充血	て と は で て
#       1 充たす	程 を
#       1 充たす	て は て
#       1 儲ける	なんか で くらい
#       1 儲ける	なんか
#       1 儲かる	から
#       1 優る	において は より かも
#       1 優る	は より
#       1 優る	に
#       1 償う	を
#       1 償う
#       1 働く	たり
#       1 働く	は のみ ばかり が
#       1 働く
#       1 働ける
#       1 傾く	について で に
#       1 傾く	から に
#       1 傾く	て が ので ばかり
#       1 傾ける	な と だけ に を
#       1 傾ける	に は を に も
#       1 傾ける	て を
#       1 傭う	から を
#       1 傭う	を
#       1 催す	て は を
#       1 備わる	が
#       1 停る	より に
#       1 倦む
#       1 値する	に に
#       1 借る	って で を て
#       1 借る	だけ
#       1 借る	に で も
#       1 借る
#       1 借りる	に は に
#       1 候う	て より を
#       1 候う	に も に
#       1 倒れる	ので て
#       1 倍する	に
#       1 信じる	より も と て
#       1 信じる	と と て
#       1 信じる
#       1 保つ	やいなや か か を
#       1 促す	は ものの と を
#       1 係る	から に に も
#       1 係る	て に も
#       1 係る	に
#       1 係わる	て だけ は に も
#       1 係わる	て は に
#       1 係わる	に も
#       1 係わる	に
#       1 係わる
#       1 侵す	と と でも を
#       1 侮る	に も
#       1 侮る
#       1 価する	に
#       1 依る	て に に
#       1 依る	と
#       1 供する	にて で も
#       1 供える	に
#       1 使い分ける	かも が を だけ
#       1 使う	じゃ か だって を
#       1 使う	だけ に を
#       1 使う	でも
#       1 使う	に なんか
#       1 使う	は て が に を
#       1 使う	が に で を
#       1 使う
#       1 使いこなせる
#       1 併せる	て
#       1 作り上げる	ば は から
#       1 作る	なんぞ
#       1 作る	じゃ が を て か
#       1 作る	でも て か ね
#       1 作る	とも で も
#       1 作る	は について を が ね
#       1 作る	に は から
#       1 作る	か に か て か
#       1 余る	て に
#       1 住み込む	が へ
#       1 住み込む	の
#       1 住む	から に で て も
#       1 佇む
#       1 似合う	に さえ くらい
#       1 似合う	は から は に
#       1 似合う	は に も
#       1 似合う
#       1 似る	は において に
#       1 似る	に たり か
#       1 似る	は は において に
#       1 似る	て も は たり たり
#       1 似る	て は か と くらい て
#       1 似る	て と は は
#       1 伺う	から を
#       1 伺う	から
#       1 伺える	が
#       1 伝う	を
#       1 伝える	は て が を に から は
#       1 伝える	が に を
#       1 伝わる	が へ
#       1 休む	て まで
#       1 休める
#       1 伏す	て を
#       1 ねじ伏せる	は て じゃ か と を に
#       1 任せる	から て を に て
#       1 任じる	ので て て て
#       1 任じる	に だけ に て
#       1 任せる	か を に
#       1 任せる	て に
#       1 仰向く	と
#       1 仰向く
#       1 仰ぐ	ので で に も を
#       1 仰ぐ	で も を
#       1 仰ぐ	と を
#       1 仰る
#       1 仰せる	は で ねえ と
#       1 仰せつける	で に
#       1 かける	ので が として を以て を
#       1 代る	よ と が に
#       1 代える	て と に
#       1 付き添う	が に は が の て
#       1 付く	くらい て
#       1 付く	って が から
#       1 付く	から で
#       1 付く	のに
#       1 付く	と まで は が
#       1 付く	と は が て
#       1 付ける	ばかり は て を て
#       1 付ける	が なんて を
#       1 付ける	と につき
#       1 付ける	が ねえ
#       1 付ける	が で まで ね
#       1 付ける	て に を から て
#       1 付ける	は と は て て なあ と を
#       1 付ける	で は て に を て
#       1 付ける	に は を に
#       1 付ける	を で へ
#       1 付ける
#       1 仕込む	に を
#       1 仕立てる	て は で も を
#       1 仕損じる	て を
#       1 仕切る	を
#       1 仕入れる	に が から て は
#       1 仕上がる	は
#       1 仕る	など は て を じゃ か
#       1 仕る	から を
#       1 仕る	から
#       1 仕る	て て が を
#       1 人
#       1 交う	に は が
#       1 交わす	は て を が に
#       1 交ぜる	を
#       1 亡ぼす	と は に て
#       1 亡くなる	でも が に
#       1 亡くなる	に も が
#       1 亡くなる	が
#       1 云う	に従って は て と
#       1 云う	に対して も に対する と
#       1 云う	に対して と
#       1 云う	について など と
#       1 云う	けれども と から
#       1 云う	において と
#       1 云う	から ものの と を
#       1 云う	たり など は じゃ わ と
#       1 云う	から から は とか よ
#       1 云う	から じゃ か と
#       1 云う	じゃ か とか
#       1 云う	じゃ か は ばかり から と と さ
#       1 云う	なあ と は ながら
#       1 云う	から て と ので ね
#       1 云う	から て も が ので を
#       1 云う	から て は て は か と
#       1 云う	から な は て か と
#       1 云う	は として だけ は と ば
#       1 云う	が ちゃ って
#       1 云う	て から と は を
#       1 云う	と は ながら か と
#       1 云う	て て から は で と に
#       1 云う	は と から か の よ
#       1 云う	と も から な と
#       1 云う	は て て から を
#       1 云う	に は て て だって じゃ か
#       1 云う	て よ と は ながら
#       1 云う	と ね は て って を よ
#       1 云う	し は し は て から と も
#       1 云う	と が て が ね と を
#       1 事足る	は だけ で
#       1 争う	で が に を
#       1 争う	て を
#       1 乾かす	に は
#       1 乾かす	を
#       1 乱れる	も て から に
#       1 乱れる
#       1 乞う	と から で を
#       1 乞う	て から も
#       1 乞う	て は は に を と
#       1 乞う	へ も
#       1 乗り込む	て と が から で
#       1 乗り越す	て が で は など を か
#       1 乗り越える	が を へ つつ
#       1 乗り越える	を
#       1 乗り出す	か と は さえ ば へ て
#       1 乗り出す	て て へ
#       1 乗る	ながら は に よ
#       1 乗る	から て へ
#       1 乗る	が から へ
#       1 乗る	て て から て
#       1 乗る	て が に が
#       1 乗じる	から に
#       1 乗じる	の から に
#       1 乗せる	を に だけ へ
#       1 乗せる	て を に
#       1 いる	之 が を
#       1 中る	に ばかり
#       1 中る	に の
#       1 並べ立てる	を て
#       1 並ぶ	は ばかり に
#       1 並ぶ	に が ずつ で
#       1 並べる	ばかり
#       1 並べる	じゃ ばかり て
#       1 並べる	から な と て を
#       1 並べる	たり と
#       1 並べる	が と ばかり て よ
#       1 並みいる	で
#       1 世帯染みる	わ ね と に
#       1 与える	に は に対して のみ は も
#       1 与る
#       1 与える	けれども に は を
#       1 与える	じゃあ か と は て を
#       1 与える	として を か
#       1 与える	たり て に を
#       1 与える	で だけ に を
#       1 与える	は て に を に つつ
#       1 与える	て が は は と て に を から
#       1 下げ渡す
#       1 下る	ので は で から
#       1 下す	じゃ か て
#       1 下る	から
#       1 下る	て さえ
#       1 下る	に は が とも で て
#       1 下る	て に は でも が
#       1 下す	と は へ と を
#       1 下る	が は に て
#       1 下る	の に が
#       1 下さる	から だけ て
#       1 下さる	て ながら ね まで に まで て
#       1 下がる	が から は の に たり
#       1 下げる	さ など は で と が を
#       1 下りる	て て から が
#       1 下さる	は が から
#       1 下りる	と ば て と に へ て
#       1 ぶら下げる	によって を
#       1 ぶら下げる	まで
#       1 ぶら下げる	な と は て を に
#       1 ぶら下げる	て は の に に
#       1 上る	ながら から
#       1 上る	だって て
#       1 上る	から ば が に て
#       1 上る	から て て が
#       1 上る	から で
#       1 上る	て から は と に
#       1 上る	て の まで
#       1 上る	は て て で
#       1 上がる	について て
#       1 上げる	ながら を
#       1 上げる	から でも
#       1 上げる	とも て は へ
#       1 上げる	だけ を に
#       1 上げる	は を から ね
#       1 上げる	と に か に まで
#       1 上がれる	で も
#       1 上がれる
#       1 ねじ上げる	て は
#       1 す	ながら て を て
#       1 す	ながら と を
#       1 く	たって よ
#       1 く	だって
#       1 く	から て か に に かも
#       1 く	から に て さ
#       1 く	が やいなや を
#       1 する	にあたって を
#       1 てる	けれども から か と
#       1 れる	について さえ
#       1 する	によって と だけ は に
#       1 する	によって と から
#       1 なる	けれども が に ちゃ は ば
#       1 てる	ばかり じゃ として に
#       1 なる	ばかり から と は だけ に
#       1 かく	だって に って なんぞ
#       1 する	くらい に まで
#       1 いる	くらい が に だって て よ
#       1 おる	たって て ば じゃ か
#       1 ある	なんか は が から
#       1 いる	くらい は か て に は が て
#       1 いる	かも において は に て
#       1 する	から について
#       1 なる	じゃ なんぞ は ば くらい
#       1 する	じゃ けども て を て の
#       1 くる	から が ばかり から
#       1 いる	から に なんか を で て じゃ か
#       1 ある	かも が だって に は
#       1 する	たり て たり ばかり
#       1 いる	など は て から から で よ
#       1 おる	のに は で じゃ て なあ
#       1 なる	じゃ か は から で に じゃ か
#       1 いる	から と は と んで から て
#       1 する	じゃ か と も から に を
#       1 なる	ので て は に と のみ と
#       1 くる	など は に が の の に て
#       1 いく	が において において て は
#       1 くる	と によって だけ が て
#       1 なる	が において は か に より
#       1 なる	は くらい のに から に
#       1 いる	が だって まで は を の に て は か
#       1 なる	は として だけ は と ば
#       1 なる	が ばかり じゃ に も
#       1 なる	は として よ ばかり から
#       1 いる	て くらい に まで
#       1 こむ	は ながら が て から て ので な
#       1 する	は ながら て ぜ と を が
#       1 いる	は から について を
#       1 ある	で から ばかり の
#       1 えむ	が んで なんて
#       1 いる	は から まで ばかり
#       1 いる	は かい から べ ん が へ くらい ずつ て
#       1 ある	が ので かも が は て で が
#       1 てる	と でも て ばかり
#       1 する	ば から も まで に は を よ
#       1 いる	ば のに と は だけ は て
#       1 いる	は ので も は でも て
#       1 する	か って は に を じゃ か
#       1 する	に から て て に は かしら ん
#       1 する	が へ にあたって
#       1 ある	が は について より も が
#       1 いる	と が について を で は か と
#       1 いる	と は くらい しか
#       1 いる	ば は として か に に を て かも
#       1 なる	で ば から ばかり ば
#       1 いる	と か など より として の に て
#       1 ある	は て ほど など は も
#       1 する	で を たり から
#       1 する	と に すら か かも
#       1 いる	と て かも が は より て
#       1 なる	に て から は も と は に
#       1 する	け て が によって を
#       1 する	が に に だって は でも と
#       1 いる	は て で じゃ じゃ を て
#       1 くる	て と で など は について を など と て
#       1 れる	で は は つつ と しか
#       1 いる	に て が から で で と さ
#       1 いる	で は が で から から と て
#       1 する	は か は も など て も は か
#       1 ある	と に は に に とも が て
#       1 する	は が に よ に じゃ か
#       1 おる	へ へ へ へ へ て だって
#       1 ある	ね て に は の は から な
#       1 いる	て が は で も て かも
#       1 とる	は て と と は は を から ね
#       1 れる	て が に は て も と しか
#       1 いける	けれども として で は か ちゃ
#       1 しまう	けれども と て んで て
#       1 しまう	どころか
#       1 しまう	くらい から ば で
#       1 かける	ばかり のに と
#       1 おこす	なんか も まで に
#       1 すます	くらい が に だって て よ
#       1 わかる	ばかり は に でも
#       1 はおる	だって に は に て さ
#       1 うたう	のみ において を
#       1 ござる	ので ものの ほど は
#       1 おろす	から ながら と へ を
#       1 られる	より として に
#       1 られる	など は から において を
#       1 くれる	から に ずつ じゃ か
#       1 つける	かい と から で に も を
#       1 やめる	から て だけ は
#       1 やれる	じゃ か へ だって へ じゃ か
#       1 たまる	じゃ か て たって て か
#       1 られる	は によって
#       1 られる	と ながら として に で
#       1 しまう	て ばかり て から
#       1 なさる	と から から か なんか を
#       1 しまう	か ので から が て
#       1 やめる	て から まで も
#       1 くらす	て から で から まで ば
#       1 くれる	て のみ か は さえ
#       1 られる	に から て て に は かしら ん
#       1 られる	が て について を の に
#       1 られる	と に ばかり て は から ね
#       1 やれる	に も くらい は
#       1 しまう	に て から として て
#       1 がする	は て から は ので よ
#       1 しまう	て が から で も と ほど で て
#       1 しまう	て と ので は て て
#       1 られる	に は て なんぞ に を
#       1 しまう	て が て たって
#       1 しまう	は は て から に を て さ
#       1 しまう	て が と に て かも
#       1 あるく	て が に は て も と しか
#       1 しまう	て も は て は は で へ て
#       1 しまう	て は て に は を へ て
#       1 いただく	によって
#       1 いただく	から じゃ
#       1 からかう	から に でも
#       1 しくじる	から も で から ね
#       1 しでかす	から て を かも
#       1 きかかる	から と て て として という へ
#       1 からまる	じゃ か と は に て
#       1 あてがう	から て に は を
#       1 せしめる	から を と ば
#       1 ふくれる	て ばかり に
#       1 せしめる	て として
#       1 ぬくもる	は は くらい ながら て
#       1 きつける	は で ばかり に へ
#       1 すすめる	に を なんて
#       1 ほかなる	て て から は に
#       1 あつまる	も さ は ば として に
#       1 いただく	が も で で ので
#       1 いただく	て は て に は で を て
#       1 あきらめる	くらい さ
#       1 とりかかる	だけ ながら に
#       1 あらわれる	でも など で は が て
#       1 おっしゃる	から でも
#       1 あらわれる	とも て が から
#       1 おっしゃる	でも
#       1 あらわれる	は において て
#       1 とりとめる	て から だけ は
#       1 あらわれる	て から と が に
#       1 おっしゃる	は に ばかり
#       1 なりすます	が と やら ながら に て
#       1 やってくる	と て たり て は へ
#       1 かきまぜる	は を つつ
#       1 あらわれる	へ と は でも に て
#       1 こしらえる	で も で たり を
#       1 あらわれる	て が の に として は て
#       1 あらわれる	で が と て から が
#       1 おっしゃる	か は と も て よ
#       1 いらっしゃる	じゃ けれども と
#       1 いらっしゃる	じゃ か は を に て ね
#       1 いらっしゃる	のに て よ
#       1 いらせられる	と など は て
#       1 いらっしゃる	て から で
#       1 いらっしゃる	は て ばかり
#       1 いらっしゃる	は で から て
#       1 おひゃらかす	よ に を よ
#       1 *

# %%
# !cat ../data/45.txt | sort | grep -E '^する|^見る|^与える' | uniq -c | sort -nr
# Out:
#    1098 する	が
#     749 する	が て
#     400 する
#     353 する	が と で
#     316 見る	の
#     153 する	は は は と
#     124 する	まで は
#     112 見る	は を
#      96 する	まで
#      76 見る
#      56 する	が は へ と を
#      52 する	まで が を
#      51 見る	は て て
#      44 する	に でも
#      38 する	だって は
#      37 する	から て て を
#      31 する	で でも を
#      28 する	て だけ は て
#      26 見る	ので が
#      21 見る	から
#      20 する	として
#      20 する	で は から
#      18 する	か て も に は を
#      12 する	は ながら を
#      12 する	と て たり を て
#      11 する	くらい に に
#      10 する	から に も て を
#      10 する	も くらい
#      10 する	の に まで を
#       9 見る	より で を
#       9 見る	か ね と を
#       8 見る	は て で を て
#       8 する	をもって
#       8 する	て は に かも
#       7 する	によって と は
#       7 する	から って を
#       7 する	て だけ を に に
#       7 する	は に ながら を
#       7 する	の て と は で て の
#       6 見る	に って を
#       6 見る	て まで
#       6 する	から さえ
#       6 する	が によって
#       6 する	に で を から に
#       5 与える	ば を
#       5 する	について を
#       5 する	たって ねえ
#       5 する	かい と さえ を
#       5 する	から な と は の に
#       5 する	て て だけ に よ と
#       4 見る	たり て が を
#       4 する	じゃ だけ は に
#       4 する	は ほど は と を に
#       4 する	と は が て な と は を
#       3 見る	は から て て
#       3 与える	に け を
#       3 する	ばかり わ と を
#       3 する	だけ は から
#       3 する	から で が かも
#       3 する	に たって に は
#       3 する	は から まで を
#       3 する	と は ながら
#       3 する	で は が から て と
#       2 見る	ながら は を
#       2 見る	から じゃ
#       2 見る	に ながら を
#       2 見る	て ばかり
#       2 見る	て か と ばかり て
#       2 与える	は て に を
#       2 する	だけ たって は
#       2 する	から と は から に て
#       2 する	から と を て たり
#       2 する	じゃ か は を に て ね
#       2 する	は たり へ だり
#       2 する	が から に は を に も
#       2 する	と は によって の を
#       2 する	に は をもって
#       2 する	は て ばかり に と
#       2 する	て は まで は で て かも
#       2 する	と に て ばかり さ
#       2 する	て が て たって
#       2 する	で は に から が の て
#       2 する	で の て て から
#       1 見る	に従って
#       1 見る	について は て
#       1 見る	ながら から
#       1 見る	ばかり に て が ね と を に
#       1 見る	という が
#       1 見る	なんか
#       1 見る	ので と ながら
#       1 見る	から と たり から たり て
#       1 見る	も によって
#       1 見る	に たり て たり て て
#       1 見る	に は て なんぞ に を
#       1 見る	は か ね ば まで ばかり て
#       1 見る	て が は で も て かも
#       1 見る	が と の は て に を
#       1 見る	が て な て て か
#       1 する	に従って は て
#       1 する	に対して に
#       1 する	に対し を
#       1 する	は に対して を て
#       1 する	と共に て の に
#       1 する	に で と共に
#       1 する	は て が と共に が に て
#       1 与える	に は に対して のみ は も
#       1 与える	けれども に は を
#       1 与える	じゃあ か と は て を
#       1 与える	として を か
#       1 与える	たり て に を
#       1 与える	で だけ に を
#       1 与える	は て に を に つつ
#       1 与える	て が は は と て に を から
#       1 する	にあたって を
#       1 する	によって と だけ は に
#       1 する	によって と から
#       1 する	けれども と て んで て
#       1 する	において て で を
#       1 する	なんて だって は や
#       1 する	くらい から が を
#       1 する	ばかり は として を て
#       1 する	くらい に まで
#       1 する	けれど で と は を に て
#       1 する	から について
#       1 する	から ばかり じゃ も か で
#       1 する	じゃ けども て を て の
#       1 する	から くらい の に て
#       1 する	から ながら て に
#       1 する	たり たり たり たり て て
#       1 する	とも まで は と て ば
#       1 する	から でも な と を
#       1 する	じゃ ね ものの が て さ
#       1 する	から を くらい に
#       1 する	から て だって
#       1 する	たり て たり ばかり
#       1 する	から と たり から たり て
#       1 する	ので が から は て に て
#       1 する	んで と から と に て
#       1 する	から と だけ は に
#       1 する	たり と は など を
#       1 する	じゃ か と も から に を
#       1 する	が において て に て
#       1 する	も において と
#       1 する	で ばかり に て から な
#       1 する	は として に を つつ
#       1 する	は ながら て ぜ と を が
#       1 する	は ながら の を に て
#       1 する	ん から ながら に て
#       1 する	に だけ でも
#       1 する	け たり に として て は か
#       1 する	ば こそ が として て も
#       1 する	ば から も まで に は を よ
#       1 する	て から て から は を て
#       1 する	と ちゃ か ちゃ が か
#       1 する	て から て から を
#       1 する	て のに は て ばかり に
#       1 する	ば のに で ば のに
#       1 する	か って は に を じゃ か
#       1 する	が から は の に たり
#       1 する	に から て て に は かしら ん
#       1 する	と は にあたって て て
#       1 する	が へ にあたって
#       1 する	は か について に
#       1 する	は で ばかり て から
#       1 する	と に ばかり て は から ね
#       1 する	で を たり から
#       1 する	て も から か から な
#       1 する	と に すら か かも
#       1 する	て が から は て は に つつ
#       1 する	に は から に が て ね
#       1 する	け て が によって を
#       1 する	が に に だって は でも と
#       1 する	な と は たり たり て
#       1 する	は か は も など て も は か
#       1 する	が も に ば こそ で て
#       1 する	は が に よ に じゃ か
#       1 する	と は に を て から

# %% [markdown]
# ## 46. 動詞の格フレーム情報の抽出

# %%
n,t='\n','\t'
with open('../data/46.txt', mode='w') as f:
    for chList in result:
        for ch in chList:
            ils=[idx for idx, x in enumerate([m.pos for m in list(filter(lambda x: x.pos != '記号', ch.morphs))]) if x == '動詞']
            if len(ils)==0:continue
            for i in ils:
                postPosList=[m.base for m in list(filter(lambda x: x.pos != '記号', sum([chList[idx].morphs for idx in ch.srcs],[]))) if m.pos == '助詞']
                l1=list(filter(lambda m: '助詞' in [x.pos for x in m], [chList[idx].morphs for idx in ch.srcs]))
                txtLs=[''.join([x.surface for x in hoge]) for hoge in l1]
                f.write(f"{ch.morphs[i].base}{t}{' '.join(postPosList)}{t}{' '.join(txtLs)}{n}")
f.close()

# %% [markdown]
# ## 47. 機能動詞構文のマイニング

# %%
n,t='\n','\t'
with open('../data/47.txt', mode='w') as f:
    for chList in result:
        for i,ch in enumerate(chList):
            ils=[idx for idx, x in enumerate([m.pos1 for m in ch.morphs]) if x == 'サ変接続']
            if (len(ils)==0 or len(ch.morphs)<=ils[0]+1 or ch.morphs[ils[0]+1].base != 'を') \
                or ('動詞' not in [x.pos for x in list(filter(lambda x: x.pos != '記号',chList[ch.dst].morphs))]) :continue    
            sams=list(filter(lambda x: x.pos != '記号' and (x.pos1 =='サ変接続' or x.base=='を'), list(filter(lambda x: x.pos != '記号',ch.morphs))))
            vbms=list(filter(lambda x: x.pos == '動詞', list(filter(lambda x: x.pos != '記号',chList[ch.dst].morphs))))
            saSrcsMos=[list(filter(lambda x: x.pos != '記号',chList[idx].morphs)) for idx in ch.srcs]
            vbSrcsMos=list(filter(lambda x: x not in sams+vbms,[list(filter(lambda x: x.pos != '記号',chList[idx].morphs)) for idx in list(filter(lambda x: x not in [i,i+1],chList[ch.dst].srcs))]))
            postPosList=[x.surface for x in sum([list(filter(lambda x: x.pos == '助詞',l)) for l in saSrcsMos+vbSrcsMos],[])]
            srcsSurfList=[''.join([x.surface for x in ms]) for ms in saSrcsMos+vbSrcsMos]

            f.write(f"{''.join([x.surface for x in sams])+vbms[0].base}{t}{' '.join(postPosList)}{t}{' '.join(srcsSurfList)}{n}")
        
    f.close()

# %%
# !cut -f 1 ../data/47.txt | sort | uniq -c | sort -nr
# Out:
#      30 返事をする
#      21 挨拶をする
#      17 話をする
#      16 真似をする
#      13 喧嘩をする
#       9 運動をする
#       9 質問をする
#       6 話を聞く
#       6 注意をする
#       6 昼寝をする
#       6 問答をする
#       5 質問をかける
#       5 講義をする
#       5 相談をする
#       5 病気をする
#       5 戦争をする
#       4 降参をする
#       4 辞儀をする
#       4 講釈をする
#       4 演説をする
#       4 欠伸をする
#       4 散歩をする
#       4 放蕩をする
#       4 休養を要する
#       4 いたずらをする
#       3 遠慮をする
#       3 逆上をする
#       3 議論をする
#       3 談話を聞く
#       3 談話をする
#       3 行水を使う
#       3 行動をとる
#       3 落着を告げる
#       3 自殺をする
#       3 経験をする
#       3 深入りをする
#       3 活躍を試みる
#       3 決心をする
#       3 批評を願う
#       3 往来をあるく
#       3 安心を得る
#       3 学問をする
#       3 噂をする
#       3 告訴をかく
#       3 同情を表する
#       3 同情を表す
#       3 化粧をする
#       3 写生をする
#       3 体操をする
#       3 交際をする
#       2 逆戻りをする
#       2 迫害を加える
#       2 辞職をする
#       2 賭をする
#       2 談判を聞く
#       2 談判をする
#       2 説教をやる
#       2 話をつづける
#       2 註釈をつける
#       2 観察を怠る
#       2 覚悟をする
#       2 見物をする
#       2 著述をする
#       2 苦心をする
#       2 自炊をする
#       2 自慢をする
#       2 結婚を申し込む
#       2 結婚をやる
#       2 約束をする
#       2 研究をやる
#       2 注意を惹く
#       2 沈黙を守る
#       2 撰をする
#       2 掃除をする
#       2 抗議を申し込む
#       2 意味をつける
#       2 息を凝らす
#       2 息をつく
#       2 思案を定める
#       2 心配を掛ける
#       2 復讐をとる
#       2 御馳走を食う
#       2 御無沙汰をする
#       2 座禅をする
#       2 平均を破る
#       2 工夫をする
#       2 居眠りをする
#       2 小便をする
#       2 宙返りをする
#       2 失礼を致す
#       2 外出をする
#       2 変化を生じる
#       2 勘定をする
#       2 刺激を与える
#       2 出所をする
#       2 修養をする
#       2 修行をする
#       2 供をつる
#       2 了見を起す
#       2 一段落を告げる
#       1 食事を済ませる
#       1 鞭撻を加える
#       1 面晤を期す
#       1 露見を恐れる
#       1 震動をはじめる
#       1 電話を切る
#       1 雑談を聞く
#       1 雑談をする
#       1 随行を命ずる
#       1 降参を申し込む
#       1 附を染め出す
#       1 関係をつける
#       1 関係をする
#       1 間食をする
#       1 閉鎖を命じる
#       1 長生きをする
#       1 鑑定をつける
#       1 酷評を加える
#       1 酷評をやる
#       1 邪魔を致す
#       1 邪魔をする
#       1 遠征をする
#       1 道楽をすすめる
#       1 道楽をする
#       1 運動を称す
#       1 運動を始める
#       1 運動を云う
#       1 遊戯をくだける
#       1 遊弋をする
#       1 連想をかたちづくる
#       1 速断をやる
#       1 通行をする
#       1 通信を読む
#       1 逆上を重んずる
#       1 逆上を呼ぶ
#       1 退去を命ずる
#       1 返答を待つ
#       1 返答をする
#       1 返報をする
#       1 返事を聞く
#       1 返事を承る
#       1 返事を待つ
#       1 近道を通る
#       1 辛苦をする
#       1 身震いをする
#       1 ストライキを起す
#       1 購求を願う
#       1 質問を受ける
#       1 賛成を求める
#       1 貧乏をする
#       1 議論を弄する
#       1 議論を始める
#       1 議論を好む
#       1 警戒を解く
#       1 講釈を聞く
#       1 講話を聞く
#       1 講話をする
#       1 講義を行く
#       1 談話を承る
#       1 談話を分る
#       1 談話をつづける
#       1 談笑をする
#       1 調和を計る
#       1 調和を忘れる
#       1 説法を受ける
#       1 説明を与える
#       1 説明をする
#       1 誤解を生ずる
#       1 話を進める
#       1 話を致す
#       1 話を承る
#       1 話を切らす
#       1 話を伺う
#       1 話を仕る
#       1 話をなさる
#       1 詰問を受ける
#       1 試験を受ける
#       1 試験をする
#       1 証明をする
#       1 註釈を加える
#       1 診断をする
#       1 診察を終る
#       1 診察を始める
#       1 診察を受ける
#       1 許諾を至る
#       1 訪問を受ける
#       1 訓練を与える
#       1 訓戒を垂れる
#       1 訓戒を加える
#       1 訓戒を与える
#       1 計算をする
#       1 解釈を聞く
#       1 観念をする
#       1 観察を述べる
#       1 観察を積む
#       1 観察を始める
#       1 観察をする
#       1 要求をする
#       1 襲撃を蒙る
#       1 襲撃を受ける
#       1 製造を負う
#       1 衰弱を起す
#       1 行水を見下ろす
#       1 蚕食をてる
#       1 虚構をもつ
#       1 虐待をする
#       1 薨去を落ちる
#       1 著述を居る
#       1 苦難を忍ぶ
#       1 苦笑をする
#       1 苦心を買う
#       1 苦心をなする
#       1 苦労をする
#       1 芝居をする
#       1 自証をする
#       1 自覚を与る
#       1 脱線をする
#       1 胡坐をかく
#       1 絞殺を用いる
#       1 絞殺をする
#       1 終了を告げる
#       1 紹介をする
#       1 約束を覚える
#       1 約束を守る
#       1 算段をする
#       1 算を乱す
#       1 答弁を得る
#       1 競争をやる
#       1 立見をする
#       1 稽古を始める
#       1 稽古をはじめる
#       1 稽古をやる
#       1 祈念をこらす
#       1 砲撃を食う
#       1 研究を要する
#       1 研究を続ける
#       1 研究を尽す
#       1 矛盾をする
#       1 相談を開く
#       1 相談を持ちかける
#       1 発達を致す
#       1 発達を立てる
#       1 発見をする
#       1 発展をする
#       1 病気を癒す
#       1 留守番を頼む
#       1 留守をする
#       1 由来を聞く
#       1 由来を案ずる
#       1 生活をする
#       1 猶予を与える
#       1 ご無沙汰を致す
#       1 火傷をする
#       1 演説をなする
#       1 満足を求める
#       1 清聴を煩わす
#       1 活動を見る
#       1 活動を名づける
#       1 洗髪を乾かす
#       1 洋行をする
#       1 注文をする
#       1 注意を願う
#       1 治療をうける
#       1 油断をする
#       1 決心を起す
#       1 水泳をやる
#       1 比例を失する
#       1 欠乏を感じる
#       1 案内を頼む
#       1 案内を乞う
#       1 朝食を済ます
#       1 いたずらを書く
#       1 暴行をする
#       1 晩酌を始める
#       1 早死をする
#       1 早合点をする
#       1 旅行をする
#       1 料理を食う
#       1 料理を奢る
#       1 敬意を表する
#       1 教育を受ける
#       1 教育をくる
#       1 故障を挟む
#       1 攻撃を喰う
#       1 支度をする
#       1 摩擦を与える
#       1 損害を償う
#       1 探偵を比す
#       1 探偵を使う
#       1 探偵をする
#       1 掃除を始める
#       1 掃除をはじめる
#       1 捺印を願う
#       1 挨拶を終る
#       1 抵抗をする
#       1 投書をする
#       1 批評を加える
#       1 手続きを踏む
#       1 戸締りをする
#       1 戦闘をする
#       1 戦争を挑む
#       1 我慢を重ねる
#       1 我慢をする
#       1 我儘を張れる
#       1 我儘を尽くす
#       1 我儘をする
#       1 懐中を抜く
#       1 慰安を求める
#       1 意味を聞かす
#       1 意味を究める
#       1 意味を示す
#       1 意味をする
#       1 想像をする
#       1 情死をする
#       1 悪戯をやる
#       1 息を入れる
#       1 怪我をする
#       1 怒号をする
#       1 忠告を容れる
#       1 忠告を加える
#       1 心配を願う
#       1 心配をかける
#       1 心配をもつ
#       1 御馳走を食わせる
#       1 御馳走を食べる
#       1 御馳走を致す
#       1 御馳走を来る
#       1 御馳走をあるく
#       1 御馳走をする
#       1 後悔をする
#       1 待ったをする
#       1 往生をあがる
#       1 往来を通る
#       1 影響を与える
#       1 彩色を見る
#       1 形容をなさる
#       1 弁護をする
#       1 弁論をする
#       1 弁解をする
#       1 建築を眺める
#       1 広告を出す
#       1 平均を保つ
#       1 平均をする
#       1 希望をする
#       1 差別を立てる
#       1 左右を見る
#       1 尽力を仰ぐ
#       1 小便をかける
#       1 尊敬を払う
#       1 尊敬を受ける
#       1 射撃を行う
#       1 専断を憤る
#       1 対面をする
#       1 対談をする
#       1 対話を聞く
#       1 寂滅をごねる
#       1 容赦を願う
#       1 定義を云う
#       1 定義をする
#       1 安心を求む
#       1 安心を欲する
#       1 存在を認める
#       1 始末をつける
#       1 いたずらを始める
#       1 妨害をする
#       1 奉職をする
#       1 失礼をする
#       1 失望を受取る
#       1 失敗をする
#       1 失恋をする
#       1 大発見をなす
#       1 大息を洩らす
#       1 変調を極める
#       1 変化を起こす
#       1 変化を示す
#       1 変化を求める
#       1 変化を来す
#       1 変化をあらわす
#       1 報道を逢う
#       1 報道をする
#       1 報知を致す
#       1 在宿を願う
#       1 困却をする
#       1 回向を受ける
#       1 回向をする
#       1 噂を致す
#       1 嘆願をする
#       1 嘆息をする
#       1 喧嘩を買う
#       1 喧嘩を譲る
#       1 喧嘩を見る
#       1 喧嘩を思う
#       1 喧嘩を始める
#       1 呼吸を飲み込む
#       1 呼吸を計る
#       1 呼吸をいく
#       1 告訴を書く
#       1 吶喊を喰う
#       1 含嗽をやる
#       1 同情を錬る
#       1 同情を起す
#       1 同情を求める
#       1 同情を持つ
#       1 同情を寄せる
#       1 同情をこめる
#       1 同情をする
#       1 同宿をする
#       1 合奏をする
#       1 合図をする
#       1 取締をする
#       1 反響を起す
#       1 反応を呈す
#       1 反応をする
#       1 参を食う
#       1 参を煎じる
#       1 厚遇を受ける
#       1 協賛を仰ぐ
#       1 協商を始める
#       1 午睡をする
#       1 区劃を立てる
#       1 北面を取り囲む
#       1 化粧を施す
#       1 動作を真似る
#       1 勉強をする
#       1 加減を見る
#       1 創作をやる
#       1 刺激を取り去る
#       1 刺激を作る
#       1 制裁を加える
#       1 制裁をする
#       1 判断をする
#       1 出入を禁ずる
#       1 処置を付ける
#       1 処分を受ける
#       1 写生を力む
#       1 冒険をする
#       1 再考を煩わす
#       1 入水をせしめる
#       1 克復を告げる
#       1 催促をしてやる
#       1 倹約をする
#       1 借金をする
#       1 修養を力む
#       1 信用をおく
#       1 侮辱を受ける
#       1 依頼をうける
#       1 依頼をする
#       1 供を連れる
#       1 供給を仰ぐ
#       1 供を拾う
#       1 供を可愛がる
#       1 作用を有する
#       1 作用を描き出す
#       1 位置をする
#       1 会釈をする
#       1 休養を欲する
#       1 休養を得る
#       1 休養を乞う
#       1 仲間入りをする
#       1 仮定を打つ
#       1 代理を勤める
#       1 代理を務める
#       1 他言をする
#       1 仕付を受ける
#       1 仕事を片付ける
#       1 仕事をする
#       1 交換をやる
#       1 了見を抱く
#       1 乱暴を働く
#       1 乱暴をかく
#       1 主宰をもつ
#       1 世話をする
#       1 不足を訴える
#       1 不足を云う
#       1 下宿を出る
#       1 下宿をする
#       1 一座を見廻る
#       1 ストライキをしでかす
#       1 あかんべえをする

# %%
# !cut -f 1,2 ../data/47.txt | sort | uniq -c | sort -nr
# Out:
#       8 運動をする
#       7 返事をする	は と
#       7 返事をする	て
#       7 真似をやる
#       7 挨拶をする	で
#       5 話をする	の
#       5 喧嘩をする	で
#       5 喧嘩をする
#       4 返事をする
#       4 質問をする	が て
#       4 話をする	の に
#       4 真似をする	の で
#       4 挨拶をする	か と も
#       3 返事をする	から ね と
#       3 返事をする	さ と は に
#       3 返事をする	の よ と
#       3 話を聞く	の
#       3 真似をする	の
#       3 昼寝をする	が
#       3 挨拶をする	から
#       3 安心を得る	が
#       2 遠慮をする
#       2 逆戻りをする	の
#       2 辞儀をする	が
#       2 質問をする	と
#       2 質問をかける	か と が
#       2 質問をかける	と は
#       2 議論をする	て
#       2 講釈をする	て ね
#       2 講義をきく
#       2 話を聞く
#       2 話をする
#       2 行動をする	が
#       2 落着を告げる	は と
#       2 自炊をする	で に
#       2 約束をする	て
#       2 相談をする	と
#       2 病気をする
#       2 深入りをする
#       2 活躍を試みる	て
#       2 注意を惹く	の
#       2 注意をする	で
#       2 決心をする	と
#       2 欠伸をする	て と て
#       2 散歩をする	に
#       2 散歩をする
#       2 放蕩をする	から が
#       2 放蕩をする
#       2 挨拶をする	の は て と
#       2 戦争をする	と
#       2 復讐をとる	と の と は
#       2 御無沙汰をする
#       2 平均を破る	の
#       2 工夫をする
#       2 学問をする
#       2 喧嘩をする	て も
#       2 問答をやる	の で
#       2 問答をする	の
#       2 告訴をかく
#       2 同情を表する	と は て
#       2 写生をする
#       2 供をつる	が
#       2 交際をする
#       2 いたずらをする	か
#       1 食事を済ませる
#       1 鞭撻を加える	から て て は ば て
#       1 面晤を期す
#       1 露見を恐れる
#       1 震動をはじめる	が の に
#       1 電話を切る	に と
#       1 雑談を聞く
#       1 雑談をする	は ながら
#       1 随行を命ずる	へ
#       1 降参を申し込む	かい と は て ながら
#       1 降参をする	から で は と
#       1 降参をする	から
#       1 降参をする	な と は
#       1 降参をする	と
#       1 附を染め出す	の て ので へ
#       1 関係をする	の に
#       1 関係をつける	かい と から で に も
#       1 間食をする	で
#       1 閉鎖を命じる
#       1 長生きをする
#       1 鑑定をつける	は と に は
#       1 酷評を加える	と は が
#       1 酷評をやる
#       1 邪魔を致す	て
#       1 邪魔をする	の て が
#       1 遠慮をする	に
#       1 遠征をする	の に まで
#       1 道楽をする	て
#       1 道楽をすすめる	に
#       1 運動を称す
#       1 運動を始める	は
#       1 運動を云う
#       1 運動をする	から
#       1 遊戯をくだける	の
#       1 遊弋をする	から て で
#       1 連想をかたちづくる	の
#       1 速断をやる	に て と
#       1 通行をする	は て て
#       1 通信を読む	の
#       1 逆上を重んずる	で
#       1 逆上を呼ぶ
#       1 逆上をする	に は を の へ に ば
#       1 逆上をする	の は て と
#       1 逆上をがる	て
#       1 退去を命ずる	て に
#       1 迫害を加える	から
#       1 迫害を加える	て
#       1 返答を待つ
#       1 返答をする	の ね と は て
#       1 返報をする	んで
#       1 返事を聞く	で
#       1 返事を承る	で ながら て
#       1 返事を待つ	の て
#       1 返事をする	から と
#       1 返事をする	と から
#       1 返事をする	と が から に
#       1 近道を通る	のに から
#       1 辞職をする	が に
#       1 辞職をする
#       1 辞儀をする	から と に
#       1 辞儀をする	は て て に
#       1 辛苦をする
#       1 身震いをする	は て
#       1 ストライキを起す	て が に
#       1 購求を願う	て て
#       1 賭をする	から
#       1 賭をする
#       1 質問を受ける	すら
#       1 質問をする	のに か と は が
#       1 質問をする	から
#       1 質問をする	と は だけ に
#       1 質問をかける	て さえ な に か は
#       1 賛成を求める	て
#       1 貧乏をする
#       1 議論を弄する	て
#       1 議論を始める	は で
#       1 議論を好む
#       1 議論をする
#       1 警戒を解く
#       1 講釈を聞く	の から
#       1 講釈をする	の か て も に は
#       1 講釈をいる
#       1 講話を聞く	が
#       1 講話をする	は て
#       1 講義を行く	の て て て
#       1 講義をきく	の から
#       1 講義をする	の で
#       1 講義をする	で
#       1 談話を聞く	の は
#       1 談話を聞く	が
#       1 談話を聞く
#       1 談話を承る	て
#       1 談話を分る	の まで
#       1 談話をする	て ながら
#       1 談話をする	の が
#       1 談話をする	に
#       1 談話をつづける	と は て
#       1 談笑をする	は も て て と て
#       1 談判を聞く	が と は で て
#       1 談判を聞く
#       1 談判をする	の が と
#       1 談判をもつ
#       1 調和を計る	から
#       1 調和を忘れる
#       1 説法を受ける	て
#       1 説明を与える	じゃあ か と は て
#       1 説明をする	の
#       1 説教をやる	と は で て
#       1 説教をする	て
#       1 誤解を生ずる
#       1 話を進める	と は で
#       1 話を致す	が
#       1 話を聞く	の まで として
#       1 話を承る
#       1 話を切らす	て
#       1 話を伺う	て
#       1 話を仕る	も
#       1 話をする	ながら
#       1 話をする	って でも も
#       1 話をする	たり は て
#       1 話をする	から に
#       1 話をする	から
#       1 話をする	の は か
#       1 話をなさる	が
#       1 話をつづける	て も は
#       1 話をつづける	は
#       1 詰問を受ける
#       1 試験を受ける
#       1 試験をする	の に
#       1 証明をする
#       1 註釈を加える	ね と が
#       1 註釈をつける	よ と の
#       1 註釈をつける
#       1 診断をする	も から
#       1 診察を終る
#       1 診察を始める	か と
#       1 診察を受ける	て
#       1 許諾を至る	の など を
#       1 訪問を受ける	の も
#       1 訓練を与える	て は に
#       1 訓戒を垂れる	に
#       1 訓戒を加える	に
#       1 訓戒を与える	に
#       1 計算をする	は て で
#       1 解釈を聞く
#       1 観念をする	の
#       1 観察を述べる	て が で
#       1 観察を積む	の が
#       1 観察を怠る	の か な
#       1 観察を怠る	の て
#       1 観察を始める	から
#       1 観察をする
#       1 覚悟をする	くらい の と
#       1 覚悟をする	と
#       1 見物をする	から って
#       1 見物をする	で
#       1 要求をする	と
#       1 襲撃を蒙る	の
#       1 襲撃を受ける	に
#       1 製造を負う	の
#       1 衰弱を起す
#       1 行水を見下ろす	の と と て
#       1 行水を使う	は て が に
#       1 行水を使う	が に で
#       1 行水を使う
#       1 行動をとる
#       1 蚕食をてる
#       1 虚構をもつ
#       1 虐待をする	て
#       1 薨去を落ちる	の て
#       1 著述を居る	の て より
#       1 著述をする	が は で
#       1 著述をする
#       1 落着を告げる	て
#       1 苦難を忍ぶ	の
#       1 苦笑をする	て と は
#       1 苦心を買う	の と が
#       1 苦心をする	から
#       1 苦心をする	ば から も まで に は
#       1 苦心をなする
#       1 苦労をする	の たり
#       1 芝居をする	の で
#       1 自証をする
#       1 自覚を与る
#       1 自殺をする	たり
#       1 自殺をする	に
#       1 自殺をする
#       1 自慢をする	か と が
#       1 自慢をする
#       1 脱線をする	が に
#       1 胡坐をかく	で
#       1 絞殺を用いる	として
#       1 絞殺をする
#       1 結婚を申し込む	ぜ で に に
#       1 結婚を申し込む	に
#       1 結婚をする	て
#       1 結婚をやる
#       1 経験をする	の が から に は
#       1 経験をする	ば に は
#       1 経験をする
#       1 終了を告げる	を以て ん
#       1 紹介をする
#       1 約束を覚える	の
#       1 約束を守る
#       1 算段をする
#       1 算を乱す	が
#       1 答弁を得る	に対して
#       1 競争をやる	ば なり で
#       1 立見をする	は ながら
#       1 稽古を始める	の
#       1 稽古をやる
#       1 稽古をはじめる	の
#       1 祈念をこらす	ば と に に
#       1 砲撃を食う	の
#       1 研究を要する	て が で
#       1 研究を続ける	の て て
#       1 研究を尽す	と
#       1 研究をする	について
#       1 研究をやる	の て で は
#       1 矛盾をする	くらい と
#       1 真似をやる	の は て と
#       1 真似をする	と が も
#       1 相談を開く	で も で
#       1 相談を持ちかける	て か は に
#       1 相談をする	は に対して
#       1 相談をする	て から は
#       1 相談をする	で が
#       1 発達を致す	は が て
#       1 発達を立てる	か
#       1 発見をする
#       1 発展をする	の
#       1 病気を癒す
#       1 病気をする	から
#       1 病気をする	が も
#       1 病気をする	で
#       1 留守番を頼む
#       1 留守をする	の
#       1 由来を聞く	の
#       1 由来を案ずる	て
#       1 生活をする	が を
#       1 猶予を与える	の に
#       1 ご無沙汰を致す
#       1 火傷をする	と
#       1 演説をする	じゃ けども て
#       1 演説をする	でも で
#       1 演説をする	の で
#       1 演説をする	に
#       1 演説をなする	て ば で
#       1 満足を求める	は て
#       1 清聴を煩わす	の から て
#       1 深入りをする	まで は
#       1 活躍を試みる	て て
#       1 活動を見る	の
#       1 活動を名づける
#       1 洗髪を乾かす
#       1 洋行をする
#       1 注文をする
#       1 注意を願う
#       1 注意をする	から
#       1 注意をする	は に と
#       1 注意をする	と て
#       1 注意をする
#       1 治療をうける	で も は
#       1 油断をする
#       1 沈黙を守る	も くらい
#       1 沈黙を守る
#       1 決心を起す	の と
#       1 決心をする	で が
#       1 水泳をやる	は と て
#       1 比例を失する
#       1 欠伸をする	から て て
#       1 欠伸をする	と が
#       1 欠乏を感じる
#       1 案内を頼む	の が
#       1 案内を乞う	と から で
#       1 朝食を済ます	て に
#       1 いたずらを書く	も
#       1 暴行をする	に が
#       1 晩酌を始める	て から
#       1 昼寝をする	と は て
#       1 昼寝をする	が へ
#       1 昼寝をする
#       1 早死をする	は
#       1 早合点をする	ので が と
#       1 旅行をする	て
#       1 料理を食う	の
#       1 料理を奢る	の て でも
#       1 敬意を表する	に
#       1 教育を受ける
#       1 教育をくる	で
#       1 故障を挟む	に
#       1 攻撃を喰う	か と
#       1 支度をする	よ と
#       1 撰をする	けれど で と は て
#       1 撰をする	が て から
#       1 摩擦を与える	の て が は は と て に
#       1 損害を償う	の
#       1 探偵を比す
#       1 探偵を使う
#       1 探偵をする
#       1 掃除を始める	の は によって
#       1 掃除をする	と は に
#       1 掃除をする	の へ
#       1 掃除をはじめる	の で
#       1 捺印を願う	へ
#       1 挨拶を終る	の
#       1 挨拶をする	ので て
#       1 挨拶をする	の から
#       1 挨拶をする	の と は によって の
#       1 挨拶をする	と は
#       1 挨拶をする
#       1 抵抗をする
#       1 抗議を申し込む	ね と が
#       1 抗議を申し込む	て が
#       1 投書をする	て へ
#       1 批評を願う	から
#       1 批評を願う	の から は で
#       1 批評を願う	が て から
#       1 批評を加える	て な と が
#       1 手続きを踏む	の
#       1 戸締りをする
#       1 戦闘をする	と んで
#       1 戦争を挑む	に に
#       1 戦争をする	から は と
#       1 戦争をする	は でも
#       1 戦争をする
#       1 我慢を重ねる	に
#       1 我慢をする	の に
#       1 我儘を張れる
#       1 我儘を尽くす	に
#       1 我儘をする	が
#       1 懐中を抜く	の に
#       1 慰安を求める	の に
#       1 意味を聞かす	の
#       1 意味を究める	て
#       1 意味を示す	て よ と は
#       1 意味をする	の
#       1 意味をつける	は
#       1 意味をつける
#       1 想像をする	ながら
#       1 情死をする	と
#       1 悪戯をやる
#       1 息を凝らす	て
#       1 息を凝らす
#       1 息を入れる	て で
#       1 息をする	じゃ と は から と
#       1 息をつく	と は
#       1 怪我をする	て
#       1 思案を定める	まで
#       1 思案を定める	は は と
#       1 怒号をする	と ばかり
#       1 忠告を容れる	の
#       1 忠告を加える	よ と に
#       1 心配を願う	て も へ
#       1 心配を掛ける	て は て
#       1 心配を掛ける
#       1 心配をもつ
#       1 心配をかける	へ へ へ
#       1 御馳走を食う	と
#       1 御馳走を食う
#       1 御馳走を食べる
#       1 御馳走を食わせる	から に て に
#       1 御馳走を致す	の に
#       1 御馳走を来る	で
#       1 御馳走をする	の にて
#       1 御馳走をあるく	の て
#       1 後悔をする	けれど
#       1 待ったをする	から
#       1 往生をあがる	の
#       1 往来を通る	と
#       1 往来をあるく	が て
#       1 往来をあるく	て
#       1 往来をあるく
#       1 影響を与える	な に
#       1 彩色を見る	の
#       1 形容をなさる	や の て に
#       1 弁護をする	よ と
#       1 弁論をする	と は について か
#       1 弁解をする	とか
#       1 建築を眺める
#       1 座禅をする	まで
#       1 座禅をする	で で
#       1 広告を出す	と ば
#       1 平均を保つ	やいなや か か
#       1 平均をする
#       1 希望をする
#       1 差別を立てる	は まで も
#       1 左右を見る
#       1 居眠りをする	て
#       1 居眠りをする
#       1 尽力を仰ぐ	ので で に も
#       1 小便をする	て へ は
#       1 小便をする
#       1 小便をかける	に から
#       1 尊敬を払う	て に
#       1 尊敬を受ける	も として より
#       1 射撃を行う	に も から
#       1 専断を憤る	の
#       1 対面をする	と
#       1 対談をする	て に が と
#       1 対話を聞く	で
#       1 寂滅をごねる	の
#       1 容赦を願う	が は
#       1 定義を云う	の
#       1 定義をする	の て
#       1 宙返りをする	くらい から が
#       1 宙返りをする	と に は が
#       1 安心を求む	に
#       1 安心を欲する	も
#       1 学問をする	て
#       1 存在を認める	まで から
#       1 始末をつける	だけ で
#       1 いたずらを始める	と は て
#       1 妨害をする	と が
#       1 奉職をする	が へ
#       1 失礼を致す	は て は
#       1 失礼を致す
#       1 失礼をする	が
#       1 失望を受取る	の に
#       1 失敗をする
#       1 失恋をする	の て
#       1 大発見をなす	に
#       1 大息を洩らす	から なあ と は として
#       1 外出をする	でも
#       1 外出をする
#       1 変調を極める	の に
#       1 変化を起こす	の て に
#       1 変化を示す	ほど の
#       1 変化を生ずる	の を まで に
#       1 変化を生じる	に と
#       1 変化を求める	て
#       1 変化を来す	に
#       1 変化をあらわす	に
#       1 報道を逢う	て
#       1 報道をする
#       1 報知を致す	に
#       1 在宿を願う	から
#       1 困却をする	て を が
#       1 回向を受ける	は が から
#       1 回向をする
#       1 噂を致す	に は と で
#       1 噂をする	まで
#       1 噂をする	が に
#       1 噂をする
#       1 嘆願をする	まで
#       1 嘆息をする	たり だり
#       1 喧嘩を買う	ぞ と で
#       1 喧嘩を譲る
#       1 喧嘩を見る	の と
#       1 喧嘩を思う	と の によって
#       1 喧嘩を始める	は を
#       1 喧嘩をする	が から
#       1 問答をする	について の
#       1 問答をする
#       1 呼吸を飲み込む	て から
#       1 呼吸を計る
#       1 呼吸をいく	って も に
#       1 告訴を書く
#       1 告訴をする	から
#       1 吶喊を喰う	て と
#       1 含嗽をやる	で
#       1 同情を錬る	に
#       1 同情を起す	て
#       1 同情を表す	から ね と は に
#       1 同情を表す	に
#       1 同情を表す
#       1 同情を表する	に
#       1 同情を求める	ながら て と に
#       1 同情を持つ	に
#       1 同情を寄せる	から
#       1 同情をする	て に
#       1 同情をこめる	の
#       1 同宿をする	は から と
#       1 合奏をする	の に と
#       1 合図をする	て か と
#       1 取締をする	て
#       1 反響を起す	が
#       1 反応を呈す	と も か
#       1 反応をする	の も
#       1 参を食う	の
#       1 参を煎じる
#       1 厚遇を受ける	が まで
#       1 協賛を仰ぐ	の
#       1 協商を始める	は
#       1 午睡をする	て
#       1 区劃を立てる	の と で へ
#       1 北面を取り囲む	の に は として て
#       1 化粧を施す	は て
#       1 化粧をする	の に
#       1 化粧をする	で
#       1 化粧をする
#       1 勘定をする	て
#       1 勘定をする
#       1 動作を真似る	の
#       1 勉強をする	と て たり
#       1 加減を見る
#       1 創作をやる	の
#       1 刺激を取り去る
#       1 刺激を作る
#       1 刺激を与える	たり て に
#       1 刺激を与える	で だけ に
#       1 制裁を加える	ので
#       1 制裁をする	て に
#       1 判断をする	と は
#       1 出所をする	から でも な と
#       1 出所をする	の に
#       1 出入を禁ずる	の
#       1 処置を付ける	の
#       1 処分を受ける	の て
#       1 写生を力む	に従って
#       1 写生をする	から
#       1 冒険をする
#       1 再考を煩わす
#       1 入水をせしめる	て
#       1 克復を告げる	て
#       1 催促をしてやる	の て
#       1 倹約をする	と
#       1 借金をする
#       1 修養を力む	の から
#       1 修養をやる	て から て
#       1 修養をする	の
#       1 修行をする	の から
#       1 修行をする	の て
#       1 信用をおく
#       1 侮辱を受ける
#       1 依頼をする	の から と は
#       1 依頼をうける	の で
#       1 供を連れる
#       1 供給を仰ぐ	で も
#       1 供を拾う	くらい な
#       1 供を可愛がる	て に
#       1 作用を有する	の へ
#       1 作用を描き出す	の
#       1 体操をする	の から
#       1 体操をする	が に
#       1 体操をする	で
#       1 位置をする	の ば とか
#       1 会釈をする	に
#       1 休養を要する	と ども に
#       1 休養を要する	は に と
#       1 休養を要する	の は
#       1 休養を要する	は
#       1 休養を欲する	は
#       1 休養を得る	は に
#       1 休養を乞う	て は は に
#       1 仲間入りをする	の て
#       1 仮定を打つ
#       1 代理を勤める	の に
#       1 代理を務める	の は
#       1 他言をする
#       1 仕付を受ける	ばかり じゃ
#       1 仕事を片付ける	から と
#       1 仕事をする	し て から は
#       1 交際をする	て から て から は
#       1 交換をやる	の
#       1 了見を起す	など という
#       1 了見を起す	で も ながら
#       1 了見を抱く	と
#       1 乱暴を働く	て
#       1 乱暴をかく	から て
#       1 主宰をもつ	の
#       1 世話をする	の
#       1 不足を訴える	の
#       1 不足を云う	で
#       1 下宿を出る	の ので て
#       1 下宿をする	が に
#       1 一段落を告げる	も で
#       1 一段落を告げる	が
#       1 一座を見廻る
#       1 いたずらをする	は で
#       1 いたずらをする
#       1 あかんべえをする
#       1 ストライキをしでかす	や から て

# %% [markdown]
# ## 48. 名詞から根へのパスの抽出

# %%
for chList in result[0:100]:
    for ch in chList:
        if ('名詞' not in [x.pos for x in ch.morphs]) or ch.dst==-1:continue
        res=[]
        tmpCh=ch
        res.append(''.join([x.surface for x in list(filter(lambda x: x.pos != '記号',ch.morphs))]))
        while tmpCh.dst!=-1:
            dstCh=chList[tmpCh.dst]
            res.append(''.join([x.surface for x in list(filter(lambda x: x.pos != '記号',dstCh.morphs))]))
            tmpCh=dstCh

        print(' -> '.join(res))
# Out:
# 吾輩は -> 猫である
# 名前は -> 無い
# どこで -> 生れたか -> つかぬ
# 見当が -> つかぬ
# 何でも -> 薄暗い -> 所で -> 泣いて -> 記憶している
# 所で -> 泣いて -> 記憶している
# ニャーニャー -> 泣いて -> 記憶している
# いた事だけは -> 記憶している
# 吾輩は -> 見た
# ここで -> 始めて -> 人間という -> ものを -> 見た
# 人間という -> ものを -> 見た
# ものを -> 見た
# あとで -> 聞くと -> 種族であったそうだ
# それは -> 種族であったそうだ
# 書生という -> 人間中で -> 種族であったそうだ
# 人間中で -> 種族であったそうだ
# 一番 -> 獰悪な -> 種族であったそうだ
# 獰悪な -> 種族であったそうだ
# 書生というのは -> 話である
# 我々を -> 捕えて -> 煮て -> 食うという -> 話である
# 当時は -> なかったから -> 思わなかった
# 何という -> 考も -> なかったから -> 思わなかった
# 考も -> なかったから -> 思わなかった
# 彼の -> 掌に -> 載せられて -> 持ち上げられた -> 時 -> フワフワした -> 感じが -> あったばかりである
# 掌に -> 載せられて -> 持ち上げられた -> 時 -> フワフワした -> 感じが -> あったばかりである
# スーと -> 持ち上げられた -> 時 -> フワフワした -> 感じが -> あったばかりである
# 時 -> フワフワした -> 感じが -> あったばかりである
# 感じが -> あったばかりである
# 掌の -> 上で -> 落ちついて -> 見たのが -> 人間という -> ものの -> 見始であろう
# 上で -> 落ちついて -> 見たのが -> 人間という -> ものの -> 見始であろう
# 書生の -> 顔を -> 見たのが -> 人間という -> ものの -> 見始であろう
# 顔を -> 見たのが -> 人間という -> ものの -> 見始であろう
# 見たのが -> 人間という -> ものの -> 見始であろう
# 人間という -> ものの -> 見始であろう
# ものの -> 見始であろう
# 時 -> ものだと -> 思った -> 感じが -> 残っている
# 妙な -> ものだと -> 思った -> 感じが -> 残っている
# ものだと -> 思った -> 感じが -> 残っている
# 感じが -> 残っている
# 今でも -> 残っている
# 第一毛をもって -> 装飾されべきはずの -> 顔が -> つるつるして -> 薬缶だ
# 装飾されべきはずの -> 顔が -> つるつるして -> 薬缶だ
# 顔が -> つるつるして -> 薬缶だ
# その後 -> 逢ったが -> ない
# 猫にも -> 逢ったが -> ない
# 片輪には -> ない
# 一度も -> 出会わした -> 事が -> ない
# 事が -> ない
# 顔の -> 真中が -> 突起している
# 真中が -> 突起している
# その穴の -> 中から -> 吹く
# 中から -> 吹く
# ぷうぷうと煙を -> 吹く
# 咽せぽくて -> 弱った
# これが -> ものである -> 事は -> 知った
# 人間の -> 飲む -> 煙草という -> ものである -> 事は -> 知った
# 煙草という -> ものである -> 事は -> 知った
# ものである -> 事は -> 知った
# 事は -> 知った
# 頃 -> 知った
# 書生の -> 掌の -> 裏で -> 坐って -> おったが -> 運転し始めた
# 掌の -> 裏で -> 坐って -> おったが -> 運転し始めた
# 裏で -> 坐って -> おったが -> 運転し始めた
# 心持に -> 坐って -> おったが -> 運転し始めた
# 非常な -> 速力で -> 運転し始めた
# 速力で -> 運転し始めた
# 書生が -> 動くのか -> 動くのか -> 分らないが -> 廻る
# 動くのか -> 動くのか -> 分らないが -> 廻る
# 自分だけが -> 動くのか -> 分らないが -> 廻る
# 動くのか -> 分らないが -> 廻る
# 眼が -> 廻る
# 胸が -> 悪くなる
# 音が -> して -> 出た
# 眼から -> 出た
# 火が -> 出た
# それまでは -> 記憶しているが -> 分らない
# 記憶しているが -> 分らない
# あとは -> 分らない
# 何の -> 事やら -> 分らない
# 事やら -> 分らない
# 気が -> 付いて -> 見ると -> いない
# 書生は -> いない
# たくさん -> おった -> 兄弟が -> 見えぬ
# 兄弟が -> 見えぬ
# 一疋も -> 見えぬ
# 肝心の -> 母親さえ -> 隠してしまった
# 母親さえ -> 隠してしまった
# 姿を -> 隠してしまった
# 上今までの -> 所とは -> 違って -> 明るい
# 所とは -> 違って -> 明るい
# 眼を -> 明いていられぬくらいだ
# 何でも -> おかしいと -> 痛い
# 容子が -> おかしいと -> 痛い
# 非常に -> 痛い
# 吾輩は -> 棄てられたのである
# 藁の -> 上から -> 棄てられたのである
# 上から -> 棄てられたのである
# 急に -> 棄てられたのである
# 笹原の -> 中へ -> 棄てられたのである
# 中へ -> 棄てられたのである
# 思いで -> 這い出すと -> ある
# 笹原を -> 這い出すと -> ある
# 向うに -> ある
# 池が -> ある
# 吾輩は -> 見た
# 池の -> 前に -> 坐って -> したら -> よかろうと -> 考えて -> 見た
# 前に -> 坐って -> したら -> よかろうと -> 考えて -> 見た
# これという -> 分別も -> 出ない
# 分別も -> 出ない
# 書生がまた -> 来てくれるかと -> 考え付いた
# 迎に -> 来てくれるかと -> 考え付いた
# ニャー -> ニャーと -> 試みに -> やって -> 見たが -> 来ない
# ニャーと -> 試みに -> やって -> 見たが -> 来ない
# 試みに -> やって -> 見たが -> 来ない
# 誰も -> 来ない
# 池の -> 上を -> 渡って -> かかる
# 上を -> 渡って -> かかる
# 風が -> 渡って -> かかる
# 日が -> かかる
# 暮れ -> かかる
# 腹が -> 減って来た
# 非常に -> 減って来た
# 声が -> 出ない
# 仕方が -> ない -> 廻り始めた
# 何でも -> 廻り始めた
# 食物の -> ある -> 所まで -> ある -> 廻り始めた
# 所まで -> ある -> 廻り始めた
# 決心を -> して -> そろり -> 廻り始めた
# 池を -> 廻り始めた
# 左りに -> 廻り始めた
# 非常に -> 苦しい
# そこを -> 我慢して -> 這って行くと -> 出た
# 我慢して -> 這って行くと -> 出た
# 無理やりに -> 這って行くと -> 出た
# 事で -> 出た
# 人間臭い -> 所へ -> 出た
# 所へ -> 出た
# ここへ -> 這入ったら -> なると -> 思って -> もぐり込んだ
# 竹垣の -> 崩れた -> 穴から -> もぐり込んだ
# 穴から -> もぐり込んだ
# 邸内に -> もぐり込んだ
# 縁は -> もので -> 餓死したかも知れんのである
# 不思議な -> もので -> 餓死したかも知れんのである
# もので -> 餓死したかも知れんのである
# 竹垣が -> 破れていなかったなら -> 餓死したかも知れんのである
# 吾輩は -> 餓死したかも知れんのである
# 路傍に -> 餓死したかも知れんのである
# 一樹の -> 蔭とは -> 云った -> ものだ
# 蔭とは -> 云った -> ものだ
# 垣根の -> 穴は -> なっている
# 穴は -> なっている
# 今日に -> 至るまで -> 訪問する -> 時の -> 通路に -> なっている
# 吾輩が -> 訪問する -> 時の -> 通路に -> なっている
# 隣家の -> 三毛を -> 訪問する -> 時の -> 通路に -> なっている
# 三毛を -> 訪問する -> 時の -> 通路に -> なっている
# 訪問する -> 時の -> 通路に -> なっている
# 時の -> 通路に -> なっている
# 通路に -> なっている
# 邸へは -> 忍び込んだものの -> 分らない
# 先 -> 善いか -> 分らない
# うちに -> 暗くなる -> 減る -> 寒し -> 降って来るという -> 始末で -> 出来なくなった
# 腹は -> 減る -> 寒し -> 降って来るという -> 始末で -> 出来なくなった
# 寒さは -> 寒し -> 降って来るという -> 始末で -> 出来なくなった
# 雨が -> 降って来るという -> 始末で -> 出来なくなった
# 始末で -> 出来なくなった
# 一刻の -> 猶予が -> 出来なくなった
# 猶予が -> 出来なくなった
# 仕方が -> ないから -> 明るくて -> 暖かそうな -> 方へ -> あるいて行く
# 暖かそうな -> 方へ -> あるいて行く
# 方へ -> あるいて行く
# 方へと -> あるいて行く
# 今から -> 考えると -> おったのだ
# 時は -> おったのだ
# 家の -> 内に -> 這入って -> おったのだ
# 内に -> 這入って -> おったのだ
# ここで -> 遭遇したのである
# 吾輩は -> 遭遇したのである
# 彼の -> 書生以外の -> 人間を -> 見るべき -> 機会に -> 遭遇したのである
# 書生以外の -> 人間を -> 見るべき -> 機会に -> 遭遇したのである
# 人間を -> 見るべき -> 機会に -> 遭遇したのである
# 機会に -> 遭遇したのである
# 第一に -> 逢ったのが -> おさんである
# 逢ったのが -> おさんである
# これは -> 抛り出した
# 前の -> 書生より -> 見るや -> 抛り出した
# 書生より -> 見るや -> 抛り出した
# 乱暴な -> 方で -> 見るや -> 抛り出した
# 方で -> 見るや -> 抛り出した
# 吾輩を -> 見るや -> 抛り出した
# 否やいきなり -> つかんで -> 抛り出した
# 頸筋を -> つかんで -> 抛り出した
# 表へ -> 抛り出した
# これは -> 駄目だと -> 思ったから -> 任せていた
# 駄目だと -> 思ったから -> 任せていた
# 眼を -> ねぶって -> 任せていた
# 運を -> 任せていた
# 天に -> 任せていた
# ひもじいのと -> 寒いのには -> 出来ん
# 寒いのには -> 出来ん
# 我慢が -> 出来ん
# 吾輩は -> 這い上った
# おさんの -> 隙を -> 見て -> 這い上った
# 隙を -> 見て -> 這い上った
# 台所へ -> 這い上った
# 吾輩は -> 這い上り -> 投げ出され -> 記憶している
# 何でも -> 繰り返したのを -> 記憶している
# 事を -> 繰り返したのを -> 記憶している
# 四五遍 -> 繰り返したのを -> 記憶している
# 繰り返したのを -> 記憶している
# 時に -> 云う -> 者は -> いやになった
# おさんと -> 云う -> 者は -> いやになった
# 者は -> いやになった
# この間 -> 偸んで -> してやってから -> 下りた
# おさんの -> 三馬を -> 偸んで -> してやってから -> 下りた
# 三馬を -> 偸んで -> してやってから -> 下りた
# 偸んで -> してやってから -> 下りた
# 返報を -> してやってから -> 下りた
# 胸の -> 痞が -> 下りた
# 痞が -> 下りた
# 吾輩が -> つまみ出されようとした -> ときに -> 出て来た
# 最後に -> つまみ出されようとした -> ときに -> 出て来た
# ときに -> 出て来た
# 家の -> 主人が -> 出て来た
# 主人が -> 出て来た
# 何だと -> いいながら -> 出て来た
# 下女は -> 困りますと -> いう
# 吾輩を -> ぶら下げて -> 出しても -> 困りますと -> いう
# 主人の -> 方へ -> 向けて -> 出しても -> 困りますと -> いう
# 方へ -> 向けて -> 出しても -> 困りますと -> いう
# 宿なしの -> 小猫が -> 出しても -> 出しても -> 困りますと -> いう
# 小猫が -> 出しても -> 出しても -> 困りますと -> いう
# 御台所へ -> 上って来て -> 困りますと -> いう
# 主人は -> おったが -> 這入ってしまった
# 鼻の -> 下の -> 黒い -> 毛を -> 撚りながら -> 眺めて -> おったが -> 這入ってしまった
# 下の -> 黒い -> 毛を -> 撚りながら -> 眺めて -> おったが -> 這入ってしまった
# 毛を -> 撚りながら -> 眺めて -> おったが -> 這入ってしまった
# 吾輩の -> 顔を -> 眺めて -> おったが -> 這入ってしまった
# 顔を -> 眺めて -> おったが -> 這入ってしまった
# そんなら -> 置いてやれといったまま -> 這入ってしまった
# 内へ -> 置いてやれといったまま -> 這入ってしまった
# 置いてやれといったまま -> 這入ってしまった
# 奥へ -> 這入ってしまった
# 主人は -> 見えた
# 口を -> 聞かぬ -> 人と -> 見えた
# 人と -> 見えた
# 下女は -> 抛り出した
# 口惜しそうに -> 抛り出した
# 吾輩を -> 抛り出した
# 台所へ -> 抛り出した
# 吾輩は -> したのである
# 家を -> 極める -> 事に -> したのである
# 自分の -> 住家と -> 極める -> 事に -> したのである
# 住家と -> 極める -> 事に -> したのである
# 事に -> したのである
# 吾輩の -> 主人は -> ない
# 主人は -> ない
# 滅多に -> 合せる -> 事が -> ない
# 吾輩と -> 合せる -> 事が -> ない
# 顔を -> 合せる -> 事が -> ない
# 事が -> ない
# 職業は -> 教師だそうだ
# 学校から -> 帰ると -> ぎりほとんど出て来る -> 事が -> ない
# 終日 -> 這入った -> ぎりほとんど出て来る -> 事が -> ない
# 書斎に -> 這入った -> ぎりほとんど出て来る -> 事が -> ない
# ぎりほとんど出て来る -> 事が -> ない
# 事が -> ない
# 家の -> ものは -> 勉強家だと -> 思っている
# ものは -> 勉強家だと -> 思っている
# 大変な -> 勉強家だと -> 思っている
# 勉強家だと -> 思っている
# 当人も -> ごとく -> 見せている
# 勉強家であるかの -> ごとく -> 見せている
# うちの -> ものが -> いうような -> 勤勉家ではない
# ものが -> いうような -> 勤勉家ではない
# いうような -> 勤勉家ではない
# 吾輩は -> 見るが -> ある
# 忍び足に -> 覗いて -> 見るが -> ある
# 彼の -> 書斎を -> 覗いて -> 見るが -> ある
# 書斎を -> 覗いて -> 見るが -> ある
# 彼は -> ある
# 昼寝を -> している -> 事が -> ある
# 事が -> ある
# 本の -> 上に -> たらしている
# 上に -> たらしている
# 涎を -> たらしている
# 彼は -> あらわしている
# 胃弱で -> 帯びて -> あらわしている
# 皮膚の -> 色が -> 帯びて -> あらわしている
# 色が -> 帯びて -> あらわしている
# 黄色を -> 帯びて -> あらわしている
# 弾力の -> ない -> 徴候を -> あらわしている
# 不活溌な -> 徴候を -> あらわしている
# 徴候を -> あらわしている
# 癖に -> 食う
# 大飯を -> 食う
# 大飯を -> 食った -> 後で -> 飲む
# 後で -> 飲む
# タカジヤスターゼを -> 飲む
# 後で -> ひろげる
# 書物を -> ひろげる
# 二三ページ -> 読むと -> 眠くなる
# 涎を -> 垂らす
# 本の -> 上へ -> 垂らす
# 上へ -> 垂らす
# これが -> 繰り返す -> 日課である
# 彼の -> 毎夜 -> 繰り返す -> 日課である
# 毎夜 -> 繰り返す -> 日課である
# 吾輩は -> ある
# 猫ながら -> 考える -> 事が -> ある
# 事が -> ある
# 教師という -> ものは -> ものだ
# ものは -> ものだ
# 楽な -> ものだ
# 人間と -> 生れたら -> なるに -> 限る
# 教師と -> なるに -> 限る
# ものなら -> ないと
# 猫にでも -> 出来ぬ -> 事は -> ないと
# 事は -> ないと
# 主人に -> 云わせると -> ないそうで -> 鳴らしている
# 教師ほど -> つらい -> ものは -> ないそうで -> 鳴らしている
# ものは -> ないそうで -> 鳴らしている
# ないそうで -> 鳴らしている
# 彼は -> 鳴らしている
# 友達が -> 来る -> 度に -> 鳴らしている
# 度に -> 鳴らしている
# かんとか -> 不平を -> 鳴らしている
# 不平を -> 鳴らしている
# 吾輩が -> 住み込んだ -> 当時は -> 不人望であった
# 家へ -> 住み込んだ -> 当時は -> 不人望であった
# 当時は -> 不人望であった
# 主人以外の -> ものには -> 不人望であった
# ものには -> 不人望であった
# どこへ -> 行っても -> 跳ね付けられて -> してくれ -> なかった
# 相手に -> してくれ -> なかった
# 手が -> なかった
# 珍重されなかったかは -> 分る
# 今日に -> 至るまで -> つけてくれないのでも -> 分る
# 名前さえ -> つけてくれないのでも -> 分る
# つけてくれないのでも -> 分る
# 吾輩は -> ないから -> つとめた
# 仕方が -> ないから -> つとめた
# 限り -> 入れてくれた -> 主人の -> 傍に -> いる -> 事を -> つとめた
# 吾輩を -> 入れてくれた -> 主人の -> 傍に -> いる -> 事を -> つとめた
# 主人の -> 傍に -> いる -> 事を -> つとめた
# 傍に -> いる -> 事を -> つとめた
# 事を -> つとめた
# 朝主人が -> 読む -> ときは -> 乗る
# 新聞を -> 読む -> ときは -> 乗る
# ときは -> 乗る
# 彼の -> 膝の -> 上に -> 乗る
# 膝の -> 上に -> 乗る
# 上に -> 乗る
# 彼が -> する -> ときは -> 乗る
# 昼寝を -> する -> ときは -> 乗る
# ときは -> 乗る
# 背中に -> 乗る
# これは -> やむを得んのである
# 主人が -> 好きという -> 訳ではないが -> なかったから -> やむを得んのである
# 好きという -> 訳ではないが -> なかったから -> やむを得んのである
# 訳ではないが -> なかったから -> やむを得んのである
# 別に -> なかったから -> やむを得んのである
# 構い手が -> なかったから -> やむを得んのである
# その後 -> した
# 経験の -> 上 -> した
# 上 -> した
# 朝は -> した
# 飯櫃の -> 上 -> した
# 上 -> した
# 夜は -> した
# 炬燵の -> 上 -> した
# 上 -> した
# 天気の -> よい -> 昼は -> した
# 昼は -> した
# 椽側へ -> 寝る -> 事と -> した
# 事と -> した
# 一番 -> 好いのは -> 事である
# 心持の -> 好いのは -> 事である
# 好いのは -> 事である
# 夜に -> 入って -> ねる -> 事である
# ここの -> うちの -> 小供の -> 寝床へ -> もぐり込んで -> ねる -> 事である
# うちの -> 小供の -> 寝床へ -> もぐり込んで -> ねる -> 事である
# 小供の -> 寝床へ -> もぐり込んで -> ねる -> 事である
# 寝床へ -> もぐり込んで -> ねる -> 事である
# いっしょに -> ねる -> 事である
# 小供というのは -> 寝る
# 五つと -> 三つで -> なると -> 寝る
# 三つで -> なると -> 寝る
# 夜に -> なると -> 寝る
# 二人が -> 寝る
# 一つ -> 寝る
# 床へ -> 入って -> 寝る
# 一間へ -> 寝る
# 吾輩は -> 割り込むのであるが -> なる
# いつでも -> 見出して -> 割り込むのであるが -> なる
# 彼等の -> 中間に -> 見出して -> 割り込むのであるが -> なる
# 中間に -> 見出して -> 割り込むのであるが -> なる
# 己れを -> 見出して -> 割り込むのであるが -> なる
# 容るべき -> 余地を -> 見出して -> 割り込むのであるが -> なる
# 余地を -> 見出して -> 割り込むのであるが -> なる
# 割り込むのであるが -> なる
# 運悪く -> 醒ますが -> なる
# 小供の -> 一人が -> 醒ますが -> なる
# 一人が -> 醒ますが -> なる
# 眼を -> 醒ますが -> なる
# 最後大変な -> 事に -> なる
# 事に -> なる
# 小供は—— -> 泣き出すのである
# 方が -> 来た -> 猫が -> 来たと -> いって -> 泣き出すのである
# 質が -> 来た -> 猫が -> 来たと -> いって -> 泣き出すのである
# わるい——猫が -> 来た -> 猫が -> 来たと -> いって -> 泣き出すのである
# 猫が -> 来たと -> いって -> 泣き出すのである
# 夜中でも -> 泣き出すのである
# 何でも -> 泣き出すのである
# 声で -> 泣き出すのである
# 例の -> 神経胃弱性の -> 主人は -> 飛び出してくる
# 神経胃弱性の -> 主人は -> 飛び出してくる
# 主人は -> 飛び出してくる
# 眼を -> さまして -> 飛び出してくる
# 次の -> 部屋から -> 飛び出してくる
# 部屋から -> 飛び出してくる
# せんだってなどは -> 叩かれた
# 物指で -> 叩かれた
# 尻ぺたをひどく -> 叩かれた
# 吾輩は -> 断言せざるを得ないようになった
# 人間と -> 同居して -> 観察すれば -> する -> ほど -> 断言せざるを得ないようになった
# 同居して -> 観察すれば -> する -> ほど -> 断言せざるを得ないようになった
# 彼等を -> 観察すれば -> する -> ほど -> 断言せざるを得ないようになった
# 観察すれば -> する -> ほど -> 断言せざるを得ないようになった
# 彼等は -> 断言せざるを得ないようになった
# 我儘な -> ものだと -> 断言せざるを得ないようになった
# ものだと -> 断言せざるを得ないようになった

# %% [markdown]
# ## 49. 名詞間の係り受けパスの抽出

# %%
import itertools
# methodlize 48
def chLsToRoot(startCh):
    res=[]
    tmpCh=startCh
    res.append(tmpCh)
    while tmpCh.dst!=-1:
        dstCh=chList[tmpCh.dst]
        res.append(dstCh)
        tmpCh=dstCh
    return res

for chList in result[0:100]:
    pairs=list(itertools.combinations([idx for idx,ch in enumerate(chList) if '名詞' in [x.pos for x in ch.morphs]], 2))
    if len(pairs)==0:continue
    for p in pairs:
        i,j=p[0],p[1]
        chIds2Root=[chList.index(ch) for ch in chLsToRoot(chList[i])]
        if chList.index(chList[j]) in chIds2Root:
            mosLs=[ch.morphs for ch in chList[i:j+1]]
            midArr=[''.join([x.surface for x in list(filter(lambda x: x.pos != '記号',mos))]) for mos in mosLs[1:-1]]
            repI=['X' if m.pos=='名詞' else m.surface for m in mosLs[0]]
            print(' -> '.join([''.join(repI)]+midArr+['Y']))
        else:
            k=sorted(list(set([chList.index(ch) for ch in chLsToRoot(chList[j])]) & set(chIds2Root)))[0]
            kInJ=[chList.index(ch) for ch in chLsToRoot(chList[j])].index(sorted(list(set([chList.index(ch) for ch in chLsToRoot(chList[j])]) & set(chIds2Root)))[0])
            repI=['X' if m.pos=='名詞' else m.surface for m in chList[i].morphs]
            repJ=['Y' if m.pos=='名詞' else m.surface for m in chList[j].morphs]
            mosLs=[ch.morphs for ch in chLsToRoot(chList[j])]
            midTxt=[''.join([x.surface for x in list(filter(lambda x: x.pos != '記号',mos))]) for mos in mosLs[1:kInJ]]
            print(''.join(repI),
                  ' -> '.join([''.join(repJ)]+midTxt),
                  ''.join([x.surface for x in list(filter(lambda x: x.pos != '記号',chList[k].morphs))]),
                  sep=' | '
                 )
# Out:
# Xは -> Y
# 　Xで | Yが | つかぬ
# Xでも -> 薄暗い -> じめじめした -> Y
# Xでも | Y | 泣いて
# Xでも | Yだけは | 記憶している
# Xでも -> 薄暗い -> じめじめした -> 所で -> ニャーニャー -> 泣いて -> いた事だけは -> Y
# Xで | Y | 泣いて
# Xで | Yだけは | 記憶している
# Xで -> ニャーニャー -> 泣いて -> いた事だけは -> Y
# X | Yだけは | 記憶している
# X -> 泣いて -> いた事だけは -> Y
# Xだけは -> Y
# Xは | Yで -> 始めて -> 人間という -> ものを | 見た
# Xは | Yという -> ものを | 見た
# Xは | Yを | 見た
# Xで -> 始めて -> Y
# Xで -> 始めて -> 人間という -> Y
# Xという -> Y
# Xで | Yは | 種族であったそうだ
# Xで | Yという -> 人間中で | 種族であったそうだ
# Xで | YYで | 種族であったそうだ
# Xで | Y -> 獰悪な | 種族であったそうだ
# Xで | Yな | 種族であったそうだ
# Xで -> 聞くと -> それは -> 書生という -> 人間中で -> 一番 -> 獰悪な -> Y
# Xは | Yという -> 人間中で | 種族であったそうだ
# Xは | YYで | 種族であったそうだ
# Xは | Y -> 獰悪な | 種族であったそうだ
# Xは | Yな | 種族であったそうだ
# Xは -> 書生という -> 人間中で -> 一番 -> 獰悪な -> Y
# Xという -> Y
# Xという | Y -> 獰悪な | 種族であったそうだ
# Xという | Yな | 種族であったそうだ
# Xという -> 人間中で -> 一番 -> 獰悪な -> Y
# XXで | Y -> 獰悪な | 種族であったそうだ
# XXで | Yな | 種族であったそうだ
# XXで -> 一番 -> 獰悪な -> Y
# X -> Y
# X -> 獰悪な -> Y
# Xな -> Y
# XというXは | Yを -> 捕えて -> 煮て -> 食うという | 話である
# XというXは -> 時々 -> 我々を -> 捕えて -> 煮て -> 食うという -> Y
# Xを -> 捕えて -> 煮て -> 食うという -> Y
# Xは | Yという -> 考も | なかったから
# Xは | Yも | なかったから
# Xという -> Y
# Xの -> Y
# Xの | Yと | 持ち上げられた
# Xの -> 掌に -> 載せられて -> スーと -> 持ち上げられた -> Y
# Xの -> 掌に -> 載せられて -> スーと -> 持ち上げられた -> 時 -> 何だか -> フワフワした -> Y
# Xに | Yと | 持ち上げられた
# Xに -> 載せられて -> スーと -> 持ち上げられた -> Y
# Xに -> 載せられて -> スーと -> 持ち上げられた -> 時 -> 何だか -> フワフワした -> Y
# Xと -> 持ち上げられた -> Y
# Xと -> 持ち上げられた -> 時 -> 何だか -> フワフワした -> Y
# X -> 何だか -> フワフワした -> Y
# Xの -> Y
# Xの | Yの -> 顔を | 見たのが
# Xの | Yを | 見たのが
# Xの -> 上で -> 少し -> 落ちついて -> 書生の -> 顔を -> Y
# Xの -> 上で -> 少し -> 落ちついて -> 書生の -> 顔を -> 見たのが -> いわゆる -> Y
# Xの -> 上で -> 少し -> 落ちついて -> 書生の -> 顔を -> 見たのが -> いわゆる -> 人間という -> Y
# Xの -> 上で -> 少し -> 落ちついて -> 書生の -> 顔を -> 見たのが -> いわゆる -> 人間という -> ものの -> Y
# Xで | Yの -> 顔を | 見たのが
# Xで | Yを | 見たのが
# Xで -> 少し -> 落ちついて -> 書生の -> 顔を -> Y
# Xで -> 少し -> 落ちついて -> 書生の -> 顔を -> 見たのが -> いわゆる -> Y
# Xで -> 少し -> 落ちついて -> 書生の -> 顔を -> 見たのが -> いわゆる -> 人間という -> Y
# Xで -> 少し -> 落ちついて -> 書生の -> 顔を -> 見たのが -> いわゆる -> 人間という -> ものの -> Y
# Xの -> Y
# Xの -> 顔を -> Y
# Xの -> 顔を -> 見たのが -> いわゆる -> Y
# Xの -> 顔を -> 見たのが -> いわゆる -> 人間という -> Y
# Xの -> 顔を -> 見たのが -> いわゆる -> 人間という -> ものの -> Y
# Xを -> Y
# Xを -> 見たのが -> いわゆる -> Y
# Xを -> 見たのが -> いわゆる -> 人間という -> Y
# Xを -> 見たのが -> いわゆる -> 人間という -> ものの -> Y
# 見たXが -> いわゆる -> Y
# 見たXが -> いわゆる -> 人間という -> Y
# 見たXが -> いわゆる -> 人間という -> ものの -> Y
# Xという -> Y
# Xという -> ものの -> Y
# Xの -> Y
# X | Yな | ものだと
# X -> 妙な -> Y
# X -> 妙な -> ものだと -> 思った -> Y
# X | Yでも | 残っている
# Xな -> Y
# Xな -> ものだと -> 思った -> Y
# Xな | Yでも | 残っている
# Xだと -> 思った -> Y
# Xだと | Yでも | 残っている
# Xが | Yでも | 残っている
# 第XXをもって -> Y
# 第XXをもって -> 装飾されべきはずの -> Y
# 第XXをもって -> 装飾されべきはずの -> 顔が -> つるつるして -> まるで -> Y
# XされべきXの -> Y
# XされべきXの -> 顔が -> つるつるして -> まるで -> Y
# Xが -> つるつるして -> まるで -> Y
# X | Yにも | 逢ったが
# X | 片Yには | ない
# X | YYも -> 出会わした -> 事が | ない
# X | Yが | ない
# Xにも | 片Yには | ない
# Xにも | YYも -> 出会わした -> 事が | ない
# Xにも | Yが | ない
# 片Xには | YYも -> 出会わした -> 事が | ない
# 片Xには | Yが | ない
# XXも -> 出会わした -> Y
# Xの -> Y
# Xの -> 真中が -> あまりに -> Y
# Xが -> あまりに -> Y
# そのXの -> Y
# そのXの | YYを | 吹く
# Xから | YYを | 吹く
# Xが | Yの -> 飲む -> 煙草という | ものである
# Xが | Yという | ものである
# Xが -> 人間の -> 飲む -> 煙草という -> Y
# Xが -> 人間の -> 飲む -> 煙草という -> ものである -> Y
# Xが | Y | 知った
# Xの -> 飲む -> Y
# Xの -> 飲む -> 煙草という -> Y
# Xの -> 飲む -> 煙草という -> ものである -> Y
# Xの | Y | 知った
# Xという -> Y
# Xという -> ものである -> Y
# Xという | Y | 知った
# Xである -> Y
# Xである | Y | 知った
# Xは | Y | 知った
# Xの -> Y
# Xの -> 掌の -> Y
# Xの | Yに | 坐って
# Xの | Yな -> 速力で | 運転し始めた
# Xの | Yで | 運転し始めた
# Xの -> 掌の -> 裏で -> しばらくは -> よい -> 心持に -> 坐って -> おったが -> しばらく -> すると -> 非常な -> 速力で -> Y
# Xの -> Y
# Xの | Yに | 坐って
# Xの | Yな -> 速力で | 運転し始めた
# Xの | Yで | 運転し始めた
# Xの -> 裏で -> しばらくは -> よい -> 心持に -> 坐って -> おったが -> しばらく -> すると -> 非常な -> 速力で -> Y
# Xで | Yに | 坐って
# Xで | Yな -> 速力で | 運転し始めた
# Xで | Yで | 運転し始めた
# Xで -> しばらくは -> よい -> 心持に -> 坐って -> おったが -> しばらく -> すると -> 非常な -> 速力で -> Y
# Xに | Yな -> 速力で | 運転し始めた
# Xに | Yで | 運転し始めた
# Xに -> 坐って -> おったが -> しばらく -> すると -> 非常な -> 速力で -> Y
# Xな -> Y
# Xな -> 速力で -> Y
# Xで -> Y
# Xが -> Y
# Xが | Yだけが | 動くのか
# Xが -> 動くのか -> 自分だけが -> Y
# Xが | Yが | 廻る
# 動くXか | Yだけが | 動くのか
# 動くXか -> 自分だけが -> Y
# 動くXか | Yが | 廻る
# Xだけが -> Y
# Xだけが | Yが | 廻る
# 動くXか | Yが | 廻る
# Xが | Yから | 出た
# Xが | Yが | 出た
# Xから | Yが | 出た
# Xまでは -> Y
# Xまでは | Yは | 分らない
# Xまでは | Yの -> 事やら | 分らない
# Xまでは | Yやら | 分らない
# Xしているが | Yは | 分らない
# Xしているが | Yの -> 事やら | 分らない
# Xしているが | Yやら | 分らない
# Xは | Yの -> 事やら | 分らない
# Xは | Yやら | 分らない
# Xの -> Y
# Xが | Yは | いない
# X -> おった -> Y
# X | Yも | 見えぬ
# Xが | Yも | 見えぬ
# Xの -> Y
# Xの | Yを | 隠してしまった
# Xさえ | Yを | 隠してしまった
# Xまでの -> Y
# Xでも | Yが | おかしいと
# Xでも | Yに | 痛い
# Xが | Yに | 痛い
# Xは | Yの -> 上から | 棄てられたのである
# Xは | Yから | 棄てられたのである
# Xは | Yに | 棄てられたのである
# Xは | Yの -> 中へ | 棄てられたのである
# Xは | Yへ | 棄てられたのである
# Xは -> 藁の -> 上から -> 急に -> 笹原の -> 中へ -> Y
# Xの -> Y
# Xの | Yに | 棄てられたのである
# Xの | Yの -> 中へ | 棄てられたのである
# Xの | Yへ | 棄てられたのである
# Xの -> 上から -> 急に -> 笹原の -> 中へ -> Y
# Xから | Yに | 棄てられたのである
# Xから | Yの -> 中へ | 棄てられたのである
# Xから | Yへ | 棄てられたのである
# Xから -> 急に -> 笹原の -> 中へ -> Y
# Xに | Yの -> 中へ | 棄てられたのである
# Xに | Yへ | 棄てられたのである
# Xに -> 笹原の -> 中へ -> Y
# Xの -> Y
# Xの -> 中へ -> Y
# Xへ -> Y
# Xで | Yを | 這い出すと
# Xで | Yに | ある
# Xで | Yが | ある
# Xを | Yに | ある
# Xを | Yが | ある
# Xに | Yが | ある
# Xは | Yの -> 前に -> 坐って -> したら -> よかろうと -> 考えて | 見た
# Xは | Yに -> 坐って -> したら -> よかろうと -> 考えて | 見た
# Xの -> Y
# Xという -> Y
# Xがまた | Yに | 来てくれるかと
# X、 -> Y
# X、 -> ニャーと -> Y
# X、 | Yも | 来ない
# Xと -> Y
# Xと | Yも | 来ない
# Xに | Yも | 来ない
# Xの -> Y
# Xの | Yが | 渡って
# Xの | Yが | かかる
# Xの | Y | かかる
# Xを | Yが | 渡って
# Xを | Yが | かかる
# Xを | Y | かかる
# Xが | Yが | かかる
# Xが | Y | かかる
# Xが | Y | かかる
# Xが | Yに | 減って来た
# Xが | Yでも | 廻り始めた
# Xが | Yの -> ある -> 所まで -> ある | 廻り始めた
# Xが | Yまで -> ある | 廻り始めた
# Xが | Yを -> して -> そろり | 廻り始めた
# Xが | Yを | 廻り始めた
# Xが | Yりに | 廻り始めた
# Xでも | Yの -> ある -> 所まで -> ある | 廻り始めた
# Xでも | Yまで -> ある | 廻り始めた
# Xでも | Yを -> して -> そろり | 廻り始めた
# Xでも | Yを | 廻り始めた
# Xでも | Yりに | 廻り始めた
# Xの -> ある -> Y
# Xの | Yを -> して -> そろり | 廻り始めた
# Xの | Yを | 廻り始めた
# Xの | Yりに | 廻り始めた
# Xまで | Yを -> して -> そろり | 廻り始めた
# Xまで | Yを | 廻り始めた
# Xまで | Yりに | 廻り始めた
# Xを | Yを | 廻り始めた
# Xを | Yりに | 廻り始めた
# Xを | Yりに | 廻り始めた
# Xを -> Y
# Xを | Yに | 這って行くと
# Xを | Yで | 出た
# Xを | Y臭い -> 所へ | 出た
# Xを | Yへ | 出た
# Xして | Yに | 這って行くと
# Xして | Yで | 出た
# Xして | Y臭い -> 所へ | 出た
# Xして | Yへ | 出た
# Xに | Yで | 出た
# Xに | Y臭い -> 所へ | 出た
# Xに | Yへ | 出た
# Xで | Y臭い -> 所へ | 出た
# Xで | Yへ | 出た
# X臭い -> Y
# Xへ | Yの -> 崩れた -> 穴から | もぐり込んだ
# Xへ | Yから、 | もぐり込んだ
# Xへ | YYに | もぐり込んだ
# Xの -> 崩れた -> Y
# Xの | YYに | もぐり込んだ
# Xから、 | YYに | もぐり込んだ
# Xは | Yな | もので
# Xは -> 不思議な -> Y
# Xは | Yが -> 破れていなかったなら | 餓死したかも知れんのである
# Xは | Yは | 餓死したかも知れんのである
# Xは | Yに | 餓死したかも知れんのである
# Xは -> 不思議な -> もので -> もし -> この -> 竹垣が -> 破れていなかったなら -> 吾輩は -> ついに -> 路傍に -> Y
# Xな -> Y
# Xな | Yが -> 破れていなかったなら | 餓死したかも知れんのである
# Xな | Yは | 餓死したかも知れんのである
# Xな | Yに | 餓死したかも知れんのである
# Xな -> もので -> もし -> この -> 竹垣が -> 破れていなかったなら -> 吾輩は -> ついに -> 路傍に -> Y
# Xで、 | Yが -> 破れていなかったなら | 餓死したかも知れんのである
# Xで、 | Yは | 餓死したかも知れんのである
# Xで、 | Yに | 餓死したかも知れんのである
# Xで、 -> もし -> この -> 竹垣が -> 破れていなかったなら -> 吾輩は -> ついに -> 路傍に -> Y
# Xが | Yは | 餓死したかも知れんのである
# Xが | Yに | 餓死したかも知れんのである
# Xが -> 破れていなかったなら -> 吾輩は -> ついに -> 路傍に -> Y
# Xは | Yに | 餓死したかも知れんのである
# Xは -> ついに -> 路傍に -> Y
# Xに -> Y
# Xの -> Y
# Xの -> 蔭とは -> よく -> 云った -> Y
# Xとは -> よく -> 云った -> Y
# Xの -> Y
# Xの | Yに -> 至るまで -> 訪問する -> 時の -> 通路に | なっている
# Xの | Yが -> 訪問する -> 時の -> 通路に | なっている
# Xの | Yの -> 三毛を -> 訪問する -> 時の -> 通路に | なっている
# Xの | YYを -> 訪問する -> 時の -> 通路に | なっている
# Xの | Yする -> 時の -> 通路に | なっている
# Xの | Yの -> 通路に | なっている
# Xの | Yに | なっている
# Xは | Yに -> 至るまで -> 訪問する -> 時の -> 通路に | なっている
# Xは | Yが -> 訪問する -> 時の -> 通路に | なっている
# Xは | Yの -> 三毛を -> 訪問する -> 時の -> 通路に | なっている
# Xは | YYを -> 訪問する -> 時の -> 通路に | なっている
# Xは | Yする -> 時の -> 通路に | なっている
# Xは | Yの -> 通路に | なっている
# Xは | Yに | なっている
# Xに | Yが | 訪問する
# Xに | Yの -> 三毛を | 訪問する
# Xに | YYを | 訪問する
# Xに -> 至るまで -> 吾輩が -> 隣家の -> 三毛を -> Y
# Xに -> 至るまで -> 吾輩が -> 隣家の -> 三毛を -> 訪問する -> Y
# Xに -> 至るまで -> 吾輩が -> 隣家の -> 三毛を -> 訪問する -> 時の -> Y
# Xが | Yの -> 三毛を | 訪問する
# Xが | YYを | 訪問する
# Xが -> 隣家の -> 三毛を -> Y
# Xが -> 隣家の -> 三毛を -> 訪問する -> Y
# Xが -> 隣家の -> 三毛を -> 訪問する -> 時の -> Y
# Xの -> Y
# Xの -> 三毛を -> Y
# Xの -> 三毛を -> 訪問する -> Y
# Xの -> 三毛を -> 訪問する -> 時の -> Y
# XXを -> Y
# XXを -> 訪問する -> Y
# XXを -> 訪問する -> 時の -> Y
# Xする -> Y
# Xする -> 時の -> Y
# Xの -> Y
# Xへは | Y -> 善いか | 分らない
# Xに | Yは | 減る
# Xに | 寒Yは | 寒し
# Xに | Yが | 降って来るという
# Xに -> 暗くなる -> 腹は -> 減る -> 寒さは -> 寒し -> 雨が -> 降って来るという -> Y
# Xに | Yの -> 猶予が | 出来なくなった
# Xに | Yが | 出来なくなった
# Xは | 寒Yは | 寒し
# Xは | Yが | 降って来るという
# Xは -> 減る -> 寒さは -> 寒し -> 雨が -> 降って来るという -> Y
# Xは | Yの -> 猶予が | 出来なくなった
# Xは | Yが | 出来なくなった
# 寒Xは | Yが | 降って来るという
# 寒Xは -> 寒し -> 雨が -> 降って来るという -> Y
# 寒Xは | Yの -> 猶予が | 出来なくなった
# 寒Xは | Yが | 出来なくなった
# Xが -> 降って来るという -> Y
# Xが | Yの -> 猶予が | 出来なくなった
# Xが | Yが | 出来なくなった
# Xで | Yの -> 猶予が | 出来なくなった
# Xで | Yが | 出来なくなった
# Xの -> Y
# Xが -> ないから -> とにかく -> 明るくて -> Y
# Xが -> ないから -> とにかく -> 明るくて -> 暖かそうな -> Y
# Xが | Yへと | あるいて行く
# 暖かXな -> Y
# 暖かXな | Yへと | あるいて行く
# Xへ | Yへと | あるいて行く
# Xから | Yは | おったのだ
# Xから | Yの -> 内に -> 這入って | おったのだ
# Xから | Yに -> 這入って | おったのだ
# Xから -> 考えると -> その -> 時は -> すでに -> 家の -> 内に -> 這入って -> Y
# Xは | Yの -> 内に -> 這入って | おったのだ
# Xは | Yに -> 這入って | おったのだ
# Xは -> すでに -> 家の -> 内に -> 這入って -> Y
# Xの -> Y
# Xの -> 内に -> 這入って -> Y
# Xに -> 這入って -> Y
# Xで | Yは | 遭遇したのである
# Xで | Yの -> 書生以外の -> 人間を -> 見るべき -> 機会に | 遭遇したのである
# Xで | YYの -> 人間を -> 見るべき -> 機会に | 遭遇したのである
# Xで | Yを -> 見るべき -> 機会に | 遭遇したのである
# Xで | Yに | 遭遇したのである
# Xで -> 吾輩は -> 彼の -> 書生以外の -> 人間を -> 再び -> 見るべき -> 機会に -> Y
# Xは | Yの -> 書生以外の -> 人間を -> 見るべき -> 機会に | 遭遇したのである
# Xは | YYの -> 人間を -> 見るべき -> 機会に | 遭遇したのである
# Xは | Yを -> 見るべき -> 機会に | 遭遇したのである
# Xは | Yに | 遭遇したのである
# Xは -> 彼の -> 書生以外の -> 人間を -> 再び -> 見るべき -> 機会に -> Y
# Xの -> Y
# Xの -> 書生以外の -> Y
# Xの -> 書生以外の -> 人間を -> 再び -> 見るべき -> Y
# Xの -> 書生以外の -> 人間を -> 再び -> 見るべき -> 機会に -> Y
# XXの -> Y
# XXの -> 人間を -> 再び -> 見るべき -> Y
# XXの -> 人間を -> 再び -> 見るべき -> 機会に -> Y
# Xを -> 再び -> 見るべき -> Y
# Xを -> 再び -> 見るべき -> 機会に -> Y
# Xに -> Y
# 第Xに -> Y
# 第Xに -> 逢ったのが -> Y
# 逢ったXが -> Y
# Xは | Yの -> 書生より -> 見るや | 抛り出した
# Xは | Yより -> 見るや | 抛り出した
# Xは | Yな -> 方で -> 見るや | 抛り出した
# Xは | Yで -> 見るや | 抛り出した
# Xは | Yを -> 見るや | 抛り出した
# Xは | Yいきなり -> つかんで | 抛り出した
# Xは | Yを -> つかんで | 抛り出した
# Xは | Yへ | 抛り出した
# Xの -> Y
# Xの | Yな -> 方で | 見るや
# Xの | Yで | 見るや
# Xの | Yを | 見るや
# Xの | Yいきなり -> つかんで | 抛り出した
# Xの | Yを -> つかんで | 抛り出した
# Xの | Yへ | 抛り出した
# Xより | Yな -> 方で | 見るや
# Xより | Yで | 見るや
# Xより | Yを | 見るや
# Xより | Yいきなり -> つかんで | 抛り出した
# Xより | Yを -> つかんで | 抛り出した
# Xより | Yへ | 抛り出した
# Xな -> Y
# Xな | Yを | 見るや
# Xな | Yいきなり -> つかんで | 抛り出した
# Xな | Yを -> つかんで | 抛り出した
# Xな | Yへ | 抛り出した
# Xで | Yを | 見るや
# Xで | Yいきなり -> つかんで | 抛り出した
# Xで | Yを -> つかんで | 抛り出した
# Xで | Yへ | 抛り出した
# Xを | Yいきなり -> つかんで | 抛り出した
# Xを | Yを -> つかんで | 抛り出した
# Xを | Yへ | 抛り出した
# Xいきなり | Yを | つかんで
# Xいきなり | Yへ | 抛り出した
# Xを | Yへ | 抛り出した
# Xは -> Y
# Xは | Yを -> ねぶって | 任せていた
# Xは | Yを | 任せていた
# Xは | Yに | 任せていた
# Xだと | Yを -> ねぶって | 任せていた
# Xだと | Yを | 任せていた
# Xだと | Yに | 任せていた
# Xを | Yを | 任せていた
# Xを | Yに | 任せていた
# Xを | Yに | 任せていた
# ひもじいXと -> Y
# ひもじいXと | Yが | 出来ん
# 寒いXには | Yが | 出来ん
# Xは | Yの -> 隙を -> 見て | 這い上った
# Xは | Yを -> 見て | 這い上った
# Xは | Yへ | 這い上った
# Xの -> Y
# Xの | Yへ | 這い上った
# Xを | Yへ | 這い上った
# Xは | Yでも -> 繰り返したのを | 記憶している
# Xは | Yを -> 繰り返したのを | 記憶している
# Xは | YYY -> 繰り返したのを | 記憶している
# Xは | 繰り返したYを | 記憶している
# Xは -> 投げ出されては -> 這い上り -> 這い上っては -> 投げ出され -> 何でも -> 同じ -> 事を -> 四五遍 -> 繰り返したのを -> Y
# Xでも | Yを | 繰り返したのを
# Xでも | YYY | 繰り返したのを
# Xでも -> 同じ -> 事を -> 四五遍 -> Y
# Xでも -> 同じ -> 事を -> 四五遍 -> 繰り返したのを -> Y
# Xを | YYY | 繰り返したのを
# Xを -> 四五遍 -> Y
# Xを -> 四五遍 -> 繰り返したのを -> Y
# XXX -> Y
# XXX -> 繰り返したのを -> Y
# 繰り返したXを -> Y
# Xに | Yと | 云う
# Xに -> おさんと -> 云う -> Y
# Xに -> おさんと -> 云う -> 者は -> つくづく -> Y
# Xと -> 云う -> Y
# Xと -> 云う -> 者は -> つくづく -> Y
# Xは -> つくづく -> Y
# X | Yの -> 三馬を | 偸んで
# X | YYを | 偸んで
# X -> おさんの -> 三馬を -> Y
# X | Yを | してやってから
# X | Yの -> 痞が | 下りた
# X | Yが | 下りた
# Xの -> Y
# Xの -> 三馬を -> Y
# Xの | Yを | してやってから
# Xの | Yの -> 痞が | 下りた
# Xの | Yが | 下りた
# XXを -> Y
# XXを | Yを | してやってから
# XXを | Yの -> 痞が | 下りた
# XXを | Yが | 下りた
# Xんで | Yを | してやってから
# Xんで | Yの -> 痞が | 下りた
# Xんで | Yが | 下りた
# Xを | Yの -> 痞が | 下りた
# Xを | Yが | 下りた
# Xの -> Y
# Xが | Yに | つまみ出されようとした
# Xが -> 最後に -> つまみ出されようとした -> Y
# Xが | Yの -> 主人が | 出て来た
# Xが | Yが | 出て来た
# Xが | Yだと -> いいながら | 出て来た
# Xに -> つまみ出されようとした -> Y
# Xに | Yの -> 主人が | 出て来た
# Xに | Yが | 出て来た
# Xに | Yだと -> いいながら | 出て来た
# Xに、 | Yの -> 主人が | 出て来た
# Xに、 | Yが | 出て来た
# Xに、 | Yだと -> いいながら | 出て来た
# Xの -> Y
# Xの | Yだと -> いいながら | 出て来た
# Xが | Yだと -> いいながら | 出て来た
# Xは | Yを -> ぶら下げて -> 出しても | 困りますと
# Xは | Yの -> 方へ -> 向けて -> 出しても | 困りますと
# Xは | Yへ -> 向けて -> 出しても | 困りますと
# Xは | Yなしの -> 小猫が -> 出しても -> 出しても | 困りますと
# Xは | 小Yが -> 出しても -> 出しても | 困りますと
# Xは | YYへ -> 上って来て | 困りますと
# Xを | Yの -> 方へ -> 向けて | 出しても
# Xを | Yへ -> 向けて | 出しても
# Xを | Yなしの -> 小猫が -> 出しても | 出しても
# Xを | 小Yが -> 出しても | 出しても
# Xを | YYへ -> 上って来て | 困りますと
# Xの -> Y
# Xの | Yなしの -> 小猫が -> 出しても | 出しても
# Xの | 小Yが -> 出しても | 出しても
# Xの | YYへ -> 上って来て | 困りますと
# Xへ | Yなしの -> 小猫が -> 出しても | 出しても
# Xへ | 小Yが -> 出しても | 出しても
# Xへ | YYへ -> 上って来て | 困りますと
# Xなしの -> Y
# Xなしの | YYへ -> 上って来て | 困りますと
# 小Xが | YYへ -> 上って来て | 困りますと
# Xは | Yの -> 下の -> 黒い -> 毛を -> 撚りながら -> 眺めて | おったが
# Xは | Yの -> 黒い -> 毛を -> 撚りながら -> 眺めて | おったが
# Xは | Yを -> 撚りながら -> 眺めて | おったが
# Xは | Yの -> 顔を -> 眺めて | おったが
# Xは | Yを -> 眺めて | おったが
# Xは | Yなら -> 置いてやれといったまま | 這入ってしまった
# Xは | Yへ -> 置いてやれといったまま | 這入ってしまった
# Xは | 置いてやれといったY | 這入ってしまった
# Xは | Yへ | 這入ってしまった
# Xの -> Y
# Xの -> 下の -> 黒い -> Y
# Xの | Yの -> 顔を | 眺めて
# Xの | Yを | 眺めて
# Xの | Yなら -> 置いてやれといったまま | 這入ってしまった
# Xの | Yへ -> 置いてやれといったまま | 這入ってしまった
# Xの | 置いてやれといったY | 這入ってしまった
# Xの | Yへ | 這入ってしまった
# Xの -> 黒い -> Y
# Xの | Yの -> 顔を | 眺めて
# Xの | Yを | 眺めて
# Xの | Yなら -> 置いてやれといったまま | 這入ってしまった
# Xの | Yへ -> 置いてやれといったまま | 這入ってしまった
# Xの | 置いてやれといったY | 這入ってしまった
# Xの | Yへ | 這入ってしまった
# Xを | Yの -> 顔を | 眺めて
# Xを | Yを | 眺めて
# Xを | Yなら -> 置いてやれといったまま | 這入ってしまった
# Xを | Yへ -> 置いてやれといったまま | 這入ってしまった
# Xを | 置いてやれといったY | 這入ってしまった
# Xを | Yへ | 這入ってしまった
# Xの -> Y
# Xの | Yなら -> 置いてやれといったまま | 這入ってしまった
# Xの | Yへ -> 置いてやれといったまま | 這入ってしまった
# Xの | 置いてやれといったY | 這入ってしまった
# Xの | Yへ | 這入ってしまった
# Xを | Yなら -> 置いてやれといったまま | 這入ってしまった
# Xを | Yへ -> 置いてやれといったまま | 這入ってしまった
# Xを | 置いてやれといったY | 這入ってしまった
# Xを | Yへ | 這入ってしまった
# Xなら | Yへ | 置いてやれといったまま
# Xなら -> 内へ -> Y
# Xなら | Yへ | 這入ってしまった
# Xへ -> Y
# Xへ | Yへ | 這入ってしまった
# 置いてやれといったX | Yへ | 這入ってしまった
# Xは | Yを -> 聞かぬ -> 人と | 見えた
# Xは | Yと | 見えた
# Xを -> 聞かぬ -> Y
# Xは | 口惜しYに | 抛り出した
# Xは | Yを | 抛り出した
# Xは | Yへ | 抛り出した
# 口惜しXに | Yを | 抛り出した
# 口惜しXに | Yへ | 抛り出した
# Xを | Yへ | 抛り出した
# Xは | Yを -> 極める -> 事に | したのである
# Xは | Yの -> 住家と -> 極める -> 事に | したのである
# Xは | YYと -> 極める -> 事に | したのである
# Xは | Yに | したのである
# Xは -> ついに -> この -> 家を -> 自分の -> 住家と -> 極める -> 事に -> Y
# Xを | Yの -> 住家と | 極める
# Xを | YYと | 極める
# Xを -> 自分の -> 住家と -> 極める -> Y
# Xを -> 自分の -> 住家と -> 極める -> 事に -> Y
# Xの -> Y
# Xの -> 住家と -> 極める -> Y
# Xの -> 住家と -> 極める -> 事に -> Y
# XXと -> 極める -> Y
# XXと -> 極める -> 事に -> Y
# Xに -> Y
# Xの -> Y
# Xの | Yに -> 合せる -> 事が | ない
# Xの | Yと -> 合せる -> 事が | ない
# Xの | Yを -> 合せる -> 事が | ない
# Xの | Yが | ない
# Xは | Yに -> 合せる -> 事が | ない
# Xは | Yと -> 合せる -> 事が | ない
# Xは | Yを -> 合せる -> 事が | ない
# Xは | Yが | ない
# Xに | Yと | 合せる
# Xに | Yを | 合せる
# Xに -> 吾輩と -> 顔を -> 合せる -> Y
# Xと | Yを | 合せる
# Xと -> 顔を -> 合せる -> Y
# Xを -> 合せる -> Y
# Xは -> Y
# Xから | Y -> 這入った | ぎりほとんど出て来る
# Xから | Yに -> 這入った | ぎりほとんど出て来る
# Xから -> 帰ると -> 終日 -> 書斎に -> 這入った -> Y
# Xから -> 帰ると -> 終日 -> 書斎に -> 這入った -> ぎりほとんど出て来る -> Y
# X | Yに | 這入った
# X -> 書斎に -> 這入った -> Y
# X -> 書斎に -> 這入った -> ぎりほとんど出て来る -> Y
# Xに -> 這入った -> Y
# Xに -> 這入った -> ぎりほとんど出て来る -> Y
# X出て来る -> Y
# Xの -> Y
# Xの | Yな | 勉強家だと
# Xの -> ものは -> 大変な -> Y
# Xは | Yな | 勉強家だと
# Xは -> 大変な -> Y
# Xな -> Y
# Xも | YYであるかの | ごとく
# Xの -> Y
# Xの -> ものが -> Y
# Xの -> ものが -> いうような -> Y
# Xが -> Y
# Xが -> いうような -> Y
# いうXな -> Y
# Xは | Yに -> 覗いて | 見るが
# Xは | Yの -> 書斎を -> 覗いて | 見るが
# Xは | Yを -> 覗いて | 見るが
# Xは | Yは | ある
# Xは | Yを -> している -> 事が | ある
# Xは | Yが | ある
# Xに | Yの -> 書斎を | 覗いて
# Xに | Yを | 覗いて
# Xに | Yは | ある
# Xに | Yを -> している -> 事が | ある
# Xに | Yが | ある
# Xの -> Y
# Xの | Yは | ある
# Xの | Yを -> している -> 事が | ある
# Xの | Yが | ある
# Xを | Yは | ある
# Xを | Yを -> している -> 事が | ある
# Xを | Yが | ある
# Xは | Yを -> している -> 事が | ある
# Xは | Yが | ある
# Xを -> している -> Y
# Xの -> Y
# Xの | Yを | たらしている
# Xに | Yを | たらしている
# Xは | Yで -> 帯びて | あらわしている
# Xは | Yの -> 色が -> 帯びて | あらわしている
# Xは | Yが -> 帯びて | あらわしている
# Xは | Yを -> 帯びて | あらわしている
# Xは | Yの -> ない -> 徴候を | あらわしている
# Xは | 不Yな -> 徴候を | あらわしている
# Xは | Yを | あらわしている
# Xで | Yの -> 色が | 帯びて
# Xで | Yが | 帯びて
# Xで | Yを | 帯びて
# Xで | Yの -> ない -> 徴候を | あらわしている
# Xで | 不Yな -> 徴候を | あらわしている
# Xで | Yを | あらわしている
# Xの -> Y
# Xの | Yを | 帯びて
# Xの | Yの -> ない -> 徴候を | あらわしている
# Xの | 不Yな -> 徴候を | あらわしている
# Xの | Yを | あらわしている
# Xが | Yを | 帯びて
# Xが | Yの -> ない -> 徴候を | あらわしている
# Xが | 不Yな -> 徴候を | あらわしている
# Xが | Yを | あらわしている
# Xを | Yの -> ない -> 徴候を | あらわしている
# Xを | 不Yな -> 徴候を | あらわしている
# Xを | Yを | あらわしている
# Xの | 不Yな | 徴候を
# Xの -> ない -> 不活溌な -> Y
# 不Xな -> Y
# Xに | Yを | 食う
# Xを -> 食った -> Y
# Xを | Yを | 飲む
# Xで | Yを | 飲む
# Xで | Yを | ひろげる
# Xを | Yの -> 上へ | 垂らす
# Xを | Yへ | 垂らす
# Xの -> Y
# Xが | Yの -> 毎夜 | 繰り返す
# Xが | Y | 繰り返す
# Xが -> 彼の -> 毎夜 -> 繰り返す -> Y
# Xの -> Y
# Xの -> 毎夜 -> 繰り返す -> Y
# X -> 繰り返す -> Y
# Xは | Yながら -> 考える -> 事が | ある
# Xは | Yが | ある
# Xながら -> 時々 -> 考える -> Y
# Xという -> Y
# Xという | Yな | ものだ
# Xという -> ものは -> 実に -> 楽な -> Y
# Xは | Yな | ものだ
# Xは -> 実に -> 楽な -> Y
# Xな -> Y
# Xと | Yと | なるに
# Xなら | Yにでも -> 出来ぬ -> 事は | ないと
# Xなら | Yは | ないと
# Xにでも -> 出来ぬ -> Y
# Xに | Yほど -> つらい -> ものは | ないそうで
# Xに | Yは | ないそうで
# Xに -> 云わせると -> 教師ほど -> つらい -> ものは -> Y
# Xに | Yは | 鳴らしている
# Xに | Yが -> 来る -> 度に | 鳴らしている
# Xに | Yに | 鳴らしている
# Xに | Yとか -> 不平を | 鳴らしている
# Xに | Yを | 鳴らしている
# Xほど -> つらい -> Y
# Xほど -> つらい -> ものは -> Y
# Xほど | Yは | 鳴らしている
# Xほど | Yが -> 来る -> 度に | 鳴らしている
# Xほど | Yに | 鳴らしている
# Xほど | Yとか -> 不平を | 鳴らしている
# Xほど | Yを | 鳴らしている
# Xは -> Y
# Xは | Yは | 鳴らしている
# Xは | Yが -> 来る -> 度に | 鳴らしている
# Xは | Yに | 鳴らしている
# Xは | Yとか -> 不平を | 鳴らしている
# Xは | Yを | 鳴らしている
# ないXで | Yは | 鳴らしている
# ないXで | Yが -> 来る -> 度に | 鳴らしている
# ないXで | Yに | 鳴らしている
# ないXで | Yとか -> 不平を | 鳴らしている
# ないXで | Yを | 鳴らしている
# Xは | Yが -> 来る -> 度に | 鳴らしている
# Xは | Yに | 鳴らしている
# Xは | Yとか -> 不平を | 鳴らしている
# Xは | Yを | 鳴らしている
# Xが -> 来る -> Y
# Xが | Yとか -> 不平を | 鳴らしている
# Xが | Yを | 鳴らしている
# Xに | Yとか -> 不平を | 鳴らしている
# Xに | Yを | 鳴らしている
# Xとか -> Y
# 　Xが | Yへ | 住み込んだ
# 　Xが -> この -> 家へ -> 住み込んだ -> Y
# 　Xが | YYの -> ものには | 不人望であった
# 　Xが | Yには | 不人望であった
# 　Xが -> この -> 家へ -> 住み込んだ -> 当時は -> 主人以外の -> ものには -> はなはだ -> Y
# Xへ -> 住み込んだ -> Y
# Xへ | YYの -> ものには | 不人望であった
# Xへ | Yには | 不人望であった
# Xへ -> 住み込んだ -> 当時は -> 主人以外の -> ものには -> はなはだ -> Y
# Xは、 | YYの -> ものには | 不人望であった
# Xは、 | Yには | 不人望であった
# Xは、 -> 主人以外の -> ものには -> はなはだ -> Y
# XXの -> Y
# XXの -> ものには -> はなはだ -> Y
# Xには -> はなはだ -> Y
# Xへ | Yに | してくれ
# Xへ | Yが | なかった
# Xに | Yが | なかった
# Xされなかったかは、 | Yに -> 至るまで -> つけてくれないのでも | 分る
# Xされなかったかは、 | Yさえ -> つけてくれないのでも | 分る
# Xされなかったかは、 | つけてくれないYでも | 分る
# Xに | Yさえ | つけてくれないのでも
# Xに -> 至るまで -> 名前さえ -> Y
# Xさえ -> Y
# Xは | Yが | ないから
# Xは | Y -> 入れてくれた -> 主人の -> 傍に -> いる -> 事を | つとめた
# Xは | Yを -> 入れてくれた -> 主人の -> 傍に -> いる -> 事を | つとめた
# Xは | Yの -> 傍に -> いる -> 事を | つとめた
# Xは | Yに -> いる -> 事を | つとめた
# Xは | Yを | つとめた
# Xが | Y -> 入れてくれた -> 主人の -> 傍に -> いる -> 事を | つとめた
# Xが | Yを -> 入れてくれた -> 主人の -> 傍に -> いる -> 事を | つとめた
# Xが | Yの -> 傍に -> いる -> 事を | つとめた
# Xが | Yに -> いる -> 事を | つとめた
# Xが | Yを | つとめた
# X | Yを | 入れてくれた
# X -> 吾輩を -> 入れてくれた -> Y
# X -> 吾輩を -> 入れてくれた -> 主人の -> Y
# X -> 吾輩を -> 入れてくれた -> 主人の -> 傍に -> いる -> Y
# Xを -> 入れてくれた -> Y
# Xを -> 入れてくれた -> 主人の -> Y
# Xを -> 入れてくれた -> 主人の -> 傍に -> いる -> Y
# Xの -> Y
# Xの -> 傍に -> いる -> Y
# Xに -> いる -> Y
# XXが | Yを | 読む
# XXが -> 新聞を -> 読む -> Y
# XXが | Yの -> 膝の -> 上に | 乗る
# XXが | Yの -> 上に | 乗る
# XXが | Yに | 乗る
# Xを -> 読む -> Y
# Xを | Yの -> 膝の -> 上に | 乗る
# Xを | Yの -> 上に | 乗る
# Xを | Yに | 乗る
# Xは | Yの -> 膝の -> 上に | 乗る
# Xは | Yの -> 上に | 乗る
# Xは | Yに | 乗る
# Xの -> Y
# Xの -> 膝の -> Y
# Xの -> Y
# Xが | Yを | する
# Xが -> 昼寝を -> する -> Y
# Xが | Yに | 乗る
# Xを -> する -> Y
# Xを | Yに | 乗る
# Xは | Yに | 乗る
# Xは | Yが -> 好きという -> 訳ではないが -> なかったから | やむを得んのである
# Xは | Yという -> 訳ではないが -> なかったから | やむを得んのである
# Xは | Yではないが -> なかったから | やむを得んのである
# Xは | Yに -> なかったから | やむを得んのである
# Xは | 構いYが -> なかったから | やむを得んのである
# Xは -> あながち -> 主人が -> 好きという -> 訳ではないが -> 別に -> 構い手が -> なかったから -> Y
# Xが -> Y
# Xが -> 好きという -> Y
# Xが | Yに | なかったから
# Xが | 構いYが | なかったから
# Xが -> 好きという -> 訳ではないが -> 別に -> 構い手が -> なかったから -> Y
# Xという -> Y
# Xという | Yに | なかったから
# Xという | 構いYが | なかったから
# Xという -> 訳ではないが -> 別に -> 構い手が -> なかったから -> Y
# Xではないが | Yに | なかったから
# Xではないが | 構いYが | なかったから
# Xではないが -> 別に -> 構い手が -> なかったから -> Y
# Xに | 構いYが | なかったから
# Xに -> 構い手が -> なかったから -> Y
# 構いXが -> なかったから -> Y
# X | Yの -> 上 | した
# X | Y、 | した
# X | Yは | した
# X | Yの -> 上 | した
# X | Y、 | した
# X | Yは | した
# X | Yの -> 上 | した
# X | Y、 | した
# X | Yの -> よい -> 昼は | した
# X | Yは | した
# X | Yへ -> 寝る -> 事と | した
# X | Yと | した
# Xの -> Y
# Xの | Yは | した
# Xの | Yの -> 上 | した
# Xの | Y、 | した
# Xの | Yは | した
# Xの | Yの -> 上 | した
# Xの | Y、 | した
# Xの | Yの -> よい -> 昼は | した
# Xの | Yは | した
# Xの | Yへ -> 寝る -> 事と | した
# Xの | Yと | した
# X、 | Yは | した
# X、 | Yの -> 上 | した
# X、 | Y、 | した
# X、 | Yは | した
# X、 | Yの -> 上 | した
# X、 | Y、 | した
# X、 | Yの -> よい -> 昼は | した
# X、 | Yは | した
# X、 | Yへ -> 寝る -> 事と | した
# X、 | Yと | した
# Xは | Yの -> 上 | した
# Xは | Y、 | した
# Xは | Yは | した
# Xは | Yの -> 上 | した
# Xは | Y、 | した
# Xは | Yの -> よい -> 昼は | した
# Xは | Yは | した
# Xは | Yへ -> 寝る -> 事と | した
# Xは | Yと | した
# Xの -> Y
# Xの | Yは | した
# Xの | Yの -> 上 | した
# Xの | Y、 | した
# Xの | Yの -> よい -> 昼は | した
# Xの | Yは | した
# Xの | Yへ -> 寝る -> 事と | した
# Xの | Yと | した
# X、 | Yは | した
# X、 | Yの -> 上 | した
# X、 | Y、 | した
# X、 | Yの -> よい -> 昼は | した
# X、 | Yは | した
# X、 | Yへ -> 寝る -> 事と | した
# X、 | Yと | した
# Xは | Yの -> 上 | した
# Xは | Y、 | した
# Xは | Yの -> よい -> 昼は | した
# Xは | Yは | した
# Xは | Yへ -> 寝る -> 事と | した
# Xは | Yと | した
# Xの -> Y
# Xの | Yの -> よい -> 昼は | した
# Xの | Yは | した
# Xの | Yへ -> 寝る -> 事と | した
# Xの | Yと | した
# X、 | Yの -> よい -> 昼は | した
# X、 | Yは | した
# X、 | Yへ -> 寝る -> 事と | した
# X、 | Yと | した
# Xの -> よい -> Y
# Xの | Yへ -> 寝る -> 事と | した
# Xの | Yと | した
# Xは | Yへ -> 寝る -> 事と | した
# Xは | Yと | した
# Xへ -> 寝る -> Y
# X | Yの | 好いのは
# X -> 心持の -> Y
# X | Yに -> 入って -> ねる | 事である
# X | Yの -> うちの -> 小供の -> 寝床へ -> もぐり込んで -> ねる | 事である
# X | Yの -> 小供の -> 寝床へ -> もぐり込んで -> ねる | 事である
# X | 小Yの -> 寝床へ -> もぐり込んで -> ねる | 事である
# X | Yへ -> もぐり込んで -> ねる | 事である
# X | Yに -> ねる | 事である
# X -> 心持の -> 好いのは -> 夜に -> 入って -> ここの -> うちの -> 小供の -> 寝床へ -> もぐり込んで -> いっしょに -> ねる -> Y
# Xの -> Y
# Xの | Yに -> 入って -> ねる | 事である
# Xの | Yの -> うちの -> 小供の -> 寝床へ -> もぐり込んで -> ねる | 事である
# Xの | Yの -> 小供の -> 寝床へ -> もぐり込んで -> ねる | 事である
# Xの | 小Yの -> 寝床へ -> もぐり込んで -> ねる | 事である
# Xの | Yへ -> もぐり込んで -> ねる | 事である
# Xの | Yに -> ねる | 事である
# Xの -> 好いのは -> 夜に -> 入って -> ここの -> うちの -> 小供の -> 寝床へ -> もぐり込んで -> いっしょに -> ねる -> Y
# 好いXは | Yに -> 入って -> ねる | 事である
# 好いXは | Yの -> うちの -> 小供の -> 寝床へ -> もぐり込んで -> ねる | 事である
# 好いXは | Yの -> 小供の -> 寝床へ -> もぐり込んで -> ねる | 事である
# 好いXは | 小Yの -> 寝床へ -> もぐり込んで -> ねる | 事である
# 好いXは | Yへ -> もぐり込んで -> ねる | 事である
# 好いXは | Yに -> ねる | 事である
# 好いXは -> 夜に -> 入って -> ここの -> うちの -> 小供の -> 寝床へ -> もぐり込んで -> いっしょに -> ねる -> Y
# Xに | Yの -> うちの -> 小供の -> 寝床へ -> もぐり込んで | ねる
# Xに | Yの -> 小供の -> 寝床へ -> もぐり込んで | ねる
# Xに | 小Yの -> 寝床へ -> もぐり込んで | ねる
# Xに | Yへ -> もぐり込んで | ねる
# Xに | Yに | ねる
# Xに -> 入って -> ここの -> うちの -> 小供の -> 寝床へ -> もぐり込んで -> いっしょに -> ねる -> Y
# Xの -> Y
# Xの -> うちの -> Y
# Xの -> うちの -> 小供の -> Y
# Xの | Yに | ねる
# Xの -> うちの -> 小供の -> 寝床へ -> もぐり込んで -> いっしょに -> ねる -> Y
# Xの -> Y
# Xの -> 小供の -> Y
# Xの | Yに | ねる
# Xの -> 小供の -> 寝床へ -> もぐり込んで -> いっしょに -> ねる -> Y
# 小Xの -> Y
# 小Xの | Yに | ねる
# 小Xの -> 寝床へ -> もぐり込んで -> いっしょに -> ねる -> Y
# Xへ | Yに | ねる
# Xへ -> もぐり込んで -> いっしょに -> ねる -> Y
# Xに -> ねる -> Y
# 小XというXは | Yと -> 三つで -> なると | 寝る
# 小XというXは | Yで -> なると | 寝る
# 小XというXは | Yに -> なると | 寝る
# 小XというXは | YYが | 寝る
# 小XというXは | Y | 寝る
# 小XというXは | Yへ -> 入って | 寝る
# 小XというXは | Yへ | 寝る
# Xと -> Y
# Xと | Yに | なると
# Xと | YYが | 寝る
# Xと | Y | 寝る
# Xと | Yへ -> 入って | 寝る
# Xと | Yへ | 寝る
# Xで | Yに | なると
# Xで | YYが | 寝る
# Xで | Y | 寝る
# Xで | Yへ -> 入って | 寝る
# Xで | Yへ | 寝る
# Xに | YYが | 寝る
# Xに | Y | 寝る
# Xに | Yへ -> 入って | 寝る
# Xに | Yへ | 寝る
# XXが | Y | 寝る
# XXが | Yへ -> 入って | 寝る
# XXが | Yへ | 寝る
# X | Yへ -> 入って | 寝る
# X | Yへ | 寝る
# Xへ | Yへ | 寝る
# Xは | Yでも -> 見出して | 割り込むのであるが
# Xは | Yの -> 中間に -> 見出して | 割り込むのであるが
# Xは | Yに -> 見出して | 割り込むのであるが
# Xは | Yれを -> 見出して | 割り込むのであるが
# Xは | Yるべき -> 余地を -> 見出して | 割り込むのであるが
# Xは | Yを -> 見出して | 割り込むのであるが
# Xは -> いつでも -> 彼等の -> 中間に -> 己れを -> 容るべき -> 余地を -> 見出して -> どうにか -> こうにか -> Y
# Xは | Y悪く -> 醒ますが | なる
# Xは | 小Yの -> 一人が -> 醒ますが | なる
# Xは | YYが -> 醒ますが | なる
# Xは | Yを -> 醒ますが | なる
# Xは | YYな -> 事に | なる
# Xは | Yに | なる
# Xでも | Yの -> 中間に | 見出して
# Xでも | Yに | 見出して
# Xでも | Yれを | 見出して
# Xでも | Yるべき -> 余地を | 見出して
# Xでも | Yを | 見出して
# Xでも -> 彼等の -> 中間に -> 己れを -> 容るべき -> 余地を -> 見出して -> どうにか -> こうにか -> Y
# Xでも | Y悪く -> 醒ますが | なる
# Xでも | 小Yの -> 一人が -> 醒ますが | なる
# Xでも | YYが -> 醒ますが | なる
# Xでも | Yを -> 醒ますが | なる
# Xでも | YYな -> 事に | なる
# Xでも | Yに | なる
# Xの -> Y
# Xの | Yれを | 見出して
# Xの | Yるべき -> 余地を | 見出して
# Xの | Yを | 見出して
# Xの -> 中間に -> 己れを -> 容るべき -> 余地を -> 見出して -> どうにか -> こうにか -> Y
# Xの | Y悪く -> 醒ますが | なる
# Xの | 小Yの -> 一人が -> 醒ますが | なる
# Xの | YYが -> 醒ますが | なる
# Xの | Yを -> 醒ますが | なる
# Xの | YYな -> 事に | なる
# Xの | Yに | なる
# Xに | Yれを | 見出して
# Xに | Yるべき -> 余地を | 見出して
# Xに | Yを | 見出して
# Xに -> 己れを -> 容るべき -> 余地を -> 見出して -> どうにか -> こうにか -> Y
# Xに | Y悪く -> 醒ますが | なる
# Xに | 小Yの -> 一人が -> 醒ますが | なる
# Xに | YYが -> 醒ますが | なる
# Xに | Yを -> 醒ますが | なる
# Xに | YYな -> 事に | なる
# Xに | Yに | なる
# Xれを | Yるべき -> 余地を | 見出して
# Xれを | Yを | 見出して
# Xれを -> 容るべき -> 余地を -> 見出して -> どうにか -> こうにか -> Y
# Xれを | Y悪く -> 醒ますが | なる
# Xれを | 小Yの -> 一人が -> 醒ますが | なる
# Xれを | YYが -> 醒ますが | なる
# Xれを | Yを -> 醒ますが | なる
# Xれを | YYな -> 事に | なる
# Xれを | Yに | なる
# Xるべき -> Y
# Xるべき -> 余地を -> 見出して -> どうにか -> こうにか -> Y
# Xるべき | Y悪く -> 醒ますが | なる
# Xるべき | 小Yの -> 一人が -> 醒ますが | なる
# Xるべき | YYが -> 醒ますが | なる
# Xるべき | Yを -> 醒ますが | なる
# Xるべき | YYな -> 事に | なる
# Xるべき | Yに | なる
# Xを -> 見出して -> どうにか -> こうにか -> Y
# Xを | Y悪く -> 醒ますが | なる
# Xを | 小Yの -> 一人が -> 醒ますが | なる
# Xを | YYが -> 醒ますが | なる
# Xを | Yを -> 醒ますが | なる
# Xを | YYな -> 事に | なる
# Xを | Yに | なる
# 割り込むXであるが、 | Y悪く -> 醒ますが | なる
# 割り込むXであるが、 | 小Yの -> 一人が -> 醒ますが | なる
# 割り込むXであるが、 | YYが -> 醒ますが | なる
# 割り込むXであるが、 | Yを -> 醒ますが | なる
# 割り込むXであるが、 | YYな -> 事に | なる
# 割り込むXであるが、 | Yに | なる
# X悪く | 小Yの -> 一人が | 醒ますが
# X悪く | YYが | 醒ますが
# X悪く | Yを | 醒ますが
# X悪く | YYな -> 事に | なる
# X悪く | Yに | なる
# 小Xの -> Y
# 小Xの | Yを | 醒ますが
# 小Xの | YYな -> 事に | なる
# 小Xの | Yに | なる
# XXが | Yを | 醒ますが
# XXが | YYな -> 事に | なる
# XXが | Yに | なる
# Xを | YYな -> 事に | なる
# Xを | Yに | なる
# XXな -> Y
# 小XはX | Yが -> 来た -> 猫が -> 来たと -> いって | 泣き出すのである
# 小XはX | Yが -> 来た -> 猫が -> 来たと -> いって | 泣き出すのである
# 小XはX | わるいYYが -> 来た -> 猫が -> 来たと -> いって | 泣き出すのである
# 小XはX | Yが -> 来たと -> いって | 泣き出すのである
# 小XはX | Yでも | 泣き出すのである
# 小XはX | Yでも | 泣き出すのである
# 小XはX | Yで | 泣き出すのである
# 小XはX -> ことに -> 小さい -> 方が -> 質が -> わるい——猫が -> 来た -> 猫が -> 来たと -> いって -> 夜中でも -> 何でも -> 大きな -> 声で -> Y
# Xが | Yが | 来た
# Xが | わるいYYが | 来た
# Xが -> 質が -> わるい——猫が -> 来た -> Y
# Xが | Yでも | 泣き出すのである
# Xが | Yでも | 泣き出すのである
# Xが | Yで | 泣き出すのである
# Xが -> 質が -> わるい——猫が -> 来た -> 猫が -> 来たと -> いって -> 夜中でも -> 何でも -> 大きな -> 声で -> Y
# Xが | わるいYYが | 来た
# Xが -> わるい——猫が -> 来た -> Y
# Xが | Yでも | 泣き出すのである
# Xが | Yでも | 泣き出すのである
# Xが | Yで | 泣き出すのである
# Xが -> わるい——猫が -> 来た -> 猫が -> 来たと -> いって -> 夜中でも -> 何でも -> 大きな -> 声で -> Y
# わるいXXが -> 来た -> Y
# わるいXXが | Yでも | 泣き出すのである
# わるいXXが | Yでも | 泣き出すのである
# わるいXXが | Yで | 泣き出すのである
# わるいXXが -> 来た -> 猫が -> 来たと -> いって -> 夜中でも -> 何でも -> 大きな -> 声で -> Y
# Xが | Yでも | 泣き出すのである
# Xが | Yでも | 泣き出すのである
# Xが | Yで | 泣き出すのである
# Xが -> 来たと -> いって -> 夜中でも -> 何でも -> 大きな -> 声で -> Y
# Xでも | Yでも | 泣き出すのである
# Xでも | Yで | 泣き出すのである
# Xでも -> 何でも -> 大きな -> 声で -> Y
# Xでも | Yで | 泣き出すのである
# Xでも -> 大きな -> 声で -> Y
# Xで -> Y
# Xの -> Y
# Xの -> 神経胃弱性の -> Y
# Xの | Yを -> さまして | 飛び出してくる
# Xの | Yの -> 部屋から | 飛び出してくる
# Xの | Yから | 飛び出してくる
# XXXの -> Y
# XXXの | Yを -> さまして | 飛び出してくる
# XXXの | Yの -> 部屋から | 飛び出してくる
# XXXの | Yから | 飛び出してくる
# Xは | Yを -> さまして | 飛び出してくる
# Xは | Yの -> 部屋から | 飛び出してくる
# Xは | Yから | 飛び出してくる
# Xを | Yの -> 部屋から | 飛び出してくる
# Xを | Yから | 飛び出してくる
# Xの -> Y
# Xなどは | YYで | 叩かれた
# Xなどは | YY | 叩かれた
# XXで | YY | 叩かれた
# Xは | Yと -> 同居して -> 観察すれば -> する -> ほど | 断言せざるを得ないようになった
# Xは | Yして -> 観察すれば -> する -> ほど | 断言せざるを得ないようになった
# Xは | Yを -> 観察すれば -> する -> ほど | 断言せざるを得ないようになった
# Xは | Yすれば -> する -> ほど | 断言せざるを得ないようになった
# Xは | Yは | 断言せざるを得ないようになった
# Xは | Yな -> ものだと | 断言せざるを得ないようになった
# Xは | Yだと | 断言せざるを得ないようになった
# Xは -> 人間と -> 同居して -> 彼等を -> 観察すれば -> する -> ほど -> 彼等は -> 我儘な -> ものだと -> Y
# Xと -> Y
# Xと | Yを | 観察すれば
# Xと -> 同居して -> 彼等を -> Y
# Xと | Yは | 断言せざるを得ないようになった
# Xと | Yな -> ものだと | 断言せざるを得ないようになった
# Xと | Yだと | 断言せざるを得ないようになった
# Xと -> 同居して -> 彼等を -> 観察すれば -> する -> ほど -> 彼等は -> 我儘な -> ものだと -> Y
# Xして | Yを | 観察すれば
# Xして -> 彼等を -> Y
# Xして | Yは | 断言せざるを得ないようになった
# Xして | Yな -> ものだと | 断言せざるを得ないようになった
# Xして | Yだと | 断言せざるを得ないようになった
# Xして -> 彼等を -> 観察すれば -> する -> ほど -> 彼等は -> 我儘な -> ものだと -> Y
# Xを -> Y
# Xを | Yは | 断言せざるを得ないようになった
# Xを | Yな -> ものだと | 断言せざるを得ないようになった
# Xを | Yだと | 断言せざるを得ないようになった
# Xを -> 観察すれば -> する -> ほど -> 彼等は -> 我儘な -> ものだと -> Y
# Xすれば | Yは | 断言せざるを得ないようになった
# Xすれば | Yな -> ものだと | 断言せざるを得ないようになった
# Xすれば | Yだと | 断言せざるを得ないようになった
# Xすれば -> する -> ほど -> 彼等は -> 我儘な -> ものだと -> Y
# Xは | Yな -> ものだと | 断言せざるを得ないようになった
# Xは | Yだと | 断言せざるを得ないようになった
# Xは -> 我儘な -> ものだと -> Y
# Xな -> Y
# Xな -> ものだと -> Y
# Xだと -> Y
